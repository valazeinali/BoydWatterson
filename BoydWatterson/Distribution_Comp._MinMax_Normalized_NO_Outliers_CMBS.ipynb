# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('minmax_OAS_with_Returns_Final_NO_Outliers_CMBS.csv')

# %%
df.head(20)
# Out:
#                    Date       OAS Total Return % 1-mo-LOC Agg Returns  \
# 0   1998-01-31 00:00:00  0.131980                 #VALUE!     #VALUE!
# 1   1998-02-28 00:00:00  0.076142                 #VALUE!     #VALUE!
# 2   1998-03-31 00:00:00  0.055838                 #VALUE!     #VALUE!
# 3   1998-04-30 00:00:00  0.055838                 #VALUE!     #VALUE!
# 4   1998-05-31 00:00:00  0.010152                 #VALUE!     #VALUE!
# 5   1998-06-30 00:00:00  0.045685                 #VALUE!     #VALUE!
# 6   1998-07-31 00:00:00  0.040609                 #VALUE!     #VALUE!
# 7   1998-08-31 00:00:00  0.157360                 #VALUE!     #VALUE!
# 8   1998-09-30 00:00:00  0.355330                 #VALUE!     #VALUE!
# 9   1998-10-31 00:00:00  0.456853                 #VALUE!     #VALUE!
# 10  1998-11-30 00:00:00  0.289340                 #VALUE!     #VALUE!
# 11  1998-12-31 00:00:00  0.279188                 #VALUE!     #VALUE!
# 12  1999-01-31 00:00:00  0.258883                 #VALUE!     #VALUE!
# 13  1999-02-28 00:00:00  0.233503                 #VALUE!     #VALUE!
# 14  1999-03-31 00:00:00  0.177665                 #VALUE!     #VALUE!
# 15  1999-04-30 00:00:00  0.253807                 #VALUE!     #VALUE!
# 16  1999-05-31 00:00:00  0.203046                 #VALUE!     #VALUE!
# 17  1999-06-30 00:00:00  0.233503                 #VALUE!     #VALUE!
# 18  1999-07-31 00:00:00  0.314721                 #VALUE!     #VALUE!
# 19  1999-08-31 00:00:00  0.335025                 #VALUE!     #VALUE!
#
#     Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 0                          0.405000                    0.660023
# 1                          0.779222                    0.633513
# 2                          0.576556                    0.528896
# 3                          0.442333                    0.439477
# 4                          0.617444                    0.652790
# 5                          0.365000                    0.475991
# 6                          0.386333                    0.477684
# 7                          0.000000                    0.585918
# 8                          0.000000                    0.214159
# 9                          0.000000                    0.103771
# 10                         1.000000                    0.875298
# 11                         0.542778                    0.592728
# 12                         0.573889                    0.556175
# 13                         0.616556                    0.058830
# 14                         0.729444                    0.744517
# 15                         0.109889                    0.231781
# 16                         0.703222                    0.439823
# 17                         0.313000                    0.447018
# 18                         0.003222                    0.133474
# 19                         0.446778                    0.509080
#
#     Excess Return % 3-mo (Treasury)  Excess Return % 3-mo (Agg)  \
# 0                          0.671127                    0.708245
# 1                          0.691848                    0.573015
# 2                          0.602060                    0.584834
# 3                          0.484645                    0.552395
# 4                          0.453564                    0.575822
# 5                          0.032992                    0.534819
# 6                          0.000000                    0.374275
# 7                          0.000000                    0.145006
# 8                          0.132400                    0.322443
# 9                          0.720955                    0.554566
# 10                         1.000000                    0.831962
# 11                         0.655834                    0.331337
# 12                         0.759435                    0.424408
# 13                         0.501912                    0.225503
# 14                         0.550012                    0.459112
# 15                         0.318883                    0.276697
# 16                         0.259682                    0.216420
# 17                         0.117353                    0.258885
# 18                         0.414837                    0.433113
# 19                         0.635853                    0.540764
#
#     Excess Return % 6-mo (Treasury)  Excess Return % 6-mo (Agg)  \
# 0                          0.624016                    0.706001
# 1                          0.616500                    0.623432
# 2                          0.246242                    0.601879
# 3                          0.000000                    0.459356
# 4                          0.000000                    0.307336
# 5                          0.000000                    0.408096
# 6                          0.000000                    0.460958
# 7                          0.052613                    0.496502
# 8                          0.357373                    0.257819
# 9                          0.859520                    0.497983
# 10                         0.927344                    0.555951
# 11                         0.660344                    0.358753
# 12                         0.567824                    0.292770
# 13                         0.338046                    0.101356
# 14                         0.269685                    0.305245
# 15                         0.317824                    0.299199
# 16                         0.435218                    0.334186
# 17                         0.451324                    0.408810
# 18                         0.504653                    0.403165
# 19                         0.523801                    0.417923
#
#     Excess Return % 9-mo (Treasury)  Excess Return % 9-mo (Agg)  \
# 0                          0.000000                    0.561522
# 1                          0.000000                    0.394141
# 2                          0.033368                    0.466896
# 3                          0.020775                    0.486104
# 4                          0.069822                    0.521219
# 5                          0.069490                    0.342492
# 6                          0.205365                    0.423294
# 7                          0.102299                    0.349300
# 8                          0.416798                    0.305339
# 9                          0.726491                    0.375408
# 10                         0.749524                    0.384346
# 11                         0.406690                    0.274148
# 12                         0.520857                    0.315805
# 13                         0.456566                    0.241441
# 14                         0.503790                    0.405673
# 15                         0.397908                    0.312402
# 16                         0.375870                    0.292627
# 17                         0.317046                    0.310306
# 18                         0.219283                    0.336588
# 19                         0.390617                    0.429164
#
#     Excess Return % 12-mo (Treasury)  Excess Return % 12-mo (Agg)  \
# 0                           0.173089                     0.617685
# 1                           0.231658                     0.586884
# 2                           0.175247                     0.416437
# 3                           0.228268                     0.480389
# 4                           0.112978                     0.418787
# 5                           0.142725                     0.355623
# 6                           0.124692                     0.347029
# 7                           0.000000                     0.244939
# 8                           0.195438                     0.222149
# 9                           0.669390                     0.375491
# 10                          0.828915                     0.436373
# 11                          0.612824                     0.356091
# 12                          0.579069                     0.309176
# 13                          0.397657                     0.193471
# 14                          0.372996                     0.323898
# 15                          0.137639                     0.261566
# 16                          0.260018                     0.323658
# 17                          0.080456                     0.317952
# 18                          0.249229                     0.410377
# 19                          0.362053                     0.466820
#
#     Excess Return % 24-mo (Treasury)  Excess Return % 24-mo (Agg)  \
# 0                           0.318823                     0.420055
# 1                           0.243321                     0.350215
# 2                           0.193492                     0.331136
# 3                           0.081423                     0.331909
# 4                           0.085781                     0.332143
# 5                           0.000000                     0.299312
# 6                           0.086349                     0.339275
# 7                           0.074034                     0.317514
# 8                           0.229585                     0.324532
# 9                           0.492374                     0.397315
# 10                          0.590517                     0.458125
# 11                          0.384000                     0.424407
# 12                          0.428429                     0.462580
# 13                          0.414977                     0.432132
# 14                          0.375095                     0.510752
# 15                          0.269089                     0.455274
# 16                          0.418198                     0.495574
# 17                          0.365432                     0.484471
# 18                          0.351033                     0.467368
# 19                          0.469070                     0.547261
#
#     Excess Return % 36-mo (Treasury)  Excess Return % 36-mo (Agg)  Quadrant
# 0                           0.242360                     0.498648         1
# 1                           0.261704                     0.463807         1
# 2                           0.197741                     0.461774         1
# 3                           0.134753                     0.442481         3
# 4                           0.201886                     0.450922         3
# 5                           0.172302                     0.419105         3
# 6                           0.150439                     0.402739         2
# 7                           0.181648                     0.426845         2
# 8                           0.324854                     0.431100         2
# 9                           0.456437                     0.493856         1
# 10                          0.512923                     0.519680         1
# 11                          0.382802                     0.463446         1
# 12                          0.399545                     0.453816         3
# 13                          0.394831                     0.447315         3
# 14                          0.385566                     0.515190         3
# 15                          0.378820                     0.478015         3
# 16                          0.471229                     0.538222         3
# 17                          0.420107                     0.548696         3
# 18                          0.451154                     0.587950         2
# 19                          0.454405                     0.652613         2

# %% [markdown]
# # OAS to 3 Month Tres.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (Treasury)
#for x in df["Excess Return % 1-mo (Treasury)"]:
    #if x == "FALSE":
        ##else:
#for x in df["Excess Return % 1-mo (Treasury)"]:
#if(df["Excess Return % 3-mo (Treasury)"].any() > -1):

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"
df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 3-mo (Treasury)"] = df["Excess Return % 3-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 3-mo (Treasury)"] = df["Excess Return % 3-mo (Treasury)"].replace([1],["NaN"])
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 3-mo (Treasury)"], color="red", label="1M_Tres._Normalized_Value")

# %%
df["Excess Return % 3-mo (Treasury)"].describe()
# Out:
# count     266
# unique    209
# top       NaN
# freq       48
# Name: Excess Return % 3-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 3 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 3-mo (Agg)"] = df["Excess Return % 3-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 3-mo (Agg)"] = df["Excess Return % 3-mo (Agg)"].replace([1],["NaN"])


plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 3-mo (Agg)"], color="red", label="3M_AGG_Normalized_Value")

# %%
df["Excess Return % 3-mo (Agg)"].describe()
# Out:
# count     266
# unique    235
# top       NaN
# freq       32
# Name: Excess Return % 3-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 6 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 6-mo (Treasury)"] = df["Excess Return % 6-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 6-mo (Treasury)"] = df["Excess Return % 6-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
df["Excess Return % 6-mo (Treasury)"].describe()
# Out:
# count     263
# unique    203
# top       NaN
# freq       56
# Name: Excess Return % 6-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 6 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 6-mo (Agg)"] = df["Excess Return % 6-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 6-mo (Agg)"] = df["Excess Return % 6-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 6-mo (Agg)"], color="red", label="6M_AGG_Normalized_Value")

# %%
df["Excess Return % 6-mo (Agg)"].tail(60)
# Out:
# 207    0.593115
# 208    0.503942
# 209    0.474409
# 210    0.394871
# 211    0.382936
# 212    0.349239
# 213    0.328366
# 214    0.417557
# 215    0.378877
# 216    0.369154
# 217    0.466307
# 218    0.508612
# 219     0.47657
# 220    0.464722
# 221    0.595363
# 222    0.609458
# 223    0.614668
# 224    0.554331
# 225     0.55778
# 226     0.54318
# 227    0.426321
# 228    0.423394
# 229     0.40212
# 230      0.5045
# 231    0.426495
# 232    0.456812
# 233    0.418132
# 234     0.42923
# 235    0.417243
# 236    0.443762
# 237    0.489881
# 238    0.459007
# 239    0.506921
# 240    0.536019
# 241    0.500893
# 242    0.505545
# 243    0.567433
# 244    0.603709
# 245    0.598621
# 246    0.555568
# 247    0.549748
# 248    0.555951
# 249    0.473381
# 250    0.470472
# 251    0.452613
# 252    0.477093
# 253    0.487738
# 254    0.369032
# 255    0.407103
# 256    0.337827
# 257    0.304792
# 258     0.29054
# 259    0.376194
# 260    0.376072
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN
# 265         NaN
# 266         NaN
# Name: Excess Return % 6-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 9 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 9-mo (Treasury)"] = df["Excess Return % 9-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 9-mo (Treasury)"] = df["Excess Return % 9-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
df["Excess Return % 9-mo (Treasury)"].describe()
# Out:
# count     260
# unique    190
# top       NaN
# freq       63
# Name: Excess Return % 9-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 9 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 9-mo (Agg)"] = df["Excess Return % 9-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 9-mo (Agg)"] = df["Excess Return % 9-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 9-mo (Agg)"], color="red", label="9M_AGG_Normalized_Value")

# %%
df["Excess Return % 9-mo (Agg)"].describe()
# Out:
# count     260
# unique    220
# top       NaN
# freq       40
# Name: Excess Return % 9-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 12 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 12-mo (Treasury)"] = df["Excess Return % 12-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 12-mo (Treasury)"] = df["Excess Return % 12-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df["Excess Return % 12-mo (Treasury)"].describe()
# Out:
# count     257
# unique    192
# top       NaN
# freq       59
# Name: Excess Return % 12-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 12 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 12-mo (Agg)"] = df["Excess Return % 12-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 12-mo (Agg)"] = df["Excess Return % 12-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 12-mo (Agg)"], color="red", label="12M_AGG_Normalized_Value")

# %%
df["Excess Return % 12-mo (Agg)"].describe()
# Out:
# count     257
# unique    214
# top       NaN
# freq       43
# Name: Excess Return % 12-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 24 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (Treasury)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 24-mo (Treasury)"] = df["Excess Return % 24-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 24-mo (Treasury)"] = df["Excess Return % 24-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 24-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df["Excess Return % 24-mo (Treasury)"].describe()
# Out:
# count     245
# unique    178
# top       NaN
# freq       64
# Name: Excess Return % 24-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 24 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 24-mo (Agg)"] = df["Excess Return % 24-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 24-mo (Agg)"] = df["Excess Return % 24-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 24-mo (Agg)"], color="red", label="1Vale")

# %%
df["Excess Return % 24-mo (Agg)"].describe()
# Out:
# count     245
# unique    216
# top       NaN
# freq       27
# Name: Excess Return % 24-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 36 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 36-mo (Treasury)"] = df["Excess Return % 36-mo (Treasury)"].replace([0],["NaN"])
df["Excess Return % 36-mo (Treasury)"] = df["Excess Return % 36-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 36-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df["Excess Return % 36-mo (Treasury)"].describe()
# Out:
# count     233
# unique    155
# top       NaN
# freq       74
# Name: Excess Return % 36-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 36 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])
df["Excess Return % 36-mo (Agg)"] = df["Excess Return % 36-mo (Agg)"].replace([0],["NaN"])
df["Excess Return % 36-mo (Agg)"] = df["Excess Return % 36-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 36-mo (Agg)"], color="red", label="1Vale")

# %%
df["Excess Return % 36-mo (Agg)"].describe()
# Out:
# count     233
# unique    206
# top       NaN
# freq       27
# Name: Excess Return % 36-mo (Agg), dtype: object

# %% [markdown]
# # Below we test with 15 years of data. Jan 2005 - April 2020

# %%
df1 = df[df.Date >= '2005-01-31 00:00:00'] # data set for dates greater than a given time
df1.head()
# Out:
#                    Date        OAS Total Return % 1-mo-LOC Agg Returns  \
# 84  2005-01-31 00:00:00  0.0101523                 #VALUE!     #VALUE!
# 85  2005-02-28 00:00:00        NaN                 #VALUE!     #VALUE!
# 86  2005-03-31 00:00:00  0.0101523                 #VALUE!     #VALUE!
# 87  2005-04-30 00:00:00  0.0507614                 #VALUE!     #VALUE!
# 88  2005-05-31 00:00:00  0.0456853                 #VALUE!     #VALUE!
#
#     Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 84                         0.559222                    0.435668
# 85                         0.482333                    0.396499
# 86                         0.379667                    0.480108
# 87                         0.313444                    0.468950
# 88                         0.485000                    0.496075
#
#    Excess Return % 3-mo (Treasury) Excess Return % 3-mo (Agg)  \
# 84                        0.482671                   0.395437
# 85                        0.346263                   0.415844
# 86                        0.347743                     0.4769
# 87                        0.421991                   0.483058
# 88                        0.499445                    0.39881
#
#    Excess Return % 6-mo (Treasury) Excess Return % 6-mo (Agg)  \
# 84                         0.44184                   0.423777
# 85                        0.399069                   0.376629
# 86                        0.390301                   0.457753
# 87                        0.387616                   0.406092
# 88                        0.427523                   0.410936
#
#    Excess Return % 9-mo (Treasury) Excess Return % 9-mo (Agg)  \
# 84                        0.399565                   0.372618
# 85                        0.344884                   0.385851
# 86                        0.309093                   0.403264
# 87                        0.328645                   0.384346
# 88                        0.408679                   0.383385
#
#    Excess Return % 12-mo (Treasury) Excess Return % 12-mo (Agg)  \
# 84                         0.341708                    0.366076
# 85                         0.330919                       0.375
# 86                         0.352189                    0.380215
# 87                         0.392725                    0.427883
# 88                         0.463317                    0.449303
#
#    Excess Return % 24-mo (Treasury) Excess Return % 24-mo (Agg)  \
# 84                         0.403515                    0.391739
# 85                         0.354538                    0.378569
# 86                          0.34478                    0.397049
# 87                         0.361643                    0.403267
# 88                         0.360601                    0.387556
#
#    Excess Return % 36-mo (Treasury) Excess Return % 36-mo (Agg)  Quadrant
# 84                              NaN                    0.296151         1
# 85                              NaN                    0.173271         1
# 86                              NaN                   0.0405985         1
# 87                              NaN                    0.111708         4
# 88                              NaN                     0.17997         4

# %% [markdown]
# # OAS to 3 Month Tres.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (Treasury)
#for x in df["Excess Return % 1-mo (Treasury)"]:
    #if x == "FALSE":
        ##else:
#for x in df["Excess Return % 1-mo (Treasury)"]:
#if(df["Excess Return % 3-mo (Treasury)"].any() > -1):

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"
df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 3-mo (Treasury)"] = df1["Excess Return % 3-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 3-mo (Treasury)"] = df1["Excess Return % 3-mo (Treasury)"].replace([1],["NaN"])
plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 3-mo (Treasury)"], color="red", label="1M_Tres._Normalized_Value")

# %%
df1["Excess Return % 3-mo (Treasury)"].describe()
# Out:
# count     182
# unique    134
# top       NaN
# freq       45
# Name: Excess Return % 3-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 3 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 3-mo (Agg)"] = df1["Excess Return % 3-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 3-mo (Agg)"] = df1["Excess Return % 3-mo (Agg)"].replace([1],["NaN"])


plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 3-mo (Agg)"], color="red", label="3M_AGG_Normalized_Value")

# %%
df1["Excess Return % 3-mo (Agg)"].describe()
# Out:
# count     182
# unique    151
# top       NaN
# freq       32
# Name: Excess Return % 3-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 6 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 6-mo (Treasury)"] = df1["Excess Return % 6-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 6-mo (Treasury)"] = df1["Excess Return % 6-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
df1["Excess Return % 6-mo (Treasury)"].describe()
# Out:
# count     179
# unique    127
# top       NaN
# freq       52
# Name: Excess Return % 6-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 6 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 6-mo (Agg)"] = df1["Excess Return % 6-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 6-mo (Agg)"] = df1["Excess Return % 6-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 6-mo (Agg)"], color="red", label="6M_AGG_Normalized_Value")

# %%
df1["Excess Return % 6-mo (Agg)"].tail(10)
# Out:
# 257    0.304792
# 258     0.29054
# 259    0.376194
# 260    0.376072
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN
# 265         NaN
# 266         NaN
# Name: Excess Return % 6-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 9 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 9-mo (Treasury)"] = df1["Excess Return % 9-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 9-mo (Treasury)"] = df1["Excess Return % 9-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
df1["Excess Return % 9-mo (Treasury)"].describe()
# Out:
# count     176
# unique    113
# top       NaN
# freq       61
# Name: Excess Return % 9-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 9 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 9-mo (Agg)"] = df1["Excess Return % 9-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 9-mo (Agg)"] = df1["Excess Return % 9-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 9-mo (Agg)"], color="red", label="9M_AGG_Normalized_Value")

# %%
df1["Excess Return % 9-mo (Agg)"].describe()
# Out:
# count     176
# unique    137
# top       NaN
# freq       40
# Name: Excess Return % 9-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 12 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 12-mo (Treasury)"] = df1["Excess Return % 12-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 12-mo (Treasury)"] = df1["Excess Return % 12-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df1["Excess Return % 12-mo (Treasury)"].describe()
# Out:
# count     173
# unique    113
# top       NaN
# freq       58
# Name: Excess Return % 12-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 12 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 12-mo (Agg)"] = df1["Excess Return % 12-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 12-mo (Agg)"] = df1["Excess Return % 12-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 12-mo (Agg)"], color="red", label="12M_AGG_Normalized_Value")

# %%
df1["Excess Return % 12-mo (Agg)"].describe()
# Out:
# count     173
# unique    130
# top       NaN
# freq       43
# Name: Excess Return % 12-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 24 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (Treasury)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 24-mo (Treasury)"] = df1["Excess Return % 24-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 24-mo (Treasury)"] = df1["Excess Return % 24-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 24-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df1["Excess Return % 24-mo (Treasury)"].describe()
# Out:
# count     161
# unique     97
# top       NaN
# freq       63
# Name: Excess Return % 24-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 24 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 24-mo (Agg)"] = df1["Excess Return % 24-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 24-mo (Agg)"] = df1["Excess Return % 24-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 24-mo (Agg)"], color="red", label="1Vale")

# %%
df1["Excess Return % 24-mo (Agg)"].describe()
# Out:
# count     161
# unique    134
# top       NaN
# freq       27
# Name: Excess Return % 24-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 36 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 36-mo (Treasury)"] = df1["Excess Return % 36-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 36-mo (Treasury)"] = df1["Excess Return % 36-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 36-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df1["Excess Return % 36-mo (Treasury)"].describe()
# Out:
# count     149
# unique     76
# top       NaN
# freq       73
# Name: Excess Return % 36-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 36 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df1["OAS"] = df1["OAS"].replace([0],["NaN"])
df1["OAS"] = df1["OAS"].replace([1],["Nan"])
df1["Excess Return % 36-mo (Agg)"] = df1["Excess Return % 36-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 36-mo (Agg)"] = df1["Excess Return % 36-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df1["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 36-mo (Agg)"], color="red", label="1Vale")

# %%
df1["Excess Return % 36-mo (Agg)"].describe()
# Out:
# count     149
# unique    123
# top       NaN
# freq       27
# Name: Excess Return % 36-mo (Agg), dtype: object

# %% [markdown]
# # Below we test with 10 years of data. Jan 2010 - April 2020

# %%
df2 = df[df.Date >= '2010-01-31 00:00:00'] # data set for dates greater than a given time
df2.head()
# Out:
#                     Date  OAS Total Return % 1-mo-LOC Agg Returns  \
# 144  2010-01-31 00:00:00  Nan                 #VALUE!     #VALUE!
# 145  2010-02-28 00:00:00  Nan                 #VALUE!     #VALUE!
# 146  2010-03-31 00:00:00  Nan                 #VALUE!     #VALUE!
# 147  2010-04-30 00:00:00  Nan                 #VALUE!     #VALUE!
# 148  2010-05-31 00:00:00  Nan                 #VALUE!     #VALUE!
#
#      Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 144                         1.000000                    1.000000
# 145                         0.975667                    0.951058
# 146                         1.000000                    1.000000
# 147                         1.000000                    1.000000
# 148                         0.000000                    0.000000
#
#     Excess Return % 3-mo (Treasury) Excess Return % 3-mo (Agg)  \
# 144                             NaN                        NaN
# 145                             NaN                        NaN
# 146                             NaN                   0.917649
# 147                        0.573693                   0.545813
# 148                        0.354896                   0.341057
#
#     Excess Return % 6-mo (Treasury) Excess Return % 6-mo (Agg)  \
# 144                             NaN                        NaN
# 145                             NaN                        NaN
# 146                             NaN                        NaN
# 147                        0.974767                   0.909838
# 148                        0.744452                   0.746737
#
#     Excess Return % 9-mo (Treasury) Excess Return % 9-mo (Agg)  \
# 144                             NaN                        NaN
# 145                             NaN                        NaN
# 146                             NaN                        NaN
# 147                             NaN                        NaN
# 148                             NaN                   0.994671
#
#     Excess Return % 12-mo (Treasury) Excess Return % 12-mo (Agg)  \
# 144                              NaN                         NaN
# 145                              NaN                         NaN
# 146                              NaN                         NaN
# 147                              NaN                         NaN
# 148                              NaN                         NaN
#
#     Excess Return % 24-mo (Treasury) Excess Return % 24-mo (Agg)  \
# 144                              NaN                    0.886114
# 145                              NaN                    0.850454
# 146                              NaN                    0.833992
# 147                              NaN                     0.75973
# 148                              NaN                       0.625
#
#     Excess Return % 36-mo (Treasury) Excess Return % 36-mo (Agg)  Quadrant
# 144                              NaN                    0.949158         2
# 145                              NaN                    0.900988         2
# 146                              NaN                    0.833171         2
# 147                              NaN                    0.751491         1
# 148                              NaN                    0.667123         1

# %% [markdown]
# # OAS to 3 Month Tres.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (Treasury)
#for x in df["Excess Return % 1-mo (Treasury)"]:
    #if x == "FALSE":
        ##else:
#for x in df["Excess Return % 1-mo (Treasury)"]:
#if(df["Excess Return % 3-mo (Treasury)"].any() > -1):

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"
df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 3-mo (Treasury)"] = df2["Excess Return % 3-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 3-mo (Treasury)"] = df2["Excess Return % 3-mo (Treasury)"].replace([1],["NaN"])
plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 3-mo (Treasury)"], color="red", label="1M_Tres._Normalized_Value")

# %%
df2["Excess Return % 3-mo (Treasury)"].describe()
# Out:
# count     122
# unique    102
# top       NaN
# freq       19
# Name: Excess Return % 3-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 3 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 3-mo (Agg)"] = df2["Excess Return % 3-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 3-mo (Agg)"] = df2["Excess Return % 3-mo (Agg)"].replace([1],["NaN"])


plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 3-mo (Agg)"], color="red", label="3M_AGG_Normalized_Value")

# %%
df2["Excess Return % 3-mo (Agg)"].describe()
# Out:
# count     122
# unique    111
# top       NaN
# freq       12
# Name: Excess Return % 3-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 6 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 6-mo (Treasury)"] = df2["Excess Return % 6-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 6-mo (Treasury)"] = df2["Excess Return % 6-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
df2["Excess Return % 6-mo (Treasury)"].describe()
# Out:
# count     119
# unique     97
# top       NaN
# freq       22
# Name: Excess Return % 6-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 6 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 6-mo (Agg)"] = df2["Excess Return % 6-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 6-mo (Agg)"] = df2["Excess Return % 6-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 6-mo (Agg)"], color="red", label="6M_AGG_Normalized_Value")

# %%
df2["Excess Return % 6-mo (Agg)"].tail(10)
# Out:
# 257    0.304792
# 258     0.29054
# 259    0.376194
# 260    0.376072
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN
# 265         NaN
# 266         NaN
# Name: Excess Return % 6-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 9 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 9-mo (Treasury)"] = df2["Excess Return % 9-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 9-mo (Treasury)"] = df2["Excess Return % 9-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
df2["Excess Return % 9-mo (Treasury)"].describe()
# Out:
# count     116
# unique     90
# top       NaN
# freq       24
# Name: Excess Return % 9-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 9 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 9-mo (Agg)"] = df2["Excess Return % 9-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 9-mo (Agg)"] = df2["Excess Return % 9-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 9-mo (Agg)"], color="red", label="9M_AGG_Normalized_Value")

# %%
df2["Excess Return % 9-mo (Agg)"].describe()
# Out:
# count     116
# unique    107
# top       NaN
# freq       10
# Name: Excess Return % 9-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 12 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 12-mo (Treasury)"] = df2["Excess Return % 12-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 12-mo (Treasury)"] = df2["Excess Return % 12-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df2["Excess Return % 12-mo (Treasury)"].describe()
# Out:
# count     113
# unique     92
# top       NaN
# freq       20
# Name: Excess Return % 12-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 12 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 12-mo (Agg)"] = df2["Excess Return % 12-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 12-mo (Agg)"] = df2["Excess Return % 12-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 12-mo (Agg)"], color="red", label="12M_AGG_Normalized_Value")

# %%
df2["Excess Return % 12-mo (Agg)"].describe()
# Out:
# count     113
# unique    103
# top       NaN
# freq       10
# Name: Excess Return % 12-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 24 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (Treasury)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 24-mo (Treasury)"] = df2["Excess Return % 24-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 24-mo (Treasury)"] = df2["Excess Return % 24-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 24-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df2["Excess Return % 24-mo (Treasury)"].describe()
# Out:
# count     101
# unique     81
# top       NaN
# freq       20
# Name: Excess Return % 24-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 24 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 24-mo (Agg)"] = df2["Excess Return % 24-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 24-mo (Agg)"] = df2["Excess Return % 24-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 24-mo (Agg)"], color="red", label="1Vale")

# %%
df2["Excess Return % 24-mo (Agg)"].describe()
# Out:
# count    101.000000
# mean       0.495061
# std        0.140225
# min        0.145292
# 25%        0.412047
# 50%        0.449007
# 75%        0.581501
# max        0.886114
# Name: Excess Return % 24-mo (Agg), dtype: float64

# %% [markdown]
# # OAS to 36 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 36-mo (Treasury)"] = df2["Excess Return % 36-mo (Treasury)"].replace([0],["NaN"])
df2["Excess Return % 36-mo (Treasury)"] = df2["Excess Return % 36-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 36-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df2["Excess Return % 36-mo (Treasury)"].describe()
# Out:
# count      89
# unique     69
# top       NaN
# freq       20
# Name: Excess Return % 36-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 36 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df2["OAS"] = df2["OAS"].replace([0],["NaN"])
df2["OAS"] = df2["OAS"].replace([1],["Nan"])
df2["Excess Return % 36-mo (Agg)"] = df2["Excess Return % 36-mo (Agg)"].replace([0],["NaN"])
df2["Excess Return % 36-mo (Agg)"] = df2["Excess Return % 36-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df2["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df2["Excess Return % 36-mo (Agg)"], color="red", label="1Vale")

# %%
df2["Excess Return % 36-mo (Agg)"].describe()
# Out:
# count    89.000000
# mean      0.491180
# std       0.139437
# min       0.193170
# 25%       0.400379
# 50%       0.445185
# 75%       0.537991
# max       0.949158
# Name: Excess Return % 36-mo (Agg), dtype: float64

# %% [markdown]
# # Below we test with 5 years of data. Jan 2015 - April 2020

# %%
df3 = df[df.Date >= '2015-01-31 00:00:00'] # data set for dates greater than a given time
df3.head()
# Out:
#                     Date       OAS Total Return % 1-mo-LOC Agg Returns  \
# 204  2015-01-31 00:00:00  0.335025                 #VALUE!     #VALUE!
# 205  2015-02-28 00:00:00  0.324873                 #VALUE!     #VALUE!
# 206  2015-03-31 00:00:00  0.304569                 #VALUE!     #VALUE!
# 207  2015-04-30 00:00:00  0.314721                 #VALUE!     #VALUE!
# 208  2015-05-31 00:00:00  0.304569                 #VALUE!     #VALUE!
#
#      Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 204                         0.396556                    0.236052
# 205                         0.571667                    0.616506
# 206                         0.519667                    0.541747
# 207                         0.469889                    0.582147
# 208                         0.488556                    0.615660
#
#     Excess Return % 3-mo (Treasury) Excess Return % 3-mo (Agg)  \
# 204                        0.519672                   0.445735
# 205                        0.560372                   0.657946
# 206                        0.514245                   0.657427
# 207                        0.360323                    0.65193
# 208                        0.341576                   0.541732
#
#     Excess Return % 6-mo (Treasury) Excess Return % 6-mo (Agg)  \
# 204                        0.423944                    0.58564
# 205                        0.439871                   0.660979
# 206                        0.336077                   0.576946
# 207                        0.331424                   0.593115
# 208                        0.342162                   0.503942
#
#     Excess Return % 9-mo (Treasury) Excess Return % 9-mo (Agg)  \
# 204                         0.37239                   0.521578
# 205                        0.409673                   0.566465
# 206                        0.399731                   0.546586
# 207                        0.294843                   0.491036
# 208                        0.182498                   0.429025
#
#     Excess Return % 12-mo (Treasury) Excess Return % 12-mo (Agg)  \
# 204                         0.333385                    0.495566
# 205                         0.254316                    0.537094
# 206                         0.166461                    0.459984
# 207                         0.277281                    0.456903
# 208                            0.375                    0.456914
#
#     Excess Return % 24-mo (Treasury) Excess Return % 24-mo (Agg)  \
# 204                         0.480248                    0.450101
# 205                         0.519373                    0.501858
# 206                         0.472954                    0.459469
# 207                         0.446808                    0.449072
# 208                         0.455712                     0.44082
#
#     Excess Return % 36-mo (Treasury) Excess Return % 36-mo (Agg)  Quadrant
# 204                         0.502113                    0.413247         1
# 205                         0.544538                    0.445185         1
# 206                         0.512272                    0.443531         1
# 207                         0.470416                     0.42782         3
# 208                         0.482932                    0.421314         3

# %% [markdown]
# # OAS to 3 Month Tres.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (Treasury)
#for x in df["Excess Return % 1-mo (Treasury)"]:
    #if x == "FALSE":
        ##else:
#for x in df["Excess Return % 1-mo (Treasury)"]:
#if(df["Excess Return % 3-mo (Treasury)"].any() > -1):

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"
df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 3-mo (Treasury)"] = df3["Excess Return % 3-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 3-mo (Treasury)"] = df3["Excess Return % 3-mo (Treasury)"].replace([1],["NaN"])
plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 3-mo (Treasury)"], color="red", label="1M_Tres._Normalized_Value")

# %%
df3["Excess Return % 3-mo (Treasury)"].describe()
# Out:
# count     62.000000
# unique    60.000000
# top        0.373397
# freq       2.000000
# Name: Excess Return % 3-mo (Treasury), dtype: float64

# %% [markdown]
# # OAS to 3 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 3-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 3-mo (Agg)"] = df3["Excess Return % 3-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 3-mo (Agg)"] = df3["Excess Return % 3-mo (Agg)"].replace([1],["NaN"])


plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 3-mo (Agg)"], color="red", label="3M_AGG_Normalized_Value")

# %%
df3["Excess Return % 3-mo (Agg)"].describe()
# Out:
# count      62
# unique     61
# top       NaN
# freq        2
# Name: Excess Return % 3-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 6 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 6-mo (Treasury)"] = df3["Excess Return % 6-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 6-mo (Treasury)"] = df3["Excess Return % 6-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
df3["Excess Return % 6-mo (Treasury)"].describe()
# Out:
# count     59.000000
# unique    57.000000
# top        0.503221
# freq       2.000000
# Name: Excess Return % 6-mo (Treasury), dtype: float64

# %% [markdown]
# # OAS to 6 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 6-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 6-mo (Agg)"] = df3["Excess Return % 6-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 6-mo (Agg)"] = df3["Excess Return % 6-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 6-mo (Agg)"], color="red", label="6M_AGG_Normalized_Value")

# %%
df3["Excess Return % 6-mo (Agg)"].tail(10)
# Out:
# 257    0.304792
# 258     0.29054
# 259    0.376194
# 260    0.376072
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN
# 265         NaN
# 266         NaN
# Name: Excess Return % 6-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 9 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 9-mo (Treasury)"] = df3["Excess Return % 9-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 9-mo (Treasury)"] = df3["Excess Return % 9-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
df3["Excess Return % 9-mo (Treasury)"].describe()
# Out:
# count     56.000000
# unique    53.000000
# top        0.535936
# freq       2.000000
# Name: Excess Return % 9-mo (Treasury), dtype: float64

# %% [markdown]
# # OAS to 9 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 9-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 9-mo (Agg)"] = df3["Excess Return % 9-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 9-mo (Agg)"] = df3["Excess Return % 9-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 9-mo (Agg)"], color="red", label="9M_AGG_Normalized_Value")

# %%
df3["Excess Return % 9-mo (Agg)"].describe()
# Out:
# count      56
# unique     55
# top       NaN
# freq        2
# Name: Excess Return % 9-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 12 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 12-mo (Treasury)"] = df3["Excess Return % 12-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 12-mo (Treasury)"] = df3["Excess Return % 12-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df3["Excess Return % 12-mo (Treasury)"].describe()
# Out:
# count      53
# unique     52
# top       NaN
# freq        2
# Name: Excess Return % 12-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 12 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 12-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 12-mo (Agg)"] = df3["Excess Return % 12-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 12-mo (Agg)"] = df3["Excess Return % 12-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 12-mo (Agg)"], color="red", label="12M_AGG_Normalized_Value")

# %%
df3["Excess Return % 12-mo (Agg)"].describe()
# Out:
# count      53
# unique     52
# top       NaN
# freq        2
# Name: Excess Return % 12-mo (Agg), dtype: object

# %% [markdown]
# # OAS to 24 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (Treasury)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 24-mo (Treasury)"] = df3["Excess Return % 24-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 24-mo (Treasury)"] = df3["Excess Return % 24-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 24-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df3["Excess Return % 24-mo (Treasury)"].describe()
# Out:
# count      41
# unique     40
# top       NaN
# freq        2
# Name: Excess Return % 24-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 24 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 24-mo (AGG)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 24-mo (Agg)"] = df3["Excess Return % 24-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 24-mo (Agg)"] = df3["Excess Return % 24-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 24-mo (Agg)"], color="red", label="1Vale")

# %%
df3["Excess Return % 24-mo (Agg)"].describe()
# Out:
# count    41.000000
# mean      0.427361
# std       0.065896
# min       0.145292
# 25%       0.422275
# 50%       0.442544
# 75%       0.455459
# max       0.501858
# Name: Excess Return % 24-mo (Agg), dtype: float64

# %% [markdown]
# # OAS to 36 Month Treasury.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (Treasury)

# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 36-mo (Treasury)"] = df3["Excess Return % 36-mo (Treasury)"].replace([0],["NaN"])
df3["Excess Return % 36-mo (Treasury)"] = df3["Excess Return % 36-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 36-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
df3["Excess Return % 36-mo (Treasury)"].describe()
# Out:
# count      29
# unique     28
# top       NaN
# freq        2
# Name: Excess Return % 36-mo (Treasury), dtype: object

# %% [markdown]
# # OAS to 36 Month AGG.
#
# ## OAS = Blue

# %%
#OAS to Excess Return % 36-mo (AGG)
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df3["OAS"] = df3["OAS"].replace([0],["NaN"])
df3["OAS"] = df3["OAS"].replace([1],["Nan"])
df3["Excess Return % 36-mo (Agg)"] = df3["Excess Return % 36-mo (Agg)"].replace([0],["NaN"])
df3["Excess Return % 36-mo (Agg)"] = df3["Excess Return % 36-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df3["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df3["Excess Return % 36-mo (Agg)"], color="red", label="1Vale")

# %%
df3["Excess Return % 36-mo (Agg)"].describe()
# Out:
# count    29.000000
# mean      0.415323
# std       0.063322
# min       0.193170
# 25%       0.406599
# 50%       0.427820
# 75%       0.445362
# max       0.476146
# Name: Excess Return % 36-mo (Agg), dtype: float64
