# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Arseny_Project.xlsx', sheet_name="CMBS_Tres")

# %%
df.head()
df_copy = df.copy()

# %%
df.head(6)
# Out:
#         Date  ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# 0 1998-05-31                                         61
# 1 1998-06-30                                         68
# 2 1998-07-31                                         67
# 3 1998-08-31                                         90
# 4 1998-09-30                                        130
# 5 1998-10-31                                        147
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 47
# 3                                                 58
# 4                                                 77
# 5                                                101
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 25 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 253 non-null    datetime64[ns]
#  1   ICE BofA AAA US Fixed Rate CMBS Index OAS            253 non-null    int64
#  2   ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS   253 non-null    int64
#  3   ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS   253 non-null    int64
#  4   ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS   253 non-null    int64
#  5   ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS  253 non-null    int64
#  6   ICE BofA AA US Fixed Rate CMBS Index OAS             253 non-null    int64
#  7   ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS   253 non-null    int64
# ...

# %%
df.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# count                                 253.000000
# mean                                  119.075099
# std                                    64.872573
# min                                    53.000000
# 25%                                    72.000000
# 50%                                   105.000000
# 75%                                   130.000000
# max                                   448.000000
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# count                                         253.000000
# mean                                          118.735178
# std                                            70.691293
# min                                            45.000000
# 25%                                            62.000000
# 50%                                            94.000000
# 75%                                           158.000000
# max                                           434.000000
# ...

# %% [markdown]
# # Drop Outliers!

# %%
df = df.drop(columns = ['Date'])

#q1 = df.quantile(0.25)
#q3 = df.quantile(0.75)

#iqr = q3 - q1

#lower_bound = q1 -(1.5 * iqr) 
#upper_bound = q3 +(1.5 * iqr)

#print(lower_bound)
#print(upper_bound)

#df = df[(df > lower_bound) & (df < upper_bound)] # gets rid of outliers on Agg Excess Returns
#df['Date'] = df_Date
#df.head()

# %%
def lower_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    lower_bounds = q1 -(1.5 * iqr) 
    
    return lower_bounds

# %%
def upper_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    upper_bounds = q3 +(1.5 * iqr) 
    
    return upper_bounds

# %%
lower_bound(df)
# Out:
# ICE BofA AAA US Fixed Rate CMBS Index OAS             -15.000000
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS    -82.000000
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS    -22.000000
# ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS    -12.000000
# ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS    -5.000000
# ICE BofA AA US Fixed Rate CMBS Index OAS               27.500000
# ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS     15.500000
# ICE BofA Single-A US Fixed Rate CMBS Index OAS         62.500000
# ICE BofA BBB US Fixed Rate CMBS Index OAS             -22.500000
# ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS   -88.000000
# ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS    -32.000000
# ICE BofA US ABS & CMBS Index OAS                       -3.000000
# ICE BofA AAA US Fixed Rate CMBS Index                  -0.008255
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index         -0.002770
# ...

# %%
upper_bound(df)
# Out:
# ICE BofA AAA US Fixed Rate CMBS Index OAS              217.000000
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS     302.000000
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS     202.000000
# ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS     212.000000
# ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS    211.000000
# ICE BofA AA US Fixed Rate CMBS Index OAS               255.500000
# ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS     275.500000
# ICE BofA Single-A US Fixed Rate CMBS Index OAS         290.500000
# ICE BofA BBB US Fixed Rate CMBS Index OAS              557.500000
# ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS    704.000000
# ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS     616.000000
# ICE BofA US ABS & CMBS Index OAS                       197.000000
# ICE BofA AAA US Fixed Rate CMBS Index                    0.010345
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index           0.004190
# ...

# %%
df["Date"] = df_copy["Date"]
df.head()
# Out:
#    ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# 0                                         61
# 1                                         68
# 2                                         67
# 3                                         90
# 4                                        130
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 47
# 3                                                 58
# 4                                                 77
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 53
# 3                                                 71
# 4                                                117
#
# ...

# %%
df.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# count                                 253.000000
# mean                                  119.075099
# std                                    64.872573
# min                                    53.000000
# 25%                                    72.000000
# 50%                                   105.000000
# 75%                                   130.000000
# max                                   448.000000
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# count                                         253.000000
# mean                                          118.735178
# std                                            70.691293
# min                                            45.000000
# 25%                                            62.000000
# 50%                                            94.000000
# 75%                                           158.000000
# max                                           434.000000
# ...

# %%
df1 = df.drop(columns = ['ICE BofA AAA US Fixed Rate CMBS Index OAS','ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS','ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS','ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS','ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS','ICE BofA AA US Fixed Rate CMBS Index OAS','ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS','ICE BofA Single-A US Fixed Rate CMBS Index OAS','ICE BofA BBB US Fixed Rate CMBS Index OAS','ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS','ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS','ICE BofA US ABS & CMBS Index OAS'])

# %%
df1.head(36)
# Out:
#     ICE BofA AAA US Fixed Rate CMBS Index  \
# 0                                 0.00423
# 1                                -0.00160
# 2                                -0.00083
# 3                                -0.01286
# 4                                -0.02129
# 5                                -0.00972
# 6                                 0.02121
# 7                                 0.00264
# 8                                 0.00384
# 9                                 0.00254
# 10                                0.00647
# 11                               -0.00681
# 12                                0.00611
# 13                               -0.00374
# 14                               -0.00916
# 15                                0.00074
# 16                                0.00941
# 17                               -0.00023
# 18                                0.00715
# 19                               -0.00023
# 20                               -0.00889
# ...

# %% [markdown]
# # Create Excess returns

# %%
# Creating Excess Returns 3,6,9,12,24,36 for AGG
df_3_Agg = df1.rolling(3,win_type='boxcar',center=True).sum().shift(-1)
df_6_Agg = df1.rolling(6,win_type='boxcar',center=True).sum().shift(-3)
df_9_Agg = df1.rolling(9,win_type='boxcar',center=True).sum().shift(-4)
df_12_Agg = df1.rolling(12,win_type='boxcar',center=True).sum().shift(-6)
df_24_Agg = df1.rolling(24,win_type='boxcar',center=True).sum().shift(-12)
df_36_Agg = df1.rolling(36,win_type='boxcar',center=True).sum().shift(-18)

# %%
df_36_Agg.head()
# Out:
#    ICE BofA AAA US Fixed Rate CMBS Index  \
# 0                                0.00516
# 1                                0.00108
# 2                               -0.00145
# 3                                0.00188
# 4                                0.01961
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# 0                                         0.04292
# 1                                         0.04047
# 2                                         0.04156
# 3                                         0.04414
# 4                                         0.04720
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# 0                                         0.01762
# 1                                         0.01437
# 2                                         0.01301
# 3                                         0.01548
# 4                                         0.02429
#
#    ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
df_12_Agg.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                             242.000000
# mean                                0.006215
# std                                 0.028515
# min                                -0.135960
# 25%                                 0.003483
# 50%                                 0.010725
# 75%                                 0.016775
# max                                 0.076980
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                      242.000000
# mean                                         0.009523
# std                                          0.011462
# min                                         -0.034060
# 25%                                          0.005290
# 50%                                          0.007565
# 75%                                          0.012672
# max                                          0.043560
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %% [markdown]
# # Calculate Min/Max

# %%
# Now lets normalize our data (for treasury)
#df_3_Agg = df_3_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_3_Agg)
df_3_Agg_Max = column_maxes
column_mins = lower_bound(df_3_Agg)
df_3_Agg_Min = column_mins
df_3_Agg_Normal = (df_3_Agg - df_3_Agg_Min) / (df_3_Agg_Max - df_3_Agg_Min)

#df_3_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_6_Agg = df_6_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_6_Agg)
df_6_Agg_Max = column_maxes
column_mins = lower_bound(df_6_Agg)
df_6_Agg_Min = column_mins
df_6_Agg_Normal = (df_6_Agg - df_6_Agg_Min) / (df_6_Agg_Max - df_6_Agg_Min)

#df_6_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_9_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_9_Agg)
df_9_Agg_Max = column_maxes
column_mins = lower_bound(df_9_Agg)
df_9_Agg_Min = column_mins
df_9_Agg_Normal = (df_9_Agg - df_9_Agg_Min) / (df_9_Agg_Max - df_9_Agg_Min)

#df_9_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_12_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_12_Agg)
df_12_Agg_Max = column_maxes
column_mins = lower_bound(df_12_Agg)
df_12_Agg_Min = column_mins
df_12_Agg_Normal = (df_12_Agg - df_12_Agg_Min) / (df_12_Agg_Max - df_12_Agg_Min)

#df_12_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_24_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_24_Agg)
df_24_Agg_Max = column_maxes
column_mins = lower_bound(df_24_Agg)
df_24_Agg_Min = column_mins
df_24_Agg_Normal = (df_24_Agg - df_24_Agg_Min) / (df_24_Agg_Max - df_24_Agg_Min)

#df_24_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_36_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_36_Agg)
df_36_Agg_Max = column_maxes
column_mins = lower_bound(df_36_Agg)
df_36_Agg_Min = column_mins
df_36_Agg_Normal = (df_36_Agg - df_36_Agg_Min) / (df_36_Agg_Max - df_36_Agg_Min)

#df_36_Agg_Normal['Date'] = df_Date

# %%
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal >= 0]
df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal <= 1]
df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal >= 0]
df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal <= 1]
df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal >= 0]
df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal <= 1]
df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal >= 0]
df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal <= 1]
df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal >= 0]
df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal <= 1]

# %%
df_3_Agg_Normal.head()
# Out:
#    ICE BofA AAA US Fixed Rate CMBS Index  \
# 0                               0.479167
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                               0.133929
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# 0                                        0.520592
# 1                                        0.346460
# 2                                        0.099350
# 3                                             NaN
# 4                                        0.024205
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# 0                                        0.510833
# 1                                        0.193333
# 2                                             NaN
# 3                                             NaN
# 4                                        0.042500
#
#    ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
df_12_Agg_Normal.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                             202.000000
# mean                                0.512275
# std                                 0.167419
# min                                 0.000306
# 25%                                 0.417599
# 50%                                 0.514129
# 75%                                 0.610753
# max                                 0.930529
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                      194.000000
# mean                                         0.483583
# std                                          0.166931
# min                                          0.011979
# 25%                                          0.378217
# 50%                                          0.443066
# 75%                                          0.566077
# max                                          0.983195
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
df.head()
# Out:
#    ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# 0                                         61
# 1                                         68
# 2                                         67
# 3                                         90
# 4                                        130
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 47
# 3                                                 58
# 4                                                 77
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 53
# 3                                                 71
# 4                                                117
#
# ...

# %%
pd.options.display.max_rows  = 280 # want to see all columns

df_36_Agg.head(280)
# Out:
#      ICE BofA AAA US Fixed Rate CMBS Index  \
# 0                                  0.00516
# 1                                  0.00108
# 2                                 -0.00145
# 3                                  0.00188
# 4                                  0.01961
# 5                                  0.03697
# 6                                  0.04219
# 7                                  0.02584
# 8                                  0.02747
# 9                                  0.02566
# 10                                 0.02607
# 11                                 0.02494
# 12                                 0.03547
# 13                                 0.02936
# 14                                 0.03409
# 15                                 0.03445
# 16                                 0.03780
# 17                                 0.02290
# 18                                 0.02813
# 19                                 0.02305
# 20                                 0.02360
# ...

# %%
df_3_Agg_Normal.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                             220.000000
# mean                                0.519733
# std                                 0.175991
# min                                 0.000893
# 25%                                 0.406473
# 50%                                 0.530060
# 75%                                 0.619494
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                      215.000000
# mean                                         0.482536
# std                                          0.167761
# min                                          0.022760
# 25%                                          0.381503
# 50%                                          0.483743
# 75%                                          0.566474
# max                                          0.976517
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
df.head()
# Out:
#    ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# 0                                         61
# 1                                         68
# 2                                         67
# 3                                         90
# 4                                        130
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 47
# 3                                                 58
# 4                                                 77
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                 54
# 1                                                 58
# 2                                                 53
# 3                                                 71
# 4                                                117
#
# ...

# %%
# Adding back spreads so we can do the selective query 
df_3_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_3_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]

#df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal > 0]
df_3_Agg_Normal["Date"] = df_copy["Date"]

df_6_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_6_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]
#df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal > 0]
df_6_Agg_Normal["Date"] = df_copy["Date"]


df_9_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_9_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]
#df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal > 0]
df_9_Agg_Normal["Date"] = df_copy["Date"]


df_12_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_12_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]
#df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal > 0]
df_12_Agg_Normal["Date"] = df_copy["Date"]


df_24_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_24_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]
#df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal > 0]
df_24_Agg_Normal["Date"] = df_copy["Date"]


df_36_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AAA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA AA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"] = df["ICE BofA Single-A US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA BBB US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"] = df["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"]
df_36_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"] = df["ICE BofA US ABS & CMBS Index OAS"]
#df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal > 0]
df_36_Agg_Normal["Date"] = df_copy["Date"]

# %%
pd.options.display.max_rows  = 280 # want to see all columns
pd.options.display.max_columns  = 280 # want to see all columns



df_3_Agg_Normal.head(280)
# Out:
#      ICE BofA AAA US Fixed Rate CMBS Index  \
# 0                                 0.479167
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                 0.133929
# 5                                 0.846131
# 6                                      NaN
# 7                                 0.694048
# 8                                 0.808036
# 9                                 0.491071
# 10                                0.597321
# 11                                0.293452
# 12                                0.223512
# 13                                0.063690
# 14                                0.455060
# 15                                0.720833
# 16                                0.911607
# 17                                0.624702
# 18                                0.366964
# 19                                0.215179
# 20                                     NaN
# ...

# %% [markdown]
# # Now we move on to our Hypothesis Testing Segment
#
# ## Our hypothesis is that spreads that are in the 80th percentile have higher excess returns than average case.

# %%
import researchpy # for t-test stuff!

# %% [markdown]
# # 3 Month Below

# %%
# Selecting 
highspread_31 = df_3_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              30.000000
# mean                                0.653115
# std                                 0.237244
# min                                 0.000893
# 25%                                 0.499479
# 50%                                 0.681548
# 75%                                 0.842262
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.652290
# std                                          0.249604
# min                                          0.046604
# 25%                                          0.573519
# 50%                                          0.671604
# 75%                                          0.848627
# max                                          0.976517
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA AAA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   30.0  0.653115  0.237244  0.043315
#  1  ICE BofA AAA US Fixed Rate CMBS Index  220.0  0.519733  0.175991  0.011865
#  2                               combined  250.0  0.535739  0.188898  0.011947
#
#     95% Conf.  Interval
#  0   0.564527  0.741703
#  1   0.496349  0.543118
#  2   0.512209  0.559269  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.1334
#  1                              Degrees of freedom =   33.4906
#  2                                               t =    2.9699
#  3                           Two side test p value =    0.0055
#  4                          Difference < 0 p value =    0.9973
#  5                          Difference > 0 p value =    0.0027
#  6                                       Cohen's d =    0.5780
# ...

# %%
# Selecting 
highspread_32 = df_3_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              32.000000
# mean                                0.604911
# std                                 0.251963
# min                                 0.000893
# 25%                                 0.475298
# 50%                                 0.636012
# 75%                                 0.768824
# max                                 0.953869
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       29.000000
# mean                                         0.633384
# std                                          0.245466
# min                                          0.046604
# 25%                                          0.567558
# 50%                                          0.646315
# 75%                                          0.839957
# max                                          0.976517
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   29.0  0.633384  0.245466
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  215.0  0.482536  0.167761
#  2                                        combined  244.0  0.500465  0.184718
#
#           SE  95% Conf.  Interval
#  0  0.045582   0.540014  0.726754
#  1  0.011441   0.459984  0.505088
#  2  0.011825   0.477172  0.523758  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.1508
#  1                              Degrees of freedom =   31.6229
#  2                                               t =    3.2098
#  3                           Two side test p value =    0.0030
#  4                          Difference < 0 p value =    0.9985
#  5                          Difference > 0 p value =    0.0015
#  6                                       Cohen's d =    0.6350
# ...

# %%
# Selecting 
highspread_33 = df_3_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              29.000000
# mean                                0.663034
# std                                 0.248568
# min                                 0.000893
# 25%                                 0.489286
# 50%                                 0.726190
# 75%                                 0.855357
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.621662
# std                                          0.253035
# min                                          0.046604
# 25%                                          0.534321
# 50%                                          0.645592
# 75%                                          0.844292
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   19.0  0.642061  0.231627
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  213.0  0.500820  0.166001
#  2                                        combined  232.0  0.512387  0.176003
#
#           SE  95% Conf.  Interval
#  0  0.053139   0.530421  0.753702
#  1  0.011374   0.478399  0.523241
#  2  0.011555   0.489620  0.535154  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.1412
#  1                              Degrees of freedom =   19.6837
#  2                                               t =    2.5991
#  3                           Two side test p value =    0.0173
#  4                          Difference < 0 p value =    0.9914
#  5                          Difference > 0 p value =    0.0086
#  6                                       Cohen's d =    0.6223
# ...

# %%
# Selecting 
highspread_34 = df_3_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              30.000000
# mean                                0.646617
# std                                 0.242474
# min                                 0.000893
# 25%                                 0.478348
# 50%                                 0.681548
# 75%                                 0.842262
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.635310
# std                                          0.257505
# min                                          0.046604
# 25%                                          0.542630
# 50%                                          0.645954
# 75%                                          0.848627
# max                                          0.976517
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   20.0  0.587109  0.231130
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  213.0  0.508659  0.162656
#  2                                        combined  233.0  0.515393  0.170400
#
#           SE  95% Conf.  Interval
#  0  0.051682   0.478937  0.695281
#  1  0.011145   0.486690  0.530629
#  2  0.011163   0.493399  0.537388  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.0784
#  1                              Degrees of freedom =   20.8042
#  2                                               t =    1.4838
#  3                           Two side test p value =    0.1529
#  4                          Difference < 0 p value =    0.9236
#  5                          Difference > 0 p value =    0.0764
#  6                                       Cohen's d =    0.3470
# ...

# %%
# Selecting 
highspread_35 = df_3_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              31.000000
# mean                                0.649482
# std                                 0.247634
# min                                 0.000893
# 25%                                 0.525000
# 50%                                 0.686905
# 75%                                 0.850744
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.615035
# std                                          0.275815
# min                                          0.046604
# 25%                                          0.436055
# 50%                                          0.645231
# 75%                                          0.849711
# max                                          0.976517
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   28.0  0.539087  0.264512
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  219.0  0.506463  0.170589
#  2                                         combined  247.0  0.510162  0.183235
#
#           SE  95% Conf.  Interval
#  0  0.049988   0.436520  0.641655
#  1  0.011527   0.483744  0.529183
#  2  0.011659   0.487198  0.533126  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.0326
#  1                              Degrees of freedom =   29.9374
#  2                                               t =    0.6359
#  3                           Two side test p value =    0.5296
#  4                          Difference < 0 p value =    0.7352
#  5                          Difference > 0 p value =    0.2648
#  6                                       Cohen's d =    0.1276
# ...

# %%
# Selecting 
highspread_36 = df_3_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              29.000000
# mean                                0.668914
# std                                 0.241189
# min                                 0.000893
# 25%                                 0.530060
# 50%                                 0.726190
# 75%                                 0.855357
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.645092
# std                                          0.235565
# min                                          0.046604
# 25%                                          0.589234
# 50%                                          0.659682
# 75%                                          0.843208
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA AA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   15.0  0.485569  0.301297  0.077795
#  1  ICE BofA AA US Fixed Rate CMBS Index  200.0  0.500603  0.162780  0.011510
#  2                              combined  215.0  0.499554  0.174911  0.011929
#
#     95% Conf.  Interval
#  0   0.318716  0.652422
#  1   0.477906  0.523301
#  2   0.476041  0.523068  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...  -0.0150
#  1                              Degrees of freedom =   14.6192
#  2                                               t =   -0.1912
#  3                           Two side test p value =    0.8510
#  4                          Difference < 0 p value =    0.4255
#  5                          Difference > 0 p value =    0.5745
#  6                                       Cohen's d =   -0.0512
# ...

# %%
# Selecting 
highspread_37 = df_3_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_37 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_37)]

# %%
normalized_df_37.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.674320
# std                                 0.242009
# min                                 0.000893
# 25%                                 0.519866
# 50%                                 0.726786
# 75%                                 0.869271
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.628703
# std                                          0.259210
# min                                          0.046604
# 25%                                          0.559249
# 50%                                          0.659682
# 75%                                          0.845737
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_37['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index   18.0  0.538817  0.331370
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  208.0  0.501052  0.176087
#  2                                        combined  226.0  0.504060  0.192166
#
#           SE  95% Conf.  Interval
#  0  0.078105   0.374031  0.703604
#  1  0.012209   0.476982  0.525123
#  2  0.012783   0.478871  0.529249  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...   0.0378
#  1                              Degrees of freedom =   17.8401
#  2                                               t =    0.4777
#  3                           Two side test p value =    0.6387
#  4                          Difference < 0 p value =    0.6807
#  5                          Difference > 0 p value =    0.3193
#  6                                       Cohen's d =    0.1174
# ...

# %%
# Selecting 
highspread_38 = df_3_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_38 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_38)]

# %%
normalized_df_38.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              29.000000
# mean                                0.660191
# std                                 0.252458
# min                                 0.000893
# 25%                                 0.489286
# 50%                                 0.726190
# 75%                                 0.855357
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.628483
# std                                          0.254988
# min                                          0.046604
# 25%                                          0.567558
# 50%                                          0.646315
# 75%                                          0.844292
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_38['ICE BofA Single-A US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index   13.0  0.486481  0.326919
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  203.0  0.497465  0.149483
#  2                                    combined  216.0  0.496804  0.164213
#
#           SE  95% Conf.  Interval
#  0  0.090671   0.288926  0.684036
#  1  0.010492   0.476778  0.518153
#  2  0.011173   0.474781  0.518828  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...  -0.0110
#  1                              Degrees of freedom =   12.3234
#  2                                               t =   -0.1203
#  3                           Two side test p value =    0.9062
#  4                          Difference < 0 p value =    0.4531
#  5                          Difference > 0 p value =    0.5469
#  6                                       Cohen's d =   -0.0344
# ...

# %%
# Selecting 
highspread_39 = df_3_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_39 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_39)]

# %%
normalized_df_39.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.669016
# std                                 0.244189
# min                                 0.000893
# 25%                                 0.519866
# 50%                                 0.721280
# 75%                                 0.869271
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.647911
# std                                          0.245647
# min                                          0.046604
# 25%                                          0.585441
# 50%                                          0.671604
# 75%                                          0.845737
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_39['ICE BofA BBB US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index   14.0  0.505752  0.325452  0.086981
#  1  ICE BofA BBB US Fixed Rate CMBS Index  205.0  0.510681  0.166604  0.011636
#  2                               combined  219.0  0.510366  0.179700  0.012143
#
#     95% Conf.  Interval
#  0   0.317842  0.693663
#  1   0.487738  0.533623
#  2   0.486433  0.534299  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...  -0.0049
#  1                              Degrees of freedom =   13.4692
#  2                                               t =   -0.0562
#  3                           Two side test p value =    0.9560
#  4                          Difference < 0 p value =    0.4780
#  5                          Difference > 0 p value =    0.5220
#  6                                       Cohen's d =   -0.0155
# ...

# %%
# Selecting 
highspread_310 = df_3_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_310 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_310)]

# %%
normalized_df_310.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.706154
# std                                 0.222511
# min                                 0.000893
# 25%                                 0.580506
# 50%                                 0.728125
# 75%                                 0.880208
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.654835
# std                                          0.235751
# min                                          0.046604
# 25%                                          0.559790
# 50%                                          0.679913
# 75%                                          0.845737
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_310['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   17.0  0.595773  0.299823
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  202.0  0.513795  0.169788
#  2                                         combined  219.0  0.520159  0.183470
#
#           SE  95% Conf.  Interval
#  0  0.072718   0.441618  0.749928
#  1  0.011946   0.490239  0.537351
#  2  0.012398   0.495724  0.544594  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.0820
#  1                              Degrees of freedom =   16.8743
#  2                                               t =    1.1124
#  3                           Two side test p value =    0.2815
#  4                          Difference < 0 p value =    0.8592
#  5                          Difference > 0 p value =    0.1408
#  6                                       Cohen's d =    0.2809
# ...

# %%
# Selecting 
highspread_311 = df_3_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_311 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_311)]

# %%
normalized_df_311.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              30.000000
# mean                                0.660476
# std                                 0.238423
# min                                 0.000893
# 25%                                 0.499479
# 50%                                 0.706399
# 75%                                 0.849182
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.633948
# std                                          0.241990
# min                                          0.046604
# 25%                                          0.557262
# 50%                                          0.645954
# 75%                                          0.843208
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_311['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_3_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   26.0  0.636263  0.199258
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  213.0  0.499649  0.154041
#  2                                        combined  239.0  0.514510  0.164694
#
#           SE  95% Conf.  Interval
#  0  0.039078   0.555781  0.716746
#  1  0.010555   0.478843  0.520454
#  2  0.010653   0.493524  0.535497  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.1366
#  1                              Degrees of freedom =   28.7625
#  2                                               t =    3.3750
#  3                           Two side test p value =    0.0021
#  4                          Difference < 0 p value =    0.9989
#  5                          Difference > 0 p value =    0.0011
#  6                                       Cohen's d =    0.7011
# ...

# %%
# Selecting 
highspread_312 = df_3_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_312 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_312)]

# %%
normalized_df_312.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              27.000000
# mean                                0.644048
# std                                 0.254225
# min                                 0.000893
# 25%                                 0.481994
# 50%                                 0.696429
# 75%                                 0.843006
# max                                 0.977679
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.626626
# std                                          0.260299
# min                                          0.046604
# 25%                                          0.559249
# 50%                                          0.645954
# 75%                                          0.845737
# max                                          0.907876
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_312['ICE BofA US ABS & CMBS Index'], df_3_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   16.0  0.645464  0.273832  0.068458
#  1  ICE BofA US ABS & CMBS Index  209.0  0.507898  0.174408  0.012064
#  2                      combined  225.0  0.517681  0.185801  0.012387
#
#     95% Conf.  Interval
#  0   0.499550  0.791379
#  1   0.484115  0.531682
#  2   0.493271  0.542090  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...   0.1376
#  1                              Degrees of freedom =   15.9450
#  2                                               t =    1.9790
#  3                           Two side test p value =    0.0654
#  4                          Difference < 0 p value =    0.9673
#  5                          Difference > 0 p value =    0.0327
#  6                                       Cohen's d =    0.5133
#  7                                       Hedge's g =    0.5116
# ...

# %% [markdown]
# # 6 Month Below

# %%
# Selecting 
highspread_61 = df_6_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_61 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_61)]

# %%
normalized_df_61.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              35.000000
# mean                                0.678393
# std                                 0.272221
# min                                 0.074211
# 25%                                 0.537723
# 50%                                 0.790931
# 75%                                 0.897871
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.700722
# std                                          0.237456
# min                                          0.244259
# 25%                                          0.606080
# 50%                                          0.780010
# 75%                                          0.876566
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_61['ICE BofA AAA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   35.0  0.678393  0.272221  0.046014
#  1  ICE BofA AAA US Fixed Rate CMBS Index  219.0  0.516294  0.180160  0.012174
#  2                               combined  254.0  0.538631  0.202634  0.012714
#
#     95% Conf.  Interval
#  0   0.584882  0.771905
#  1   0.492300  0.540288
#  2   0.513591  0.563670  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.1621
#  1                              Degrees of freedom =   38.8969
#  2                                               t =    3.4057
#  3                           Two side test p value =    0.0015
#  4                          Difference < 0 p value =    0.9992
#  5                          Difference > 0 p value =    0.0008
#  6                                       Cohen's d =    0.6200
# ...

# %%
# Selecting 
highspread_62 = df_6_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_62 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_62)]

# %%
normalized_df_62.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              36.000000
# mean                                0.633675
# std                                 0.261642
# min                                 0.074211
# 25%                                 0.495452
# 50%                                 0.651288
# 75%                                 0.847029
# max                                 0.980415
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.640125
# std                                          0.212075
# min                                          0.244259
# 25%                                          0.453549
# 50%                                          0.655010
# 75%                                          0.839770
# max                                          0.912317
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_62['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   25.0  0.640125  0.212075
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  211.0  0.485181  0.179187
#  2                                        combined  236.0  0.501595  0.188598
#
#           SE  95% Conf.  Interval
#  0  0.042415   0.552585  0.727666
#  1  0.012336   0.460863  0.509499
#  2  0.012277   0.477408  0.525781  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.1549
#  1                              Degrees of freedom =   28.2087
#  2                                               t =    3.5077
#  3                           Two side test p value =    0.0015
#  4                          Difference < 0 p value =    0.9992
#  5                          Difference > 0 p value =    0.0008
#  6                                       Cohen's d =    0.7419
# ...

# %%
# Selecting 
highspread_63 = df_6_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_63 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_63)]

# %%
normalized_df_63.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              34.000000
# mean                                0.680638
# std                                 0.277782
# min                                 0.074211
# 25%                                 0.510962
# 50%                                 0.793244
# 75%                                 0.899606
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.696122
# std                                          0.232650
# min                                          0.244259
# 25%                                          0.605297
# 50%                                          0.780010
# 75%                                          0.871347
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_63['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   19.0  0.619216  0.328041
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  206.0  0.494237  0.162387
#  2                                        combined  225.0  0.504791  0.184372
#
#           SE  95% Conf.  Interval
#  0  0.075258   0.461106  0.777327
#  1  0.011314   0.471931  0.516544
#  2  0.012291   0.480569  0.529013  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.1250
#  1                              Degrees of freedom =   18.8220
#  2                                               t =    1.6422
#  3                           Two side test p value =    0.1171
#  4                          Difference < 0 p value =    0.9414
#  5                          Difference > 0 p value =    0.0586
#  6                                       Cohen's d =    0.3937
# ...

# %%
# Selecting 
highspread_64 = df_6_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_64 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_64)]

# %%
normalized_df_64.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              35.000000
# mean                                0.675035
# std                                 0.273626
# min                                 0.074211
# 25%                                 0.514905
# 50%                                 0.790931
# 75%                                 0.897871
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.692025
# std                                          0.236489
# min                                          0.244259
# 25%                                          0.604906
# 50%                                          0.779749
# 75%                                          0.874217
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_64['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   17.0  0.583409  0.267851
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  204.0  0.502149  0.163160
#  2                                        combined  221.0  0.508400  0.173933
#
#           SE  95% Conf.  Interval
#  0  0.064964   0.445693  0.721126
#  1  0.011423   0.479625  0.524673
#  2  0.011700   0.485341  0.531458  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.0813
#  1                              Degrees of freedom =   17.0035
#  2                                               t =    1.2320
#  3                           Two side test p value =    0.2347
#  4                          Difference < 0 p value =    0.8826
#  5                          Difference > 0 p value =    0.1174
#  6                                       Cohen's d =    0.3110
# ...

# %%
# Selecting 
highspread_65 = df_6_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_65 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_65)]

# %%
normalized_df_65.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              36.000000
# mean                                0.716810
# std                                 0.226950
# min                                 0.074211
# 25%                                 0.617324
# 50%                                 0.779048
# 75%                                 0.896136
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.747695
# std                                          0.211576
# min                                          0.273486
# 25%                                          0.624478
# 50%                                          0.835334
# 75%                                          0.884264
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_65['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   29.0  0.628252  0.200070
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  216.0  0.510335  0.183313
#  2                                         combined  245.0  0.524292  0.188839
#
#           SE  95% Conf.  Interval
#  0  0.037152   0.552150  0.704355
#  1  0.012473   0.485750  0.534920
#  2  0.012064   0.500529  0.548056  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.1179
#  1                              Degrees of freedom =   34.6103
#  2                                               t =    3.0089
#  3                           Two side test p value =    0.0049
#  4                          Difference < 0 p value =    0.9976
#  5                          Difference > 0 p value =    0.0024
#  6                                       Cohen's d =    0.5951
# ...

# %%
# Selecting 
highspread_66 = df_6_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_66 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_66)]

# %%
normalized_df_66.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              34.000000
# mean                                0.679896
# std                                 0.274412
# min                                 0.074211
# 25%                                 0.530258
# 50%                                 0.793244
# 75%                                 0.891404
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.698972
# std                                          0.227547
# min                                          0.244259
# 25%                                          0.631263
# 50%                                          0.718424
# 75%                                          0.871347
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_66['ICE BofA AA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   11.0  0.700756  0.243910  0.073542
#  1  ICE BofA AA US Fixed Rate CMBS Index  192.0  0.509742  0.151869  0.010960
#  2                              combined  203.0  0.520093  0.163195  0.011454
#
#     95% Conf.  Interval
#  0   0.536895  0.864617
#  1   0.488124  0.531361
#  2   0.497508  0.542678  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...   0.1910
#  1                              Degrees of freedom =   10.4489
#  2                                               t =    2.5690
#  3                           Two side test p value =    0.0271
#  4                          Difference < 0 p value =    0.9865
#  5                          Difference > 0 p value =    0.0135
#  6                                       Cohen's d =    0.7965
# ...

# %%
# Selecting 
highspread_67 = df_6_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_67 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_67)]

# %%
normalized_df_67.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              32.000000
# mean                                0.704522
# std                                 0.254299
# min                                 0.074211
# 25%                                 0.545189
# 50%                                 0.793244
# 75%                                 0.896136
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       24.000000
# mean                                         0.717249
# std                                          0.226067
# min                                          0.244259
# 25%                                          0.624087
# 50%                                          0.789405
# 75%                                          0.876566
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_67['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index    6.0  0.671950  0.141977
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  190.0  0.514756  0.165200
#  2                                        combined  196.0  0.519568  0.166449
#
#           SE  95% Conf.  Interval
#  0  0.057962   0.522954  0.820946
#  1  0.011985   0.491115  0.538397
#  2  0.011889   0.496120  0.543016  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...   0.1572
#  1                              Degrees of freedom =    5.4364
#  2                                               t =    2.6558
#  3                           Two side test p value =    0.0415
#  4                          Difference < 0 p value =    0.9792
#  5                          Difference > 0 p value =    0.0208
#  6                                       Cohen's d =    1.1012
# ...

# %%
# Selecting 
highspread_68 = df_6_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_68 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_68)]

# %%
normalized_df_68.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              33.000000
# mean                                0.680622
# std                                 0.276765
# min                                 0.074211
# 25%                                 0.522792
# 50%                                 0.790931
# 75%                                 0.894401
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.706660
# std                                          0.232609
# min                                          0.244259
# 25%                                          0.630480
# 50%                                          0.780271
# 75%                                          0.874217
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_68['ICE BofA Single-A US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index    8.0  0.733765  0.297277
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  191.0  0.517068  0.157245
#  2                                    combined  199.0  0.525779  0.169329
#
#           SE  95% Conf.  Interval
#  0  0.105103   0.485235  0.982294
#  1  0.011378   0.494625  0.539511
#  2  0.012003   0.502108  0.549450  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...   0.2167
#  1                              Degrees of freedom =    7.1650
#  2                                               t =    2.0498
#  3                           Two side test p value =    0.0786
#  4                          Difference < 0 p value =    0.9607
#  5                          Difference > 0 p value =    0.0393
#  6                                       Cohen's d =    0.7397
# ...

# %%
# Selecting 
highspread_69 = df_6_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_69 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_69)]

# %%
normalized_df_69.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              33.000000
# mean                                0.675040
# std                                 0.276547
# min                                 0.074211
# 25%                                 0.522792
# 50%                                 0.790931
# 75%                                 0.894401
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.702589
# std                                          0.234397
# min                                          0.244259
# 25%                                          0.604906
# 50%                                          0.780271
# 75%                                          0.874217
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_69['ICE BofA BBB US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index    6.0  0.587567  0.419770  0.171370
#  1  ICE BofA BBB US Fixed Rate CMBS Index  188.0  0.505990  0.156993  0.011450
#  2                               combined  194.0  0.508513  0.169251  0.012152
#
#     95% Conf.  Interval
#  0   0.147046  1.028088
#  1   0.483403  0.528578
#  2   0.484547  0.532480  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...   0.0816
#  1                              Degrees of freedom =    5.0447
#  2                                               t =    0.4750
#  3                           Two side test p value =    0.6547
#  4                          Difference < 0 p value =    0.6727
#  5                          Difference > 0 p value =    0.3273
#  6                                       Cohen's d =    0.1970
# ...

# %%
# Selecting 
highspread_610 = df_6_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_610 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_610)]

# %%
normalized_df_610.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              33.000000
# mean                                0.727387
# std                                 0.224501
# min                                 0.074211
# 25%                                 0.629837
# 50%                                 0.795557
# 75%                                 0.894401
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.729979
# std                                          0.199155
# min                                          0.273486
# 25%                                          0.630480
# 50%                                          0.780271
# 75%                                          0.874217
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_610['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   15.0  0.720293  0.267785
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  196.0  0.519296  0.185481
#  2                                         combined  211.0  0.533585  0.198512
#
#           SE  95% Conf.  Interval
#  0  0.069142   0.571999  0.868587
#  1  0.013249   0.493167  0.545425
#  2  0.013666   0.506645  0.560525  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.2010
#  1                              Degrees of freedom =   15.0455
#  2                                               t =    2.8551
#  3                           Two side test p value =    0.0120
#  4                          Difference < 0 p value =    0.9940
#  5                          Difference > 0 p value =    0.0060
#  6                                       Cohen's d =    0.7649
# ...

# %%
# Selecting 
highspread_611 = df_6_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_611 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_611)]

# %%
normalized_df_611.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              34.000000
# mean                                0.677638
# std                                 0.262692
# min                                 0.074211
# 25%                                 0.504180
# 50%                                 0.779048
# 75%                                 0.891404
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.684379
# std                                          0.241032
# min                                          0.244259
# 25%                                          0.466467
# 50%                                          0.780010
# 75%                                          0.871347
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_611['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_6_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   20.0  0.651470  0.186247
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  201.0  0.494704  0.156722
#  2                                        combined  221.0  0.508891  0.165398
#
#           SE  95% Conf.  Interval
#  0  0.041646   0.564304  0.738636
#  1  0.011054   0.472906  0.516502
#  2  0.011126   0.486964  0.530818  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.1568
#  1                              Degrees of freedom =   21.7614
#  2                                               t =    3.6383
#  3                           Two side test p value =    0.0015
#  4                          Difference < 0 p value =    0.9993
#  5                          Difference > 0 p value =    0.0007
#  6                                       Cohen's d =    0.8531
# ...

# %%
# Selecting 
highspread_612 = df_6_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_612 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_612)]

# %%
normalized_df_612.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              31.000000
# mean                                0.674612
# std                                 0.284756
# min                                 0.074211
# 25%                                 0.510384
# 50%                                 0.795557
# 75%                                 0.897871
# max                                 0.982729
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       23.000000
# mean                                         0.704820
# std                                          0.241924
# min                                          0.244259
# 25%                                          0.617693
# 50%                                          0.780271
# 75%                                          0.878914
# max                                          0.997912
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_612['ICE BofA US ABS & CMBS Index'], df_6_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   10.0  0.651746  0.335419  0.106069
#  1  ICE BofA US ABS & CMBS Index  196.0  0.511556  0.162414  0.011601
#  2                      combined  206.0  0.518361  0.175906  0.012256
#
#     95% Conf.  Interval
#  0   0.411802  0.891690
#  1   0.488676  0.534435
#  2   0.494197  0.542525  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...   0.1402
#  1                              Degrees of freedom =    9.2165
#  2                                               t =    1.3139
#  3                           Two side test p value =    0.2207
#  4                          Difference < 0 p value =    0.8897
#  5                          Difference > 0 p value =    0.1103
#  6                                       Cohen's d =    0.4259
#  7                                       Hedge's g =    0.4244
# ...

# %% [markdown]
# # 9 Month Below

# %%
# Selecting 
highspread_91 = df_9_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_91 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_91)]

# %%
normalized_df_91.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.715636
# std                                 0.208427
# min                                 0.276618
# 25%                                 0.542962
# 50%                                 0.806644
# 75%                                 0.897839
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.741206
# std                                          0.195769
# min                                          0.260878
# 25%                                          0.629721
# 50%                                          0.809729
# 75%                                          0.907841
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_91['ICE BofA AAA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   24.0  0.715636  0.208427  0.042545
#  1  ICE BofA AAA US Fixed Rate CMBS Index  205.0  0.513739  0.177736  0.012414
#  2                               combined  229.0  0.534898  0.191018  0.012623
#
#     95% Conf.  Interval
#  0   0.627625  0.803647
#  1   0.489263  0.538214
#  2   0.510026  0.559771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.2019
#  1                              Degrees of freedom =   27.0607
#  2                                               t =    4.5555
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
#  6                                       Cohen's d =    0.9828
# ...

# %%
# Selecting 
highspread_92 = df_9_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_92 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_92)]

# %%
normalized_df_92.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              27.000000
# mean                                0.666493
# std                                 0.206361
# min                                 0.276618
# 25%                                 0.506814
# 50%                                 0.673978
# 75%                                 0.822934
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.706470
# std                                          0.168474
# min                                          0.423030
# 25%                                          0.575739
# 50%                                          0.677340
# 75%                                          0.835591
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_92['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   26.0  0.706470  0.168474
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  208.0  0.500030  0.176348
#  2                                        combined  234.0  0.522967  0.186818
#
#           SE  95% Conf.  Interval
#  0  0.033040   0.638422  0.774518
#  1  0.012228   0.475923  0.524136
#  2  0.012213   0.498906  0.547029  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.2064
#  1                              Degrees of freedom =   32.2438
#  2                                               t =    5.8597
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.2189
# ...

# %%
# Selecting 
highspread_93 = df_9_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_93 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_93)]

# %%
normalized_df_93.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              23.000000
# mean                                0.717706
# std                                 0.212198
# min                                 0.276618
# 25%                                 0.551640
# 50%                                 0.813671
# 75%                                 0.903003
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       28.000000
# mean                                         0.735793
# std                                          0.190692
# min                                          0.260878
# 25%                                          0.610940
# 50%                                          0.791461
# 75%                                          0.900452
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_93['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   18.0  0.570481  0.277202
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  202.0  0.487044  0.159756
#  2                                        combined  220.0  0.493870  0.172958
#
#           SE  95% Conf.  Interval
#  0  0.065337   0.432631  0.708330
#  1  0.011240   0.464879  0.509208
#  2  0.011661   0.470888  0.516852  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.0834
#  1                              Degrees of freedom =   18.0198
#  2                                               t =    1.2585
#  3                           Two side test p value =    0.2243
#  4                          Difference < 0 p value =    0.8879
#  5                          Difference > 0 p value =    0.1121
#  6                                       Cohen's d =    0.3096
# ...

# %%
# Selecting 
highspread_94 = df_9_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_94 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_94)]

# %%
normalized_df_94.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.710072
# std                                 0.210528
# min                                 0.276618
# 25%                                 0.542962
# 50%                                 0.806644
# 75%                                 0.897839
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       27.000000
# mean                                         0.735412
# std                                          0.194314
# min                                          0.260878
# 25%                                          0.602217
# 50%                                          0.808498
# 75%                                          0.904146
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_94['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   15.0  0.534902  0.254133
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  198.0  0.497894  0.155678
#  2                                        combined  213.0  0.500500  0.163938
#
#           SE  95% Conf.  Interval
#  0  0.065617   0.394168  0.675636
#  1  0.011064   0.476076  0.519712
#  2  0.011233   0.478358  0.522643  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.0370
#  1                              Degrees of freedom =   14.8065
#  2                                               t =    0.5562
#  3                           Two side test p value =    0.5864
#  4                          Difference < 0 p value =    0.7068
#  5                          Difference > 0 p value =    0.2932
#  6                                       Cohen's d =    0.1489
# ...

# %%
# Selecting 
highspread_95 = df_9_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_95 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_95)]

# %%
normalized_df_95.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              25.000000
# mean                                0.748705
# std                                 0.174042
# min                                 0.368399
# 25%                                 0.667589
# 50%                                 0.799617
# 75%                                 0.892675
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       25.000000
# mean                                         0.750796
# std                                          0.197553
# min                                          0.260878
# 25%                                          0.619663
# 50%                                          0.808498
# 75%                                          0.916461
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_95['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   28.0  0.641599  0.239809
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  210.0  0.515542  0.182958
#  2                                         combined  238.0  0.530372  0.194234
#
#           SE  95% Conf.  Interval
#  0  0.045320   0.548611  0.734588
#  1  0.012625   0.490653  0.540431
#  2  0.012590   0.505569  0.555175  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.1261
#  1                              Degrees of freedom =   31.3291
#  2                                               t =    2.6795
#  3                           Two side test p value =    0.0116
#  4                          Difference < 0 p value =    0.9942
#  5                          Difference > 0 p value =    0.0058
#  6                                       Cohen's d =    0.5391
# ...

# %%
# Selecting 
highspread_96 = df_9_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_96 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_96)]

# %%
normalized_df_96.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              23.000000
# mean                                0.729196
# std                                 0.213769
# min                                 0.276618
# 25%                                 0.551640
# 50%                                 0.813671
# 75%                                 0.913330
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       28.000000
# mean                                         0.734884
# std                                          0.189921
# min                                          0.260878
# 25%                                          0.624384
# 50%                                          0.791461
# 75%                                          0.900452
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_96['ICE BofA AA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   15.0  0.534101  0.312833  0.080773
#  1  ICE BofA AA US Fixed Rate CMBS Index  195.0  0.509904  0.161762  0.011584
#  2                              combined  210.0  0.511632  0.175737  0.012127
#
#     95% Conf.  Interval
#  0   0.360860  0.707342
#  1   0.487057  0.532751
#  2   0.487726  0.535539  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...   0.0242
#  1                              Degrees of freedom =   14.5814
#  2                                               t =    0.2965
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0795
# ...

# %%
# Selecting 
highspread_97 = df_9_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_97 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_97)]

# %%
normalized_df_97.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              21.000000
# mean                                0.735722
# std                                 0.211848
# min                                 0.276618
# 25%                                 0.570273
# 50%                                 0.813671
# 75%                                 0.913330
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.732711
# std                                          0.196837
# min                                          0.260878
# 25%                                          0.594212
# 50%                                          0.791461
# 75%                                          0.907841
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_97['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index   11.0  0.585626  0.332978
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  187.0  0.509109  0.151080
#  2                                        combined  198.0  0.513360  0.165794
#
#           SE  95% Conf.  Interval
#  0  0.100397   0.361929  0.809323
#  1  0.011048   0.487313  0.530904
#  2  0.011782   0.490124  0.536596  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...   0.0765
#  1                              Degrees of freedom =   10.2436
#  2                                               t =    0.7576
#  3                           Two side test p value =    0.4658
#  4                          Difference < 0 p value =    0.7671
#  5                          Difference > 0 p value =    0.2329
#  6                                       Cohen's d =    0.2350
# ...

# %%
# Selecting 
highspread_98 = df_9_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_98 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_98)]

# %%
normalized_df_98.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.723507
# std                                 0.214330
# min                                 0.276618
# 25%                                 0.547221
# 50%                                 0.806644
# 75%                                 0.908167
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       27.000000
# mean                                         0.741493
# std                                          0.191900
# min                                          0.260878
# 25%                                          0.641215
# 50%                                          0.808498
# 75%                                          0.904146
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_98['ICE BofA Single-A US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index    8.0  0.431037  0.280795
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  188.0  0.502909  0.152779
#  2                                    combined  196.0  0.499976  0.159429
#
#           SE  95% Conf.  Interval
#  0  0.099276   0.196286  0.665787
#  1  0.011143   0.480928  0.524891
#  2  0.011388   0.477517  0.522435  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...  -0.0719
#  1                              Degrees of freedom =    7.1774
#  2                                               t =   -0.7195
#  3                           Two side test p value =    0.4946
#  4                          Difference < 0 p value =    0.2473
#  5                          Difference > 0 p value =    0.7527
#  6                                       Cohen's d =   -0.2597
# ...

# %%
# Selecting 
highspread_99 = df_9_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_99 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_99)]

# %%
normalized_df_99.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.714951
# std                                 0.215099
# min                                 0.276618
# 25%                                 0.547221
# 50%                                 0.806644
# 75%                                 0.908167
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       27.000000
# mean                                         0.740140
# std                                          0.192898
# min                                          0.260878
# 25%                                          0.622947
# 50%                                          0.808498
# 75%                                          0.904146
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_99['ICE BofA BBB US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index    5.0  0.414521  0.150356  0.067241
#  1  ICE BofA BBB US Fixed Rate CMBS Index  186.0  0.503827  0.154260  0.011311
#  2                               combined  191.0  0.501489  0.154435  0.011175
#
#     95% Conf.  Interval
#  0   0.227829  0.601212
#  1   0.481512  0.526142
#  2   0.479447  0.523531  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...  -0.0893
#  1                              Degrees of freedom =    4.2295
#  2                                               t =   -1.3097
#  3                           Two side test p value =    0.2569
#  4                          Difference < 0 p value =    0.1284
#  5                          Difference > 0 p value =    0.8716
#  6                                       Cohen's d =   -0.5936
# ...

# %%
# Selecting 
highspread_910 = df_9_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_910 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_910)]

# %%
normalized_df_910.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.756350
# std                                 0.195458
# min                                 0.276618
# 25%                                 0.645070
# 50%                                 0.816227
# 75%                                 0.913330
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       27.000000
# mean                                         0.723325
# std                                          0.199044
# min                                          0.260878
# 25%                                          0.553161
# 50%                                          0.774425
# 75%                                          0.904146
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_910['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   11.0  0.693402  0.245131
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  185.0  0.520909  0.174785
#  2                                         combined  196.0  0.530590  0.183009
#
#           SE  95% Conf.  Interval
#  0  0.073910   0.528721  0.858084
#  1  0.012850   0.495556  0.546262
#  2  0.013072   0.504809  0.556371  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.1725
#  1                              Degrees of freedom =   10.6132
#  2                                               t =    2.2993
#  3                           Two side test p value =    0.0429
#  4                          Difference < 0 p value =    0.9786
#  5                          Difference > 0 p value =    0.0214
#  6                                       Cohen's d =    0.7136
# ...

# %%
# Selecting 
highspread_911 = df_9_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_911 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_911)]

# %%
normalized_df_911.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.683046
# std                                 0.232238
# min                                 0.276618
# 25%                                 0.475564
# 50%                                 0.770443
# 75%                                 0.897839
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       28.000000
# mean                                         0.728991
# std                                          0.197049
# min                                          0.323276
# 25%                                          0.582820
# 50%                                          0.791461
# 75%                                          0.900452
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_911['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_9_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   22.0  0.632037  0.207523
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  198.0  0.493983  0.154599
#  2                                        combined  220.0  0.507788  0.165386
#
#           SE  95% Conf.  Interval
#  0  0.044244   0.540026  0.724047
#  1  0.010987   0.472316  0.515650
#  2  0.011150   0.485812  0.529764  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.1381
#  1                              Degrees of freedom =   23.6602
#  2                                               t =    3.0283
#  3                           Two side test p value =    0.0059
#  4                          Difference < 0 p value =    0.9971
#  5                          Difference > 0 p value =    0.0029
#  6                                       Cohen's d =    0.6806
# ...

# %%
# Selecting 
highspread_912 = df_9_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_912 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_912)]

# %%
normalized_df_912.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              20.000000
# mean                                0.719048
# std                                 0.224649
# min                                 0.276618
# 25%                                 0.526299
# 50%                                 0.816227
# 75%                                 0.913330
# max                                 0.963373
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       26.000000
# mean                                         0.728101
# std                                          0.214717
# min                                          0.260878
# 25%                                          0.594930
# 50%                                          0.809729
# 75%                                          0.907841
# max                                          0.998563
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_912['ICE BofA US ABS & CMBS Index'], df_9_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   11.0  0.431189  0.274672  0.082817
#  1  ICE BofA US ABS & CMBS Index  194.0  0.499193  0.154747  0.011110
#  2                      combined  205.0  0.495544  0.163063  0.011389
#
#     95% Conf.  Interval
#  0   0.246661  0.615716
#  1   0.477280  0.521106
#  2   0.473089  0.517999  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...  -0.0680
#  1                              Degrees of freedom =   10.3630
#  2                                               t =   -0.8138
#  3                           Two side test p value =    0.4340
#  4                          Difference < 0 p value =    0.2170
#  5                          Difference > 0 p value =    0.7830
#  6                                       Cohen's d =   -0.2522
#  7                                       Hedge's g =   -0.2513
# ...

# %% [markdown]
# # 12 Month Below

# %%
# Selecting 
highspread_121 = df_12_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_121 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_121)]

# %%
normalized_df_121.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.654188
# std                                 0.199433
# min                                 0.000306
# 25%                                 0.578827
# 50%                                 0.697973
# 75%                                 0.788344
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       20.000000
# mean                                         0.749687
# std                                          0.143220
# min                                          0.465417
# 25%                                          0.624323
# 50%                                          0.781705
# 75%                                          0.853327
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_121['ICE BofA AAA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   26.0  0.654188  0.199433  0.039112
#  1  ICE BofA AAA US Fixed Rate CMBS Index  202.0  0.512275  0.167419  0.011780
#  2                               combined  228.0  0.528458  0.176756  0.011706
#
#     95% Conf.  Interval
#  0   0.573635  0.734740
#  1   0.489047  0.535502
#  2   0.505391  0.551524  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.1419
#  1                              Degrees of freedom =   29.7106
#  2                                               t =    3.4742
#  3                           Two side test p value =    0.0016
#  4                          Difference < 0 p value =    0.9992
#  5                          Difference > 0 p value =    0.0008
#  6                                       Cohen's d =    0.7239
# ...

# %%
# Selecting 
highspread_122 = df_12_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_122 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_122)]

# %%
normalized_df_122.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              29.000000
# mean                                0.639038
# std                                 0.193305
# min                                 0.000306
# 25%                                 0.574502
# 50%                                 0.692613
# 75%                                 0.795115
# max                                 0.851538
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.707979
# std                                          0.148230
# min                                          0.465417
# 25%                                          0.595792
# 50%                                          0.627963
# 75%                                          0.821326
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_122['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   21.0  0.707979  0.148230
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  194.0  0.483583  0.166931
#  2                                        combined  215.0  0.505500  0.177887
#
#           SE  95% Conf.  Interval
#  0  0.032346   0.640505  0.775452
#  1  0.011985   0.459944  0.507221
#  2  0.012132   0.481587  0.529413  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.2244
#  1                              Degrees of freedom =   25.8179
#  2                                               t =    6.5051
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.4944
# ...

# %%
# Selecting 
highspread_123 = df_12_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_123 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_123)]

# %%
normalized_df_123.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              25.000000
# mean                                0.654351
# std                                 0.202174
# min                                 0.000306
# 25%                                 0.606663
# 50%                                 0.697127
# 75%                                 0.795115
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       22.000000
# mean                                         0.735758
# std                                          0.143496
# min                                          0.465417
# 25%                                          0.601973
# 50%                                          0.775779
# 75%                                          0.839612
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_123['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   18.0  0.640465  0.263247
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  195.0  0.497123  0.154696
#  2                                        combined  213.0  0.509236  0.170449
#
#           SE  95% Conf.  Interval
#  0  0.062048   0.509556  0.771375
#  1  0.011078   0.475274  0.518971
#  2  0.011679   0.486214  0.532258  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.1433
#  1                              Degrees of freedom =   18.0994
#  2                                               t =    2.2742
#  3                           Two side test p value =    0.0354
#  4                          Difference < 0 p value =    0.9823
#  5                          Difference > 0 p value =    0.0177
#  6                                       Cohen's d =    0.5602
# ...

# %%
# Selecting 
highspread_124 = df_12_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_124 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_124)]

# %%
normalized_df_124.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.655888
# std                                 0.198952
# min                                 0.000306
# 25%                                 0.589877
# 50%                                 0.697973
# 75%                                 0.788344
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.742310
# std                                          0.143628
# min                                          0.465417
# 25%                                          0.613402
# 50%                                          0.780689
# 75%                                          0.845708
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_124['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   20.0  0.611650  0.157224
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  195.0  0.497453  0.155002
#  2                                        combined  215.0  0.508076  0.158368
#
#           SE  95% Conf.  Interval
#  0  0.035156   0.538067  0.685233
#  1  0.011100   0.475561  0.519345
#  2  0.010801   0.486787  0.529365  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.1142
#  1                              Degrees of freedom =   22.9546
#  2                                               t =    3.0975
#  3                           Two side test p value =    0.0051
#  4                          Difference < 0 p value =    0.9975
#  5                          Difference > 0 p value =    0.0025
#  6                                       Cohen's d =    0.7273
# ...

# %%
# Selecting 
highspread_125 = df_12_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_125 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_125)]

# %%
normalized_df_125.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              27.000000
# mean                                0.615001
# std                                 0.194352
# min                                 0.000306
# 25%                                 0.496074
# 50%                                 0.655374
# 75%                                 0.750353
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.705979
# std                                          0.144802
# min                                          0.452887
# 25%                                          0.594776
# 50%                                          0.735650
# 75%                                          0.821326
# max                                          0.914790
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_125['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   29.0  0.575141  0.234575
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  207.0  0.515031  0.171333
#  2                                         combined  236.0  0.522417  0.180775
#
#           SE  95% Conf.  Interval
#  0  0.043560   0.485913  0.664369
#  1  0.011908   0.491552  0.538509
#  2  0.011767   0.499234  0.545600  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.0601
#  1                              Degrees of freedom =   32.3172
#  2                                               t =    1.3311
#  3                           Two side test p value =    0.1925
#  4                          Difference < 0 p value =    0.9038
#  5                          Difference > 0 p value =    0.0962
#  6                                       Cohen's d =    0.2639
# ...

# %%
# Selecting 
highspread_126 = df_12_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_126 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_126)]

# %%
normalized_df_126.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              25.000000
# mean                                0.670338
# std                                 0.206801
# min                                 0.000306
# 25%                                 0.625658
# 50%                                 0.732485
# 75%                                 0.805459
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       22.000000
# mean                                         0.739129
# std                                          0.139671
# min                                          0.465417
# 25%                                          0.613740
# 50%                                          0.775779
# 75%                                          0.839612
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_126['ICE BofA AA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   18.0  0.630133  0.196438  0.046301
#  1  ICE BofA AA US Fixed Rate CMBS Index  189.0  0.507134  0.159028  0.011568
#  2                              combined  207.0  0.517829  0.165745  0.011520
#
#     95% Conf.  Interval
#  0   0.532447  0.727820
#  1   0.484315  0.529953
#  2   0.495117  0.540542  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...   0.1230
#  1                              Degrees of freedom =   19.1817
#  2                                               t =    2.5773
#  3                           Two side test p value =    0.0184
#  4                          Difference < 0 p value =    0.9908
#  5                          Difference > 0 p value =    0.0092
#  6                                       Cohen's d =    0.6357
# ...

# %%
# Selecting 
highspread_127 = df_12_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_127 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_127)]

# %%
normalized_df_127.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              23.000000
# mean                                0.647966
# std                                 0.209625
# min                                 0.000306
# 25%                                 0.592745
# 50%                                 0.692613
# 75%                                 0.796807
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.728619
# std                                          0.136161
# min                                          0.465417
# 25%                                          0.605613
# 50%                                          0.770869
# 75%                                          0.821326
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_127['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index   18.0  0.438041  0.333912
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  195.0  0.502586  0.165480
#  2                                        combined  213.0  0.497132  0.185265
#
#           SE  95% Conf.  Interval
#  0  0.078704   0.271991  0.604091
#  1  0.011850   0.479214  0.525958
#  2  0.012694   0.472109  0.522155  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...  -0.0645
#  1                              Degrees of freedom =   17.7787
#  2                                               t =   -0.8110
#  3                           Two side test p value =    0.4281
#  4                          Difference < 0 p value =    0.2141
#  5                          Difference > 0 p value =    0.7859
#  6                                       Cohen's d =   -0.1998
# ...

# %%
# Selecting 
highspread_128 = df_12_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_128 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_128)]

# %%
normalized_df_128.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.659410
# std                                 0.209046
# min                                 0.000306
# 25%                                 0.599704
# 50%                                 0.697973
# 75%                                 0.800240
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.745164
# std                                          0.140136
# min                                          0.465417
# 25%                                          0.613402
# 50%                                          0.780689
# 75%                                          0.845708
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_128['ICE BofA Single-A US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index   17.0  0.431577  0.271067
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  194.0  0.496539  0.162149
#  2                                    combined  211.0  0.491305  0.173425
#
#           SE  95% Conf.  Interval
#  0  0.065744   0.292207  0.570947
#  1  0.011642   0.473578  0.519500
#  2  0.011939   0.467769  0.514841  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...  -0.0650
#  1                              Degrees of freedom =   17.0177
#  2                                               t =   -0.9730
#  3                           Two side test p value =    0.3442
#  4                          Difference < 0 p value =    0.1721
#  5                          Difference > 0 p value =    0.8279
#  6                                       Cohen's d =   -0.2461
# ...

# %%
# Selecting 
highspread_129 = df_12_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_129 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_129)]

# %%
normalized_df_129.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.645649
# std                                 0.207358
# min                                 0.000306
# 25%                                 0.562089
# 50%                                 0.694870
# 75%                                 0.795961
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       21.000000
# mean                                         0.739133
# std                                          0.148894
# min                                          0.465417
# 25%                                          0.613402
# 50%                                          0.780689
# 75%                                          0.845708
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_129['ICE BofA BBB US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index   12.0  0.450497  0.315751  0.091150
#  1  ICE BofA BBB US Fixed Rate CMBS Index  189.0  0.501978  0.169589  0.012336
#  2                               combined  201.0  0.498904  0.180742  0.012749
#
#     95% Conf.  Interval
#  0   0.249879  0.651116
#  1   0.477643  0.526312
#  2   0.473765  0.524043  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...  -0.0515
#  1                              Degrees of freedom =   11.4064
#  2                                               t =   -0.5597
#  3                           Two side test p value =    0.5865
#  4                          Difference < 0 p value =    0.2933
#  5                          Difference > 0 p value =    0.7067
#  6                                       Cohen's d =   -0.1666
# ...

# %%
# Selecting 
highspread_1210 = df_12_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_1210 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_1210)]

# %%
normalized_df_1210.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.642178
# std                                 0.206763
# min                                 0.000306
# 25%                                 0.570317
# 50%                                 0.681799
# 75%                                 0.797701
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       23.000000
# mean                                         0.713241
# std                                          0.139595
# min                                          0.465417
# 25%                                          0.596978
# 50%                                          0.735650
# 75%                                          0.815230
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_1210['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   15.0  0.659302  0.299094
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  192.0  0.512746  0.178698
#  2                                         combined  207.0  0.523366  0.192713
#
#           SE  95% Conf.  Interval
#  0  0.077226   0.493669  0.824935
#  1  0.012896   0.487308  0.538184
#  2  0.013394   0.496958  0.549774  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.1466
#  1                              Degrees of freedom =   14.7909
#  2                                               t =    1.8718
#  3                           Two side test p value =    0.0811
#  4                          Difference < 0 p value =    0.9594
#  5                          Difference > 0 p value =    0.0406
#  6                                       Cohen's d =    0.5018
# ...

# %%
# Selecting 
highspread_1211 = df_12_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_1211 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_1211)]

# %%
normalized_df_1211.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.628031
# std                                 0.208402
# min                                 0.000306
# 25%                                 0.502421
# 50%                                 0.681799
# 75%                                 0.788344
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       23.000000
# mean                                         0.708103
# std                                          0.175286
# min                                          0.378725
# 25%                                          0.590374
# 50%                                          0.770869
# 75%                                          0.833517
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_1211['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_12_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   22.0  0.675156  0.164960
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  192.0  0.502180  0.154136
#  2                                        combined  214.0  0.519963  0.163584
#
#           SE  95% Conf.  Interval
#  0  0.035170   0.602017  0.748295
#  1  0.011124   0.480239  0.524122
#  2  0.011182   0.497921  0.542005  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.1730
#  1                              Degrees of freedom =   25.3839
#  2                                               t =    4.6894
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.0555
# ...

# %%
# Selecting 
highspread_1212 = df_12_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_1212 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_1212)]

# %%
normalized_df_1212.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.653502
# std                                 0.214717
# min                                 0.000306
# 25%                                 0.590535
# 50%                                 0.697973
# 75%                                 0.797654
# max                                 0.898557
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       20.000000
# mean                                         0.723561
# std                                          0.212598
# min                                          0.026541
# 25%                                          0.624323
# 50%                                          0.781705
# 75%                                          0.853327
# max                                          0.944929
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_1212['ICE BofA US ABS & CMBS Index'], df_12_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   16.0  0.584292  0.171190  0.042798
#  1  ICE BofA US ABS & CMBS Index  196.0  0.512648  0.145094  0.010364
#  2                      combined  212.0  0.518055  0.147983  0.010164
#
#     95% Conf.  Interval
#  0   0.493071  0.675513
#  1   0.492209  0.533088
#  2   0.498020  0.538090  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...   0.0716
#  1                              Degrees of freedom =   16.8064
#  2                                               t =    1.6270
#  3                           Two side test p value =    0.1223
#  4                          Difference < 0 p value =    0.9388
#  5                          Difference > 0 p value =    0.0612
#  6                                       Cohen's d =    0.4230
#  7                                       Hedge's g =    0.4215
# ...

# %% [markdown]
# # 24 Month Below

# %%
# Selecting 
highspread_241 = df_24_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_241 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_241)]

# %%
normalized_df_241.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.732665
# std                                 0.229616
# min                                 0.134306
# 25%                                 0.689979
# 50%                                 0.795004
# 75%                                 0.898906
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       48.000000
# mean                                         0.733340
# std                                          0.116066
# min                                          0.446733
# 25%                                          0.636373
# 50%                                          0.732600
# 75%                                          0.811530
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_241['ICE BofA AAA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   28.0  0.732665  0.229616  0.043393
#  1  ICE BofA AAA US Fixed Rate CMBS Index  183.0  0.522046  0.179984  0.013305
#  2                               combined  211.0  0.549995  0.199959  0.013766
#
#     95% Conf.  Interval
#  0   0.643630  0.821701
#  1   0.495794  0.548298
#  2   0.522859  0.577132  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.2106
#  1                              Degrees of freedom =   32.2728
#  2                                               t =    4.6405
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    0.9417
# ...

# %%
# Selecting 
highspread_242 = df_24_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_242 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_242)]

# %%
normalized_df_242.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              30.000000
# mean                                0.710847
# std                                 0.225750
# min                                 0.134306
# 25%                                 0.590473
# 50%                                 0.765868
# 75%                                 0.896595
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       49.000000
# mean                                         0.723258
# std                                          0.134585
# min                                          0.446733
# 25%                                          0.657490
# 50%                                          0.734732
# 75%                                          0.809842
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_242['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   49.0  0.723258  0.134585
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  225.0  0.481609  0.185551
#  2                                        combined  274.0  0.524824  0.200102
#
#           SE  95% Conf.  Interval
#  0  0.019226   0.684600  0.761915
#  1  0.012370   0.457232  0.505986
#  2  0.012089   0.501025  0.548622  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.2416
#  1                              Degrees of freedom =   92.5651
#  2                                               t =   10.5699
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.6663
# ...

# %%
# Selecting 
highspread_243 = df_24_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_243 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_243)]

# %%
normalized_df_243.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              27.000000
# mean                                0.727312
# std                                 0.236084
# min                                 0.134306
# 25%                                 0.598944
# 50%                                 0.798534
# 75%                                 0.901088
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.722464
# std                                          0.127771
# min                                          0.439270
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_243['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   16.0  0.706232  0.237486
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  175.0  0.477736  0.157943
#  2                                        combined  191.0  0.496877  0.176992
#
#           SE  95% Conf.  Interval
#  0  0.059371   0.579685  0.832779
#  1  0.011939   0.454172  0.501301
#  2  0.012807   0.471616  0.522139  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.2285
#  1                              Degrees of freedom =   16.2354
#  2                                               t =    3.7730
#  3                           Two side test p value =    0.0016
#  4                          Difference < 0 p value =    0.9992
#  5                          Difference > 0 p value =    0.0008
#  6                                       Cohen's d =    0.9854
# ...

# %%
# Selecting 
highspread_244 = df_24_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_244 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_244)]

# %%
normalized_df_244.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.727550
# std                                 0.231726
# min                                 0.134306
# 25%                                 0.614475
# 50%                                 0.795004
# 75%                                 0.898906
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       48.000000
# mean                                         0.727493
# std                                          0.123582
# min                                          0.439270
# 25%                                          0.628673
# 50%                                          0.732600
# 75%                                          0.811530
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_244['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   20.0  0.747962  0.212928
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  176.0  0.500873  0.170320
#  2                                        combined  196.0  0.526086  0.189932
#
#           SE  95% Conf.  Interval
#  0  0.047612   0.648309  0.847616
#  1  0.012838   0.475535  0.526211
#  2  0.013567   0.499330  0.552843  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.2471
#  1                              Degrees of freedom =   21.8508
#  2                                               t =    5.0107
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.1824
# ...

# %%
# Selecting 
highspread_245 = df_24_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_245 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_245)]

# %%
normalized_df_245.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              31.000000
# mean                                0.692352
# std                                 0.217340
# min                                 0.134306
# 25%                                 0.567819
# 50%                                 0.741160
# 75%                                 0.844227
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       49.000000
# mean                                         0.708596
# std                                          0.135177
# min                                          0.388091
# 25%                                          0.608799
# 50%                                          0.702627
# 75%                                          0.809842
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_245['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   33.0  0.641530  0.227989
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  188.0  0.526604  0.181327
#  2                                         combined  221.0  0.543765  0.192856
#
#           SE  95% Conf.  Interval
#  0  0.039688   0.560688  0.722371
#  1  0.013225   0.500516  0.552693
#  2  0.012973   0.518198  0.569332  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.1149
#  1                              Degrees of freedom =   39.4174
#  2                                               t =    2.7472
#  3                           Two side test p value =    0.0090
#  4                          Difference < 0 p value =    0.9955
#  5                          Difference > 0 p value =    0.0045
#  6                                       Cohen's d =    0.5185
# ...

# %%
# Selecting 
highspread_246 = df_24_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_246 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_246)]

# %%
normalized_df_246.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              27.000000
# mean                                0.741954
# std                                 0.231985
# min                                 0.134306
# 25%                                 0.717735
# 50%                                 0.798534
# 75%                                 0.901088
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.720128
# std                                          0.130848
# min                                          0.446733
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_246['ICE BofA AA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   21.0  0.785867  0.250413  0.054645
#  1  ICE BofA AA US Fixed Rate CMBS Index  171.0  0.520107  0.168716  0.012902
#  2                              combined  192.0  0.549175  0.197022  0.014219
#
#     95% Conf.  Interval
#  0   0.671880  0.899853
#  1   0.494638  0.545576
#  2   0.521129  0.577221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...   0.2658
#  1                              Degrees of freedom =   22.2839
#  2                                               t =    4.7333
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.0945
# ...

# %%
# Selecting 
highspread_247 = df_24_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_247 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_247)]

# %%
normalized_df_247.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              25.000000
# mean                                0.723457
# std                                 0.239364
# min                                 0.134306
# 25%                                 0.630006
# 50%                                 0.791474
# 75%                                 0.896724
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.706569
# std                                          0.145642
# min                                          0.376599
# 25%                                          0.601513
# 50%                                          0.723122
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_247['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index   15.0  0.719711  0.221428
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  171.0  0.513175  0.158551
#  2                                        combined  186.0  0.529832  0.173177
#
#           SE  95% Conf.  Interval
#  0  0.057172   0.597088  0.842334
#  1  0.012125   0.489241  0.537110
#  2  0.012698   0.504780  0.554883  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...   0.2065
#  1                              Degrees of freedom =   15.2851
#  2                                               t =    3.5339
#  3                           Two side test p value =    0.0029
#  4                          Difference < 0 p value =    0.9985
#  5                          Difference > 0 p value =    0.0015
#  6                                       Cohen's d =    0.9516
# ...

# %%
# Selecting 
highspread_248 = df_24_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_248 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_248)]

# %%
normalized_df_248.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.742053
# std                                 0.236328
# min                                 0.134306
# 25%                                 0.730667
# 50%                                 0.814834
# 75%                                 0.903270
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.719039
# std                                          0.133984
# min                                          0.376599
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_248['ICE BofA Single-A US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index   12.0  0.740483  0.279051
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  165.0  0.506665  0.160561
#  2                                    combined  177.0  0.522517  0.179900
#
#           SE  95% Conf.  Interval
#  0  0.080555   0.563183  0.917784
#  1  0.012500   0.481984  0.531346
#  2  0.013522   0.495831  0.549204  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...   0.2338
#  1                              Degrees of freedom =   11.5356
#  2                                               t =    2.8683
#  3                           Two side test p value =    0.0146
#  4                          Difference < 0 p value =    0.9927
#  5                          Difference > 0 p value =    0.0073
#  6                                       Cohen's d =    0.8576
# ...

# %%
# Selecting 
highspread_249 = df_24_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_249 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_249)]

# %%
normalized_df_249.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.735640
# std                                 0.237219
# min                                 0.134306
# 25%                                 0.654297
# 50%                                 0.814834
# 75%                                 0.903270
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.720261
# std                                          0.130993
# min                                          0.437256
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_249['ICE BofA BBB US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index   13.0  0.709829  0.217828  0.060415
#  1  ICE BofA BBB US Fixed Rate CMBS Index  167.0  0.494074  0.167397  0.012954
#  2                               combined  180.0  0.509656  0.179734  0.013397
#
#     95% Conf.  Interval
#  0   0.578197  0.841461
#  1   0.468499  0.519649
#  2   0.483221  0.536091  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...   0.2158
#  1                              Degrees of freedom =   13.1267
#  2                                               t =    3.4919
#  3                           Two side test p value =    0.0039
#  4                          Difference < 0 p value =    0.9980
#  5                          Difference > 0 p value =    0.0020
#  6                                       Cohen's d =    1.0055
# ...

# %%
# Selecting 
highspread_2410 = df_24_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_2410 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_2410)]

# %%
normalized_df_2410.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.712053
# std                                 0.233896
# min                                 0.134306
# 25%                                 0.585243
# 50%                                 0.781398
# 75%                                 0.884466
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.702423
# std                                          0.146647
# min                                          0.437256
# 25%                                          0.594109
# 50%                                          0.702627
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_2410['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   26.0  0.784778  0.174789
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  183.0  0.498329  0.178385
#  2                                         combined  209.0  0.533964  0.201237
#
#           SE  95% Conf.  Interval
#  0  0.034279   0.714179  0.855377
#  1  0.013187   0.472311  0.524348
#  2  0.013920   0.506522  0.561406  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.2864
#  1                              Degrees of freedom =   32.8478
#  2                                               t =    7.7992
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.6346
# ...

# %%
# Selecting 
highspread_2411 = df_24_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_2411 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_2411)]

# %%
normalized_df_2411.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              28.000000
# mean                                0.720174
# std                                 0.235308
# min                                 0.134306
# 25%                                 0.603501
# 50%                                 0.795004
# 75%                                 0.898906
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.716743
# std                                          0.136572
# min                                          0.423513
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_2411['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_24_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   17.0  0.716083  0.050711
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  172.0  0.477699  0.143922
#  2                                        combined  189.0  0.499141  0.154064
#
#           SE  95% Conf.  Interval
#  0  0.012299   0.690010  0.742156
#  1  0.010974   0.456037  0.499361
#  2  0.011207   0.477034  0.521248  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.2384
#  1                              Degrees of freedom =   48.7268
#  2                                               t =   14.4622
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    3.6769
# ...

# %%
# Selecting 
highspread_2412 = df_24_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_2412 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_2412)]

# %%
normalized_df_2412.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.740652
# std                                 0.246157
# min                                 0.134306
# 25%                                 0.713371
# 50%                                 0.835178
# 75%                                 0.907313
# max                                 0.988111
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.716609
# std                                          0.138218
# min                                          0.376599
# 25%                                          0.622838
# 50%                                          0.730467
# 75%                                          0.813218
# max                                          0.966103
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_2412['ICE BofA US ABS & CMBS Index'], df_24_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   17.0  0.817779  0.211862  0.051384
#  1  ICE BofA US ABS & CMBS Index  173.0  0.521784  0.168760  0.012831
#  2                      combined  190.0  0.548267  0.192077  0.013935
#
#     95% Conf.  Interval
#  0   0.708849  0.926708
#  1   0.496458  0.547109
#  2   0.520780  0.575755  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...   0.2960
#  1                              Degrees of freedom =   18.0509
#  2                                               t =    5.5889
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.4205
#  7                                       Hedge's g =    1.4149
# ...

# %% [markdown]
# # 36 Month Below

# %%
# Selecting 
highspread_361 = df_36_Agg_Normal["ICE BofA AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_361 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index OAS'] > highspread_361)]

# %%
normalized_df_361.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.773839
# std                                 0.172909
# min                                 0.373756
# 25%                                 0.691436
# 50%                                 0.775953
# 75%                                 0.927087
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       46.000000
# mean                                         0.711447
# std                                          0.118688
# min                                          0.501478
# 25%                                          0.639868
# 50%                                          0.704393
# 75%                                          0.780694
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_361['ICE BofA AAA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA AAA US Fixed Rate CMBS Index   24.0  0.773839  0.172909  0.035295
#  1  ICE BofA AAA US Fixed Rate CMBS Index  156.0  0.537463  0.169661  0.013584
#  2                               combined  180.0  0.568980  0.187775  0.013996
#
#     95% Conf.  Interval
#  0   0.700826  0.846852
#  1   0.510630  0.564296
#  2   0.541362  0.596598  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AAA US Fixed Rate CMBS In...   0.2364
#  1                              Degrees of freedom =   30.2198
#  2                                               t =    6.2503
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.3705
# ...

# %%
# Selecting 
highspread_362 = df_36_Agg_Normal["ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_362 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_362)]

# %%
normalized_df_362.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.729100
# std                                 0.191873
# min                                 0.373756
# 25%                                 0.549129
# 50%                                 0.705573
# 75%                                 0.923447
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.696548
# std                                          0.138219
# min                                          0.440653
# 25%                                          0.632919
# 50%                                          0.701550
# 75%                                          0.780604
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_362['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   47.0  0.696548  0.138219
#  1  ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  215.0  0.474149  0.179738
#  2                                        combined  262.0  0.514045  0.192781
#
#           SE  95% Conf.  Interval
#  0  0.020161   0.655965  0.737131
#  1  0.012258   0.449987  0.498311
#  2  0.011910   0.490593  0.537497  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year AAA US Fixed Rat...   0.2224
#  1                              Degrees of freedom =   83.8323
#  2                                               t =    9.4256
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.5177
# ...

# %%
# Selecting 
highspread_363 = df_36_Agg_Normal["ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_363 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_363)]

# %%
normalized_df_363.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              23.000000
# mean                                0.766110
# std                                 0.186259
# min                                 0.373756
# 25%                                 0.637013
# 50%                                 0.800039
# 75%                                 0.930121
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.706068
# std                                          0.129007
# min                                          0.446519
# 25%                                          0.637928
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_363['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   12.0  0.655413  0.179438
#  1  ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  156.0  0.468830  0.156035
#  2                                        combined  168.0  0.482158  0.164442
#
#           SE  95% Conf.  Interval
#  0  0.051799   0.541404  0.769423
#  1  0.012493   0.444152  0.493508
#  2  0.012687   0.457110  0.507205  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year AAA US Fixed Rat...   0.1866
#  1                              Degrees of freedom =   12.3139
#  2                                               t =    3.5016
#  3                           Two side test p value =    0.0042
#  4                          Difference < 0 p value =    0.9979
#  5                          Difference > 0 p value =    0.0021
#  6                                       Cohen's d =    1.0490
# ...

# %%
# Selecting 
highspread_364 = df_36_Agg_Normal["ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_364 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_364)]

# %%
normalized_df_364.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.767838
# std                                 0.179815
# min                                 0.373756
# 25%                                 0.691436
# 50%                                 0.775953
# 75%                                 0.927087
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       46.000000
# mean                                         0.707400
# std                                          0.124467
# min                                          0.446519
# 25%                                          0.639868
# 50%                                          0.704393
# 75%                                          0.780694
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_364['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   15.0  0.747328  0.231089
#  1  ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index  148.0  0.509984  0.159469
#  2                                        combined  163.0  0.531826  0.180074
#
#           SE  95% Conf.  Interval
#  0  0.059667   0.619355  0.875301
#  1  0.013108   0.484079  0.535890
#  2  0.014104   0.503974  0.559678  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year AAA US Fixed Rat...   0.2373
#  1                              Degrees of freedom =   15.3806
#  2                                               t =    3.8851
#  3                           Two side test p value =    0.0014
#  4                          Difference < 0 p value =    0.9993
#  5                          Difference > 0 p value =    0.0007
#  6                                       Cohen's d =    1.0527
# ...

# %%
# Selecting 
highspread_365 = df_36_Agg_Normal["ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_365 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index OAS'] > highspread_365)]

# %%
normalized_df_365.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              26.000000
# mean                                0.707295
# std                                 0.165656
# min                                 0.373756
# 25%                                 0.611167
# 50%                                 0.698838
# 75%                                 0.809686
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       47.000000
# mean                                         0.686205
# std                                          0.139686
# min                                          0.398238
# 25%                                          0.578862
# 50%                                          0.692345
# 75%                                          0.780604
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_365['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index   36.0  0.673897  0.209649
#  1  ICE BofA 7-10 Year AAA US Fixed Rate CMBS Index  171.0  0.553762  0.164504
#  2                                         combined  207.0  0.574655  0.178560
#
#           SE  95% Conf.  Interval
#  0  0.034942   0.602962  0.744832
#  1  0.012580   0.528929  0.578595
#  2  0.012411   0.550187  0.599124  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AAA US Fixed Ra...   0.1201
#  1                              Degrees of freedom =   44.5075
#  2                                               t =    3.2349
#  3                           Two side test p value =    0.0023
#  4                          Difference < 0 p value =    0.9989
#  5                          Difference > 0 p value =    0.0011
#  6                                       Cohen's d =    0.5932
# ...

# %%
# Selecting 
highspread_366 = df_36_Agg_Normal["ICE BofA AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_366 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index OAS'] > highspread_366)]

# %%
normalized_df_366.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              23.000000
# mean                                0.772283
# std                                 0.180433
# min                                 0.373756
# 25%                                 0.672506
# 50%                                 0.800039
# 75%                                 0.930121
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.700788
# std                                          0.135824
# min                                          0.440653
# 25%                                          0.633145
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_366['ICE BofA AA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA AA US Fixed Rate CMBS Index   19.0  0.752613  0.243368  0.055833
#  1  ICE BofA AA US Fixed Rate CMBS Index  149.0  0.533564  0.161147  0.013202
#  2                              combined  168.0  0.558337  0.185039  0.014276
#
#     95% Conf.  Interval
#  0   0.635314  0.869913
#  1   0.507475  0.559652
#  2   0.530152  0.586522  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA AA US Fixed Rate CMBS Ind...   0.2190
#  1                              Degrees of freedom =   20.0614
#  2                                               t =    3.8181
#  3                           Two side test p value =    0.0011
#  4                          Difference < 0 p value =    0.9995
#  5                          Difference > 0 p value =    0.0005
#  6                                       Cohen's d =    0.9301
# ...

# %%
# Selecting 
highspread_367 = df_36_Agg_Normal["ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_367 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index OAS'] > highspread_367)]

# %%
normalized_df_367.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              21.000000
# mean                                0.753865
# std                                 0.186188
# min                                 0.373756
# 25%                                 0.617780
# 50%                                 0.751866
# 75%                                 0.924054
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.691810
# std                                          0.143218
# min                                          0.419536
# 25%                                          0.567086
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_367['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 7-10 Year AA US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index   13.0  0.739313  0.241579
#  1  ICE BofA 7-10 Year AA US Fixed Rate CMBS Index  146.0  0.533661  0.153249
#  2                                        combined  159.0  0.550475  0.170823
#
#           SE  95% Conf.  Interval
#  0  0.067002   0.593328  0.885298
#  1  0.012683   0.508594  0.558729
#  2  0.013547   0.523719  0.577232  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year AA US Fixed Rat...   0.2057
#  1                              Degrees of freedom =   12.8740
#  2                                               t =    3.0158
#  3                           Two side test p value =    0.0100
#  4                          Difference < 0 p value =    0.9950
#  5                          Difference > 0 p value =    0.0050
#  6                                       Cohen's d =    0.8729
# ...

# %%
# Selecting 
highspread_368 = df_36_Agg_Normal["ICE BofA Single-A US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_368 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index OAS'] > highspread_368)]

# %%
normalized_df_368.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.780354
# std                                 0.178923
# min                                 0.373756
# 25%                                 0.679666
# 50%                                 0.806471
# 75%                                 0.933154
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.700824
# std                                          0.135888
# min                                          0.419536
# 25%                                          0.633145
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_368['ICE BofA Single-A US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA Single-A US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                     Variable      N      Mean        SD  \
#  0  ICE BofA Single-A US Fixed Rate CMBS Index   17.0  0.762361  0.264226
#  1  ICE BofA Single-A US Fixed Rate CMBS Index  148.0  0.532209  0.158695
#  2                                    combined  165.0  0.555921  0.185229
#
#           SE  95% Conf.  Interval
#  0  0.064084   0.626509  0.898214
#  1  0.013045   0.506430  0.557988
#  2  0.014420   0.527449  0.584394  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA Single-A US Fixed Rate CM...   0.2302
#  1                              Degrees of freedom =   17.3501
#  2                                               t =    3.5192
#  3                           Two side test p value =    0.0026
#  4                          Difference < 0 p value =    0.9987
#  5                          Difference > 0 p value =    0.0013
#  6                                       Cohen's d =    0.9012
# ...

# %%
# Selecting 
highspread_369 = df_36_Agg_Normal["ICE BofA BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_369 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index OAS'] > highspread_369)]

# %%
normalized_df_369.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.774927
# std                                 0.185769
# min                                 0.373756
# 25%                                 0.679666
# 50%                                 0.806471
# 75%                                 0.933154
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.703515
# std                                          0.131142
# min                                          0.453287
# 25%                                          0.633145
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_369['ICE BofA BBB US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA BBB US Fixed Rate CMBS Index   24.0  0.730333  0.195879  0.039984
#  1  ICE BofA BBB US Fixed Rate CMBS Index  159.0  0.530494  0.156226  0.012390
#  2                               combined  183.0  0.556702  0.174964  0.012934
#
#     95% Conf.  Interval
#  0   0.647620  0.813045
#  1   0.506024  0.554964
#  2   0.531183  0.582222  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA BBB US Fixed Rate CMBS In...   0.1998
#  1                              Degrees of freedom =   27.5918
#  2                                               t =    4.7741
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.0455
# ...

# %%
# Selecting 
highspread_3610 = df_36_Agg_Normal["ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_3610 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index OAS'] > highspread_3610)]

# %%
normalized_df_3610.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              22.000000
# mean                                0.733829
# std                                 0.182357
# min                                 0.373756
# 25%                                 0.605312
# 50%                                 0.730570
# 75%                                 0.909614
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.686108
# std                                          0.148070
# min                                          0.423597
# 25%                                          0.549668
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_3610['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                          Variable      N      Mean        SD  \
#  0  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index   24.0  0.711108  0.250145
#  1  ICE BofA 7-10 Year BBB US Fixed Rate CMBS Index  161.0  0.510061  0.170069
#  2                                         combined  185.0  0.536143  0.193805
#
#           SE  95% Conf.  Interval
#  0  0.051061   0.605481  0.816735
#  1  0.013403   0.483591  0.536531
#  2  0.014249   0.508030  0.564255  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year BBB US Fixed Ra...   0.2010
#  1                              Degrees of freedom =   26.2609
#  2                                               t =    3.8084
#  3                           Two side test p value =    0.0008
#  4                          Difference < 0 p value =    0.9996
#  5                          Difference > 0 p value =    0.0004
#  6                                       Cohen's d =    0.8333
# ...

# %%
# Selecting 
highspread_3611 = df_36_Agg_Normal["ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_3611 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index OAS'] > highspread_3611)]

# %%
normalized_df_3611.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              24.000000
# mean                                0.746865
# std                                 0.201404
# min                                 0.373756
# 25%                                 0.586898
# 50%                                 0.775953
# 75%                                 0.927087
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.696135
# std                                          0.141682
# min                                          0.410060
# 25%                                          0.623849
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_3611['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'], df_36_Agg_Normal['ICE BofA 10+ Year BBB US Fixed Rate CMBS Index'],equal_variances= False)

des, res
# Out:
# (                                         Variable      N      Mean        SD  \
#  0  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index   17.0  0.661987  0.057076
#  1  ICE BofA 10+ Year BBB US Fixed Rate CMBS Index  155.0  0.436915  0.124735
#  2                                        combined  172.0  0.459161  0.137314
#
#           SE  95% Conf.  Interval
#  0  0.013843   0.632641  0.691332
#  1  0.010019   0.417123  0.456707
#  2  0.010470   0.438493  0.479828  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10+ Year BBB US Fixed Rat...   0.2251
#  1                              Degrees of freedom =   36.1229
#  2                                               t =   13.1712
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    3.3651
# ...

# %%
# Selecting 
highspread_3612 = df_36_Agg_Normal["ICE BofA US ABS & CMBS Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_3612 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US ABS & CMBS Index OAS'] > highspread_3612)]

# %%
normalized_df_3612.describe()
# Out:
#        ICE BofA AAA US Fixed Rate CMBS Index  \
# count                              20.000000
# mean                                0.797443
# std                                 0.178870
# min                                 0.373756
# 25%                                 0.716342
# 50%                                 0.839598
# 75%                                 0.938251
# max                                 0.993099
#
#        ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# count                                       45.000000
# mean                                         0.702940
# std                                          0.132395
# min                                          0.419536
# 25%                                          0.633145
# 50%                                          0.707235
# 75%                                          0.780785
# max                                          0.986272
#
#        ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_3612['ICE BofA US ABS & CMBS Index'], df_36_Agg_Normal['ICE BofA US ABS & CMBS Index'],equal_variances= False)

des, res
# Out:
# (                       Variable      N      Mean        SD        SE  \
#  0  ICE BofA US ABS & CMBS Index   17.0  0.855917  0.186897  0.045329
#  1  ICE BofA US ABS & CMBS Index  150.0  0.553671  0.158236  0.012920
#  2                      combined  167.0  0.584439  0.185052  0.014320
#
#     95% Conf.  Interval
#  0   0.759823  0.952010
#  1   0.528141  0.579201
#  2   0.556166  0.612711  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US ABS & CMBS Index - ICE...   0.3022
#  1                              Degrees of freedom =   18.6920
#  2                                               t =    6.4124
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.6410
#  7                                       Hedge's g =    1.6335
# ...
