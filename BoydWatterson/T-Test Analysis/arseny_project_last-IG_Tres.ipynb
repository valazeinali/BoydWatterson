# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Arseny_Project.xlsx', sheet_name="IG_Tres")

# %%
df.head()
df_copy = df.copy()

# %%
df.head(6)
# Out:
#         Date  ICE BofA 1-3 Year US Corporate Index OAS  \
# 0 1997-01-31                                        48
# 1 1997-02-28                                        47
# 2 1997-03-31                                        40
# 3 1997-04-30                                        40
# 4 1997-05-31                                        39
# 5 1997-06-30                                        40
#
#    ICE BofA 1-3 Year US Corporate Index  \
# 0                               0.00022
# 1                               0.00049
# 2                               0.00134
# 3                               0.00056
# 4                               0.00021
# 5                               0.00049
#
#    ICE BofA 3-5 Year US Corporate Index OAS  \
# 0                                        50
# 1                                        47
# 2                                        45
# 3                                        47
# 4                                        47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Date                                        269 non-null    datetime64[ns]
#  1   ICE BofA 1-3 Year US Corporate Index OAS    269 non-null    int64
#  2   ICE BofA 1-3 Year US Corporate Index        269 non-null    float64
#  3   ICE BofA 3-5 Year US Corporate Index OAS    269 non-null    int64
#  4   ICE BofA 3-5 Year US Corporate Index        269 non-null    float64
#  5   ICE BofA 5-7 Year US Corporate Index OAS    269 non-null    int64
#  6   ICE BofA 5-7 Year US Corporate Index        269 non-null    float64
#  7   ICE BofA 7-10 Year US Corporate Index OAS   269 non-null    int64
#  8   ICE BofA 7-10 Year US Corporate Index       269 non-null    float64
# ...

# %%
df.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index OAS  \
# count                                269.000000
# mean                                  99.620818
# std                                   55.929571
# min                                   39.000000
# 25%                                   61.000000
# 50%                                   87.000000
# 75%                                  119.000000
# max                                  507.000000
#
#        ICE BofA 1-3 Year US Corporate Index  \
# count                            269.000000
# mean                               0.000469
# std                                0.005364
# min                               -0.056170
# 25%                               -0.000200
# 50%                                0.000720
# 75%                                0.001890
# max                                0.023250
#
#        ICE BofA 3-5 Year US Corporate Index OAS  \
# count                                269.000000
# ...

# %% [markdown]
# # Drop Outliers!

# %%
df = df.drop(columns = ['Date'])

#q1 = df.quantile(0.25)
#q3 = df.quantile(0.75)

#iqr = q3 - q1

#lower_bound = q1 -(1.5 * iqr) 
#upper_bound = q3 +(1.5 * iqr)

#print(lower_bound)
#print(upper_bound)

#df = df[(df > lower_bound) & (df < upper_bound)] # gets rid of outliers on Agg Excess Returns
#df['Date'] = df_Date
#df.head()

# %%
def lower_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    lower_bounds = q1 -(1.5 * iqr) 
    
    return lower_bounds

# %%
def upper_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    upper_bounds = q3 +(1.5 * iqr) 
    
    return upper_bounds

# %%
lower_bound(df)
# Out:
# ICE BofA 1-3 Year US Corporate Index OAS     -26.000000
# ICE BofA 1-3 Year US Corporate Index          -0.003335
# ICE BofA 3-5 Year US Corporate Index OAS     -20.000000
# ICE BofA 3-5 Year US Corporate Index          -0.007875
# ICE BofA 5-7 Year US Corporate Index OAS      -2.500000
# ICE BofA 5-7 Year US Corporate Index          -0.012550
# ICE BofA 7-10 Year US Corporate Index OAS      5.500000
# ICE BofA 7-10 Year US Corporate Index         -0.018120
# ICE BofA 10-15 Year US Corporate Index OAS   -18.000000
# ICE BofA 10-15 Year US Corporate Index        -0.019235
# ICE BofA 15+ Year US Corporate Index OAS      35.000000
# ICE BofA 15+ Year US Corporate Index          -0.030590
# dtype: float64

# %%
upper_bound(df)
# Out:
# ICE BofA 1-3 Year US Corporate Index OAS      206.000000
# ICE BofA 1-3 Year US Corporate Index            0.005025
# ICE BofA 3-5 Year US Corporate Index OAS      252.000000
# ICE BofA 3-5 Year US Corporate Index            0.009765
# ICE BofA 5-7 Year US Corporate Index OAS      281.500000
# ICE BofA 5-7 Year US Corporate Index            0.014890
# ICE BofA 7-10 Year US Corporate Index OAS     289.500000
# ICE BofA 7-10 Year US Corporate Index           0.019400
# ICE BofA 10-15 Year US Corporate Index OAS    326.000000
# ICE BofA 10-15 Year US Corporate Index          0.021765
# ICE BofA 15+ Year US Corporate Index OAS      307.000000
# ICE BofA 15+ Year US Corporate Index            0.030690
# dtype: float64

# %%
df["Date"] = df_copy["Date"]
df.head()
# Out:
#    ICE BofA 1-3 Year US Corporate Index OAS  \
# 0                                        48
# 1                                        47
# 2                                        40
# 3                                        40
# 4                                        39
#
#    ICE BofA 1-3 Year US Corporate Index  \
# 0                               0.00022
# 1                               0.00049
# 2                               0.00134
# 3                               0.00056
# 4                               0.00021
#
#    ICE BofA 3-5 Year US Corporate Index OAS  \
# 0                                        50
# 1                                        47
# 2                                        45
# 3                                        47
# 4                                        47
#
#    ICE BofA 3-5 Year US Corporate Index  \
# 0                               0.00028
# 1                               0.00099
# 2                               0.00091
# ...

# %%
df.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index OAS  \
# count                                269.000000
# mean                                  99.620818
# std                                   55.929571
# min                                   39.000000
# 25%                                   61.000000
# 50%                                   87.000000
# 75%                                  119.000000
# max                                  507.000000
#
#        ICE BofA 1-3 Year US Corporate Index  \
# count                            269.000000
# mean                               0.000469
# std                                0.005364
# min                               -0.056170
# 25%                               -0.000200
# 50%                                0.000720
# 75%                                0.001890
# max                                0.023250
#
#        ICE BofA 3-5 Year US Corporate Index OAS  \
# count                                269.000000
# ...

# %%
df1 = df.drop(columns = ['ICE BofA 1-3 Year US Corporate Index OAS','ICE BofA 3-5 Year US Corporate Index OAS','ICE BofA 5-7 Year US Corporate Index OAS','ICE BofA 7-10 Year US Corporate Index OAS','ICE BofA 10-15 Year US Corporate Index OAS','ICE BofA 15+ Year US Corporate Index OAS'])

# %%
df1.head(36)
# Out:
#     ICE BofA 1-3 Year US Corporate Index  \
# 0                                0.00022
# 1                                0.00049
# 2                                0.00134
# 3                                0.00056
# 4                                0.00021
# 5                                0.00049
# 6                                0.00054
# 7                                0.00049
# 8                                0.00005
# 9                               -0.00094
# 10                              -0.00066
# 11                              -0.00050
# 12                               0.00035
# 13                               0.00030
# 14                               0.00106
# 15                               0.00043
# 16                               0.00058
# 17                               0.00027
# 18                               0.00002
# 19                              -0.00472
# 20                              -0.00082
# 21                              -0.00284
# ...

# %% [markdown]
# # Create Excess returns

# %%
# Creating Excess Returns 3,6,9,12,24,36 for AGG
df_3_Agg = df1.rolling(3,win_type='boxcar',center=True).sum().shift(-1)
df_6_Agg = df1.rolling(6,win_type='boxcar',center=True).sum().shift(-3)
df_9_Agg = df1.rolling(9,win_type='boxcar',center=True).sum().shift(-4)
df_12_Agg = df1.rolling(12,win_type='boxcar',center=True).sum().shift(-6)
df_24_Agg = df1.rolling(24,win_type='boxcar',center=True).sum().shift(-12)
df_36_Agg = df1.rolling(36,win_type='boxcar',center=True).sum().shift(-18)

# %%
df_36_Agg.head()
# Out:
#    ICE BofA 1-3 Year US Corporate Index  ICE BofA 3-5 Year US Corporate Index  \
# 0                               0.01260                               0.00324
# 1                               0.01247                               0.00273
# 2                               0.01326                               0.00199
# 3                               0.01099                              -0.00225
# 4                               0.00730                              -0.00626
#
#    ICE BofA 5-7 Year US Corporate Index  \
# 0                              -0.00334
# 1                              -0.00471
# 2                              -0.00992
# 3                              -0.01817
# 4                              -0.02397
#
#    ICE BofA 7-10 Year US Corporate Index  \
# 0                               -0.01984
# 1                               -0.02639
# 2                               -0.03434
# 3                               -0.04630
# ...

# %%
df_12_Agg.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                            258.000000
# mean                               0.005524
# std                                0.016876
# min                               -0.072430
# 25%                                0.001840
# 50%                                0.006155
# 75%                                0.013945
# max                                0.044790
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                            258.000000
# mean                               0.005037
# std                                0.028373
# min                               -0.120930
# 25%                               -0.003010
# 50%                                0.007905
# 75%                                0.020852
# max                                0.074090
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                            258.000000
# mean                               0.005631
# ...

# %% [markdown]
# # Calculate Min/Max

# %%
# Now lets normalize our data (for treasury)
#df_3_Agg = df_3_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_3_Agg)
df_3_Agg_Max = column_maxes
column_mins = lower_bound(df_3_Agg)
df_3_Agg_Min = column_mins
df_3_Agg_Normal = (df_3_Agg - df_3_Agg_Min) / (df_3_Agg_Max - df_3_Agg_Min)

#df_3_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_6_Agg = df_6_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_6_Agg)
df_6_Agg_Max = column_maxes
column_mins = lower_bound(df_6_Agg)
df_6_Agg_Min = column_mins
df_6_Agg_Normal = (df_6_Agg - df_6_Agg_Min) / (df_6_Agg_Max - df_6_Agg_Min)

#df_6_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_9_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_9_Agg)
df_9_Agg_Max = column_maxes
column_mins = lower_bound(df_9_Agg)
df_9_Agg_Min = column_mins
df_9_Agg_Normal = (df_9_Agg - df_9_Agg_Min) / (df_9_Agg_Max - df_9_Agg_Min)

#df_9_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_12_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_12_Agg)
df_12_Agg_Max = column_maxes
column_mins = lower_bound(df_12_Agg)
df_12_Agg_Min = column_mins
df_12_Agg_Normal = (df_12_Agg - df_12_Agg_Min) / (df_12_Agg_Max - df_12_Agg_Min)

#df_12_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_24_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_24_Agg)
df_24_Agg_Max = column_maxes
column_mins = lower_bound(df_24_Agg)
df_24_Agg_Min = column_mins
df_24_Agg_Normal = (df_24_Agg - df_24_Agg_Min) / (df_24_Agg_Max - df_24_Agg_Min)

#df_24_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_36_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_36_Agg)
df_36_Agg_Max = column_maxes
column_mins = lower_bound(df_36_Agg)
df_36_Agg_Min = column_mins
df_36_Agg_Normal = (df_36_Agg - df_36_Agg_Min) / (df_36_Agg_Max - df_36_Agg_Min)

#df_36_Agg_Normal['Date'] = df_Date

# %%
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_6_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_6_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_9_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_9_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_12_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_12_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_24_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_24_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_36_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_36_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]

# %%
df_12_Agg_Normal.head()
# Out:
#    ICE BofA 1-3 Year US Corporate Index  ICE BofA 3-5 Year US Corporate Index  \
# 0                              0.508351                              0.504535
# 1                              0.526670                              0.494571
# 2                              0.511584                              0.478219
# 3                              0.465787                              0.472598
# 4                              0.464709                              0.503002
#
#    ICE BofA 5-7 Year US Corporate Index  \
# 0                              0.512832
# 1                              0.490724
# 2                              0.480056
# 3                              0.485931
# 4                              0.501082
#
#    ICE BofA 7-10 Year US Corporate Index  \
# 0                               0.543311
# 1                               0.513084
# 2                               0.460373
# 3                               0.500468
# ...

# %%
df_12_Agg_Normal.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                            232.000000
# mean                               0.500850
# std                                0.180459
# min                                0.024515
# 25%                                0.406385
# 50%                                0.505927
# 75%                                0.609240
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                            240.000000
# mean                               0.521267
# std                                0.183300
# min                                0.000703
# 25%                                0.424502
# 50%                                0.540049
# 75%                                0.624106
# max                                0.952414
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                            251.000000
# mean                               0.508357
# ...

# %%
df.head()
# Out:
#    ICE BofA 1-3 Year US Corporate Index OAS  \
# 0                                        48
# 1                                        47
# 2                                        40
# 3                                        40
# 4                                        39
#
#    ICE BofA 1-3 Year US Corporate Index  \
# 0                               0.00022
# 1                               0.00049
# 2                               0.00134
# 3                               0.00056
# 4                               0.00021
#
#    ICE BofA 3-5 Year US Corporate Index OAS  \
# 0                                        50
# 1                                        47
# 2                                        45
# 3                                        47
# 4                                        47
#
#    ICE BofA 3-5 Year US Corporate Index  \
# 0                               0.00028
# 1                               0.00099
# 2                               0.00091
# ...

# %%
pd.options.display.max_rows  = 280 # want to see all columns

df_36_Agg.head(280)
# Out:
#      ICE BofA 1-3 Year US Corporate Index  \
# 0                                 0.01260
# 1                                 0.01247
# 2                                 0.01326
# 3                                 0.01099
# 4                                 0.00730
# 5                                 0.00628
# 6                                 0.00606
# 7                                 0.00815
# 8                                 0.00757
# 9                                 0.00957
# 10                                0.00487
# 11                                0.00551
# 12                                0.00415
# 13                                0.00652
# 14                                0.00679
# 15                                0.00763
# 16                                0.00787
# 17                                0.00970
# 18                                0.01090
# 19                                0.01423
# 20                                0.02006
# ...

# %%
df.head()
# Out:
#    ICE BofA 1-3 Year US Corporate Index OAS  \
# 0                                        48
# 1                                        47
# 2                                        40
# 3                                        40
# 4                                        39
#
#    ICE BofA 1-3 Year US Corporate Index  \
# 0                               0.00022
# 1                               0.00049
# 2                               0.00134
# 3                               0.00056
# 4                               0.00021
#
#    ICE BofA 3-5 Year US Corporate Index OAS  \
# 0                                        50
# 1                                        47
# 2                                        45
# 3                                        47
# 4                                        47
#
#    ICE BofA 3-5 Year US Corporate Index  \
# 0                               0.00028
# 1                               0.00099
# 2                               0.00091
# ...

# %%
# Adding back spreads so we can do the selective query 
df_3_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_3_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_3_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_3_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_3_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_3_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal > 0]
df_3_Agg_Normal["Date"] = df_copy["Date"]

df_6_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_6_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_6_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_6_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_6_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_6_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal > 0]
df_6_Agg_Normal["Date"] = df_copy["Date"]


df_9_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_9_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_9_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_9_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_9_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_9_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal > 0]
df_9_Agg_Normal["Date"] = df_copy["Date"]


df_12_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_12_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_12_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_12_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_12_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_12_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal > 0]
df_12_Agg_Normal["Date"] = df_copy["Date"]


df_24_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_24_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_24_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_24_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_24_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_24_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal > 0]
df_24_Agg_Normal["Date"] = df_copy["Date"]


df_36_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"] = df["ICE BofA 1-3 Year US Corporate Index OAS"]
df_36_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"] = df["ICE BofA 3-5 Year US Corporate Index OAS"]
df_36_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"] = df["ICE BofA 5-7 Year US Corporate Index OAS"]
df_36_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"] = df["ICE BofA 7-10 Year US Corporate Index OAS"]
df_36_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"] = df["ICE BofA 10-15 Year US Corporate Index OAS"]
df_36_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"] = df["ICE BofA 15+ Year US Corporate Index OAS"]
#df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal > 0]
df_36_Agg_Normal["Date"] = df_copy["Date"]

# %%
pd.options.display.max_rows  = 280 # want to see all columns

df_3_Agg_Normal.head(280)
# Out:
#      ICE BofA 1-3 Year US Corporate Index  \
# 0                                0.508351
# 1                                0.526670
# 2                                0.511584
# 3                                0.465787
# 4                                0.464709
# 5                                0.479795
# 6                                0.456088
# 7                                0.376347
# 8                                0.314386
# 9                                0.284752
# 10                               0.354256
# 11                               0.405981
# 12                               0.490032
# 13                               0.494343
# 14                               0.509429
# 15                               0.466864
# 16                               0.444774
# 17                               0.159213
# 18                               0.100485
# 19                                    NaN
# 20                               0.436692
# ...

# %% [markdown]
# # Now we move on to our Hypothesis Testing Segment
#
# ## Our hypothesis is that spreads that are in the 80th percentile have higher excess returns than average case.

# %%
import researchpy # for t-test stuff!

# %% [markdown]
# # 3 Month Below

# %%
# Selecting 
highspread_31 = df_3_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_3_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_3_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_3_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_3_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_3_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_3_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...

# %% [markdown]
# # 6 Month Below

# %%
# Selecting 
highspread_31 = df_6_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_6_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_6_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_6_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_6_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_6_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_6_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...

# %% [markdown]
# # 9 Month Below

# %%
# Selecting 
highspread_31 = df_9_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_9_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_9_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_9_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_9_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_9_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_9_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...

# %% [markdown]
# # 12 Month Below

# %%
# Selecting 
highspread_31 = df_12_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_12_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_12_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_12_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_12_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_12_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_12_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...

# %% [markdown]
# # 24 Month Below

# %%
# Selecting 
highspread_31 = df_24_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_24_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_24_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_24_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_24_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_24_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_24_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...

# %% [markdown]
# # 36 Month Below

# %%
# Selecting 
highspread_31 = df_36_Agg_Normal["ICE BofA 1-3 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 1-3 Year US Corporate Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.516366
# std                                0.291544
# min                                0.080011
# 25%                                0.293642
# 50%                                0.474138
# 75%                                0.763066
# max                                0.974407
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.590560
# std                                0.269436
# min                                0.049502
# 25%                                0.448327
# 50%                                0.622317
# 75%                                0.856094
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.536887
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 1-3 Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 1-3 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 1-3 Year US Corporate Index   32.0  0.516366  0.291544  0.051538
#  1  ICE BofA 1-3 Year US Corporate Index  232.0  0.500850  0.180459  0.011848
#  2                              combined  264.0  0.502731  0.196590  0.012099
#
#     95% Conf.  Interval
#  0   0.411253  0.621479
#  1   0.477507  0.524193
#  2   0.478907  0.526554  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 1-3 Year US Corporate Ind...   0.0155
#  1                              Degrees of freedom =   34.3501
#  2                                               t =    0.2934
#  3                           Two side test p value =    0.7710
#  4                          Difference < 0 p value =    0.6145
#  5                          Difference > 0 p value =    0.3855
#  6                                       Cohen's d =    0.0553
# ...

# %%
# Selecting 
highspread_32 = df_36_Agg_Normal["ICE BofA 3-5 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 3-5 Year US Corporate Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             33.000000
# mean                               0.486865
# std                                0.276062
# min                                0.080011
# 25%                                0.252425
# 50%                                0.464170
# 75%                                0.666218
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.556980
# std                                0.265250
# min                                0.049502
# 25%                                0.359415
# 50%                                0.551035
# 75%                                0.755685
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.530159
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 3-5 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean       SD        SE  \
#  0  ICE BofA 3-5 Year US Corporate Index   37.0  0.556980  0.26525  0.043607
#  1  ICE BofA 3-5 Year US Corporate Index  240.0  0.521267  0.18330  0.011832
#  2                              combined  277.0  0.526037  0.19601  0.011777
#
#     95% Conf.  Interval
#  0   0.468541  0.645419
#  1   0.497958  0.544575
#  2   0.502853  0.549221  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Corporate Ind...   0.0357
#  1                              Degrees of freedom =   41.4620
#  2                                               t =    0.7904
#  3                           Two side test p value =    0.4338
#  4                          Difference < 0 p value =    0.7831
#  5                          Difference > 0 p value =    0.2169
#  6                                       Cohen's d =    0.1396
# ...

# %%
# Selecting 
highspread_33 = df_36_Agg_Normal["ICE BofA 5-7 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 5-7 Year US Corporate Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             31.000000
# mean                               0.519162
# std                                0.279019
# min                                0.080011
# 25%                                0.340517
# 50%                                0.474946
# 75%                                0.767241
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             36.000000
# mean                               0.580310
# std                                0.262210
# min                                0.049502
# 25%                                0.440981
# 50%                                0.579267
# 75%                                0.818600
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             42.000000
# mean                               0.567762
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA 5-7 Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 5-7 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 5-7 Year US Corporate Index   42.0  0.567762  0.274957  0.042427
#  1  ICE BofA 5-7 Year US Corporate Index  251.0  0.508357  0.190924  0.012051
#  2                              combined  293.0  0.516873  0.205570  0.012010
#
#     95% Conf.  Interval
#  0   0.482080  0.653445
#  1   0.484623  0.532092
#  2   0.493237  0.540509  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 5-7 Year US Corporate Ind...   0.0594
#  1                              Degrees of freedom =   47.8316
#  2                                               t =    1.3469
#  3                           Two side test p value =    0.1844
#  4                          Difference < 0 p value =    0.9078
#  5                          Difference > 0 p value =    0.0922
#  6                                       Cohen's d =    0.2245
# ...

# %%
# Selecting 
highspread_34 = df_36_Agg_Normal["ICE BofA 7-10 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 7-10 Year US Corporate Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             32.000000
# mean                               0.499848
# std                                0.280139
# min                                0.080011
# 25%                                0.293642
# 50%                                0.473330
# 75%                                0.763066
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             35.000000
# mean                               0.542209
# std                                0.273267
# min                                0.042859
# 25%                                0.382665
# 50%                                0.546436
# 75%                                0.753258
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             41.000000
# mean                               0.533697
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA 7-10 Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 7-10 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                Variable      N      Mean        SD        SE  \
#  0  ICE BofA 7-10 Year US Corporate Index   41.0  0.530787  0.264002  0.041230
#  1  ICE BofA 7-10 Year US Corporate Index  251.0  0.508903  0.189107  0.011936
#  2                               combined  292.0  0.511976  0.200901  0.011757
#
#     95% Conf.  Interval
#  0   0.447458  0.614116
#  1   0.485394  0.532411
#  2   0.488836  0.535115  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 7-10 Year US Corporate In...   0.0219
#  1                              Degrees of freedom =   46.9333
#  2                                               t =    0.5098
#  3                           Two side test p value =    0.6125
#  4                          Difference < 0 p value =    0.6937
#  5                          Difference > 0 p value =    0.3063
#  6                                       Cohen's d =    0.0859
# ...

# %%
# Selecting 
highspread_35 = df_36_Agg_Normal["ICE BofA 10-15 Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 10-15 Year US Corporate Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             34.000000
# mean                               0.524056
# std                                0.266074
# min                                0.080011
# 25%                                0.323949
# 50%                                0.561422
# 75%                                0.705819
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             37.000000
# mean                               0.557560
# std                                0.261598
# min                                0.042859
# 25%                                0.418945
# 50%                                0.585526
# 75%                                0.746742
# max                                0.932230
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             43.000000
# mean                               0.557726
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA 10-15 Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 10-15 Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                                 Variable      N      Mean        SD  \
#  0  ICE BofA 10-15 Year US Corporate Index   41.0  0.526715  0.274558
#  1  ICE BofA 10-15 Year US Corporate Index  246.0  0.506142  0.190175
#  2                                combined  287.0  0.509081  0.203904
#
#           SE  95% Conf.  Interval
#  0  0.042879   0.440054  0.613376
#  1  0.012125   0.482259  0.530024
#  2  0.012036   0.485390  0.532771  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 10-15 Year US Corporate I...   0.0206
#  1                              Degrees of freedom =   46.6041
#  2                                               t =    0.4617
#  3                           Two side test p value =    0.6464
#  4                          Difference < 0 p value =    0.6768
#  5                          Difference > 0 p value =    0.3232
#  6                                       Cohen's d =    0.0779
# ...

# %%
# Selecting 
highspread_36 = df_36_Agg_Normal["ICE BofA 15+ Year US Corporate Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 15+ Year US Corporate Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 1-3 Year US Corporate Index  \
# count                             37.000000
# mean                               0.474378
# std                                0.260183
# min                                0.080011
# 25%                                0.252425
# 50%                                0.473330
# 75%                                0.622037
# max                                0.931843
#
#        ICE BofA 3-5 Year US Corporate Index  \
# count                             39.000000
# mean                               0.498121
# std                                0.256364
# min                                0.042859
# 25%                                0.301673
# 50%                                0.504024
# 75%                                0.711740
# max                                0.928654
#
#        ICE BofA 5-7 Year US Corporate Index  \
# count                             45.000000
# mean                               0.521752
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA 15+ Year US Corporate Index'], df_36_Agg_Normal['ICE BofA 15+ Year US Corporate Index'],equal_variances= False)

des, res
# Out:
# (                               Variable      N      Mean        SD        SE  \
#  0  ICE BofA 15+ Year US Corporate Index   44.0  0.501961  0.259888  0.039180
#  1  ICE BofA 15+ Year US Corporate Index  251.0  0.505421  0.193190  0.012194
#  2                              combined  295.0  0.504905  0.204002  0.011877
#
#     95% Conf.  Interval
#  0   0.422948  0.580975
#  1   0.481405  0.529437
#  2   0.481530  0.528281  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 15+ Year US Corporate Ind...  -0.0035
#  1                              Degrees of freedom =   51.6507
#  2                                               t =   -0.0843
#  3                           Two side test p value =    0.9331
#  4                          Difference < 0 p value =    0.4666
#  5                          Difference > 0 p value =    0.5334
#  6                                       Cohen's d =   -0.0138
# ...
