# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('Hyp_3_matrix_Merged.xlsx', sheet_name="Merged")

# %%
df.head()
# Out:
#   Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 0      ABS              10                           0.520337
# 1      ABS              10                           0.509468
# 2      ABS              10                           0.497420
# 3      ABS              10                           0.506328
# 4      ABS              10                           0.507046
#
#    Population Mean Excess Return  P-Value Greater Returns  Month Benchmark
# 0                       0.496887   0.1490              no      3      tres
# 1                       0.499424   0.2659              no      3       agg
# 2                       0.470617   0.1126              no      6      tres
# 3                       0.492462   0.2047              no      6       agg
# 4                       0.480718   0.1099              no      9      tres

# %%
df.tail()
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 1337       EM              85                           0.452058
# 1338       EM              85                           0.552979
# 1339       EM              85                           0.362894
# 1340       EM              85                           0.632225
# 1341       EM              85                           0.396666
#
#       Population Mean Excess Return  P-Value Greater Returns  Month Benchmark
# 1337                       0.495017   0.8187              no     12       agg
# 1338                       0.500095   0.0905              no     24      tres
# 1339                       0.487434   0.9948              no     24       agg
# 1340                       0.504781   0.0038             yes     36      tres
# 1341                       0.497593   0.9822              no     36       agg

# %% [markdown]
# # 3 Month Signal Against Tres.

# %%
df_tres_3 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 3)]
df_tres_3.head(50)
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 48        ABS              30                           0.543763
# 60        ABS              35                           0.549407
# 72        ABS              40                           0.544036
# 84        ABS              45                           0.547030
# 96        ABS              50                           0.559998
# 108       ABS              55                           0.565782
# 120       ABS              60                           0.581654
# 132       ABS              65                           0.577923
# 144       ABS              70                           0.582271
# 156       ABS              75                           0.605700
# 168       ABS              80                           0.609029
# 180       ABS              85                           0.622263
# 1294       EM              70                           0.554041
# ...

# %% [markdown]
# # 3 Month Signal Against Agg.

# %%
df_agg_3 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 3)]
df_agg_3.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 361      MBS              80                           0.563012
# 911       IG              70                           0.571538
# 923       IG              75                           0.576690
# 935       IG              80                           0.589374
# 947       IG              85                           0.608889
#
#      Population Mean Excess Return  P-Value Greater Returns  Month Benchmark
# 361                       0.497352   0.0237             yes      3       agg
# 911                       0.503562   0.0104             yes      3       agg
# 923                       0.503562   0.0096             yes      3       agg
# 935                       0.503562   0.0073             yes      3       agg
# 947                       0.503562   0.0034             yes      3       agg

# %% [markdown]
# # 6 Month Signal Against Tres.

# %%
df_tres_6 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 6)]
df_tres_6.head(50)
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 14        ABS              15                           0.513853
# 26        ABS              20                           0.515218
# 38        ABS              25                           0.521525
# 50        ABS              30                           0.532281
# 62        ABS              35                           0.538966
# 74        ABS              40                           0.535812
# 86        ABS              45                           0.538909
# 98        ABS              50                           0.554423
# 110       ABS              55                           0.570225
# 122       ABS              60                           0.591134
# 134       ABS              65                           0.598994
# 146       ABS              70                           0.601598
# 158       ABS              75                           0.620340
# ...

# %% [markdown]
# # 6 Month Signal Against Agg.

# %%
df_agg_6 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 6)]
df_agg_6.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 327      MBS              65                           0.543284
# 351      MBS              75                           0.550619
# 363      MBS              80                           0.603742
# 375      MBS              85                           0.571698
# 877       IG              55                           0.547283
# 889       IG              60                           0.552355
# 901       IG              65                           0.555288
# 913       IG              70                           0.573659
# 925       IG              75                           0.593430
# 937       IG              80                           0.603242
# 949       IG              85                           0.620401
#
#      Population Mean Excess Return  P-Value Greater Returns  Month Benchmark
# 327                       0.495918   0.0387             yes      6       agg
# ...

# %% [markdown]
# # 9 Month Signal Against Tres.

# %%
df_tres_9 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 9)]
df_tres_9.head(50)
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 16        ABS              15                           0.525791
# 28        ABS              20                           0.527401
# 40        ABS              25                           0.534760
# 52        ABS              30                           0.545207
# 64        ABS              35                           0.556258
# 76        ABS              40                           0.554303
# 88        ABS              45                           0.564018
# 100       ABS              50                           0.572149
# 112       ABS              55                           0.581518
# 124       ABS              60                           0.597074
# 136       ABS              65                           0.607985
# 148       ABS              70                           0.613181
# 160       ABS              75                           0.635122
# ...

# %% [markdown]
# # 9 Month Signal Against Agg.

# %%
df_agg_9 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 9)]
df_agg_9.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 281      MBS              45                           0.545027
# 293      MBS              50                           0.545644
# 329      MBS              65                           0.554357
# 353      MBS              75                           0.570696
# 365      MBS              80                           0.622286
# 377      MBS              85                           0.606441
# 521     CMBS              65                           0.480675
# 879       IG              55                           0.551073
# 891       IG              60                           0.560398
# 903       IG              65                           0.565887
# 915       IG              70                           0.570141
# 927       IG              75                           0.585405
# 939       IG              80                           0.587425
# 951       IG              85                           0.585654
#
# ...

# %% [markdown]
# # 12 Month Signal Against Tres.

# %%
df_tres_12 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 12)]
df_tres_12.head(50)
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 18        ABS              15                           0.534249
# 30        ABS              20                           0.536185
# 42        ABS              25                           0.541738
# 54        ABS              30                           0.553050
# 66        ABS              35                           0.568692
# 78        ABS              40                           0.570881
# 90        ABS              45                           0.580770
# 102       ABS              50                           0.589611
# 114       ABS              55                           0.599112
# 126       ABS              60                           0.608075
# 138       ABS              65                           0.615346
# 150       ABS              70                           0.620866
# 162       ABS              75                           0.629262
# ...

# %% [markdown]
# # 12 Month Signal Against Agg.

# %%
df_agg_12 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 12)]
df_agg_12.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 295      MBS              50                           0.549759
# 331      MBS              65                           0.565720
# 343      MBS              70                           0.563706
# 355      MBS              75                           0.591016
# 367      MBS              80                           0.651437
# 379      MBS              85                           0.637516
# 523     CMBS              65                           0.535512
# 857       IG              45                           0.549544
# 869       IG              50                           0.550756
# 881       IG              55                           0.566640
# 893       IG              60                           0.576422
# 905       IG              65                           0.585826
# 917       IG              70                           0.588104
# 929       IG              75                           0.596531
# ...

# %% [markdown]
# # 24 Month Signal Against Tres.

# %%
df_tres_24 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 24)]
df_tres_24.head(50)
# Out:
#      Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 32        ABS              20                           0.516533
# 44        ABS              25                           0.527501
# 56        ABS              30                           0.537910
# 68        ABS              35                           0.550079
# 80        ABS              40                           0.553473
# 92        ABS              45                           0.559542
# 104       ABS              50                           0.566908
# 116       ABS              55                           0.573659
# 128       ABS              60                           0.575703
# 140       ABS              65                           0.570255
# 152       ABS              70                           0.567640
# 164       ABS              75                           0.570318
# 176       ABS              80                           0.568362
# ...

# %% [markdown]
# # 24 Month Signal Against Agg.

# %%
df_agg_24 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 24)]
df_agg_24.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 249      MBS              30                           0.482553
# 261      MBS              35                           0.485164
# 273      MBS              40                           0.494817
# 285      MBS              45                           0.500001
# 297      MBS              50                           0.497413
# 369      MBS              80                           0.513048
# 668       HY              45                           0.546756
# 680       HY              50                           0.556341
# 692       HY              55                           0.570957
# 704       HY              60                           0.575783
# 716       HY              65                           0.580743
# 728       HY              70                           0.584225
# 740       HY              75                           0.596350
# 752       HY              80                           0.600858
# ...

# %% [markdown]
# # 36 Month Signal Against Tres.

# %%
df_tres_36 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'tres')&(df['Month'] == 36)]
df_tres_36.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 46       ABS              25                           0.544554
# 58       ABS              30                           0.555216
# 70       ABS              35                           0.574180
# 82       ABS              40                           0.582826
# 94       ABS              45                           0.592912
# 106      ABS              50                           0.602600
# 118      ABS              55                           0.610551
# 130      ABS              60                           0.614422
# 142      ABS              65                           0.614256
# 154      ABS              70                           0.616361
# 166      ABS              75                           0.629057
# 178      ABS              80                           0.634338
# 190      ABS              85                           0.640782
# 334      MBS              65                           0.551384
# ...

# %% [markdown]
# # 36 Month Signal Against Agg.

# %%
df_agg_36 = df[(df['Greater Returns'] == 'yes') & (df['Benchmark'] == 'agg')&(df['Month'] == 36)]
df_agg_36.head(50)
# Out:
#     Security  OAS Percentile  OAS Percentile Mean Excess Return  \
# 47       ABS              25                           0.567573
# 251      MBS              30                           0.494853
# 263      MBS              35                           0.496285
# 275      MBS              40                           0.502055
# 287      MBS              45                           0.504116
# 299      MBS              50                           0.502658
# 658       HY              40                           0.523567
# 670       HY              45                           0.540501
# 682       HY              50                           0.556085
# 694       HY              55                           0.578490
# 706       HY              60                           0.591431
# 718       HY              65                           0.602753
# 730       HY              70                           0.616628
# 742       HY              75                           0.631539
# ...
