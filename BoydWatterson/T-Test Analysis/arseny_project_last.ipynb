# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Index Return_OAS Data.xlsx', sheet_name="Excess Returns %1-mo To Agg")
df1 = pd.read_excel('Index Return_OAS Data.xlsx', sheet_name="Excess Returns %1-mo To Tres")
df_OAS = pd.read_excel('Index Return_OAS Data.xlsx', sheet_name="OAS")

# %%
df.head()
df_Date = df["Date"] # storing for future use
df1_Date = df1["Date"]
df_OAS_Date = df_OAS["Date"]

# %%
#date_list = [('2008-10-31'),
             #('2008-11-30'),
             #('2008-12-31'),
             #('2009-01-31'),
             #('2009-02-06'),
             #('2009-03-06'),
             #('2009-04-06'),
             #('2009-05-31'),
             #('2009-06-06'),
             #('2009-07-06'),
             #('2009-08-06'),
             #('2009-09-06')]

#df = df.drop(date_list)
#df.drop(pd.to_datetime('2008-10-31 00:00:00'))

# %% [markdown]
# # Drop Outliers!

# %%
df = df.drop(columns = ['Date'])

q1 = df.quantile(0.25)
q3 = df.quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

print(lower_bound)
print(upper_bound)

df = df[(df > lower_bound) & (df < upper_bound)] # gets rid of outliers on Agg Excess Returns
df['Date'] = df_Date
df.head()
# Out:
# ICE BofA CCC & Lower US High Yield Index         -6.939525
# ICE BofA AAA US Fixed Rate CMBS Index            -1.035275
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   -1.911475
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   -1.102325
# ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   -1.173663
#                                                     ...
# ICE BofA Current 5-Year US Treasury Index        -1.041300
# ICE BofA Current 7-Year US Treasury Index        -1.701625
# ICE BofA Current 10-Year US Treasury Index       -2.698425
# ICE BofA Current 30-Year US Treasury Index       -6.473250
# ICE US Broad Municipal Index                     -1.702388
# Length: 74, dtype: float64
# ICE BofA CCC & Lower US High Yield Index          7.623275
# ICE BofA AAA US Fixed Rate CMBS Index             1.141925
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index    1.755325
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index    1.203875
# ...

# %%
df1 = df.drop(columns = ['Date'])

q1 = df1.quantile(0.25)
q3 = df1.quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

print(lower_bound)
print(upper_bound)

df1 = df1[(df1 > lower_bound) & (df1 < upper_bound)] # gets rid of outliers on Agg Excess Returns
df1['Date'] = df1_Date
df1.head()
# Out:
# ICE BofA CCC & Lower US High Yield Index         -6.187650
# ICE BofA AAA US Fixed Rate CMBS Index            -0.911075
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index   -1.896650
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index   -0.985450
# ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index   -0.980025
#                                                     ...
# ICE BofA Current 5-Year US Treasury Index        -0.948250
# ICE BofA Current 7-Year US Treasury Index        -1.637412
# ICE BofA Current 10-Year US Treasury Index       -2.622450
# ICE BofA Current 30-Year US Treasury Index       -6.322650
# ICE US Broad Municipal Index                     -1.511250
# Length: 74, dtype: float64
# ICE BofA CCC & Lower US High Yield Index          7.030550
# ICE BofA AAA US Fixed Rate CMBS Index             1.036325
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index    1.717750
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index    1.102950
# ...

# %%
df_OAS = df_OAS.drop(columns = ['Date'])

q1 = df_OAS.quantile(0.25)
q3 = df_OAS.quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

print(lower_bound)
print(upper_bound)

df_OAS = df_OAS[(df_OAS > lower_bound) & (df_OAS < upper_bound)] # gets rid of outliers on Agg Excess Returns
df_OAS['Date'] = df_OAS_Date
df_OAS.head(20)
# Out:
# ICE BofA CCC & Lower US High Yield Index OAS              -91.50
# ICE BofA AAA US Fixed Rate CMBS Index OAS                 -24.25
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS       -104.75
# ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS        -35.50
# ICE BofA 5-7 Year AAA US Fixed Rate CMBS Index OAS OAS    -19.75
#                                                            ...
# ICE BofA Current 3-Year US Treasury Index OAS             -10.00
# ICE BofA Current 5-Year US Treasury Index OAS             -10.00
# ICE BofA Current 10-Year US Treasury Index OAS            -36.50
# ICE BofA Current 30-Year US Treasury Index OAS            -21.75
# ICE US Broad Municipal Index OAS                          -31.50
# Length: 71, dtype: float64
# ICE BofA CCC & Lower US High Yield Index OAS              2232.50
# ICE BofA AAA US Fixed Rate CMBS Index OAS                  233.75
# ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS         341.25
# ...

# %% [markdown]
# # Drop Repeat Columns

# %%
df = df.drop(columns = ['ICE BofA US High Yield Index','ICE BofA US Corporate Index','ICE BofA Fixed Rate Preferred Securities Index','ICE BofA US Emerging Markets External Debt Sovereign & Corporate Plus Index','ICE BofA US Mortgage Backed Securities Index','ICE BofA US Mortgage Backed Securities Index'])
df = df.dropna()

# %%
df_OAS = df_OAS.drop(columns = ['ICE BofA US High Yield Index OAS','ICE BofA US Corporate Index OAS','ICE BofA Fixed Rate Preferred Securities Index OAS','ICE BofA US Emerging Markets External Debt Sovereign & Corporate Plus Index OAS','ICE BofA US Mortgage Backed Securities Index OAS','ICE BofA US Mortgage Backed Securities Index OAS'])
#df_OAS = df_OAS.dropna()

# %%
df.head()
# Out:
#      ICE BofA CCC & Lower US High Yield Index  \
# 206                                    1.6691
# 210                                    2.2313
# 213                                    1.4365
# 215                                    1.5401
# 216                                   -0.5865
#
#      ICE BofA AAA US Fixed Rate CMBS Index  \
# 206                                 0.0571
# 210                                 0.2603
# 213                                -0.1245
# 215                                 0.2041
# 216                                -0.4595
#
#      ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# 206                                          0.0791
# 210                                          0.1093
# 213                                         -0.5085
# 215                                          0.5701
# 216                                         -1.1785
#
#      ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %%
df_OAS.head()
# Out:
#    ICE BofA CCC & Lower US High Yield Index OAS  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ICE BofA AAA US Fixed Rate CMBS Index OAS  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index OAS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index OAS  \
# ...

# %% [markdown]
# # Create Excess returns

# %%
# Creating Excess Returns 3,6,9,12,24,36 for AGG
df_3_Agg = df.rolling(3,win_type='boxcar',center=True).sum().shift(-1)
df_6_Agg = df.rolling(6,win_type='boxcar',center=True).sum().shift(-3)
df_9_Agg = df.rolling(9,win_type='boxcar',center=True).sum().shift(-4)
df_12_Agg = df.rolling(12,win_type='boxcar',center=True).sum().shift(-6)
df_24_Agg = df.rolling(24,win_type='boxcar',center=True).sum().shift(-12)
df_36_Agg = df.rolling(36,win_type='boxcar',center=True).sum().shift(-18)

# %%
df_12_Agg.head()
# Out:
#      ICE BofA CCC & Lower US High Yield Index  \
# 206                                    7.4419
# 210                                    3.5178
# 213                                   -0.3614
# 215                                   -3.4205
# 216                                   -8.2822
#
#      ICE BofA AAA US Fixed Rate CMBS Index  \
# 206                                -1.0191
# 210                                -0.7622
# 213                                -1.2584
# 215                                -1.1735
# 216                                -1.5152
#
#      ICE BofA 0-3 Year AAA US Fixed Rate CMBS Index  \
# 206                                         -3.3891
# 210                                         -2.8072
# 213                                         -3.7064
# 215                                         -3.7575
# 216                                         -4.5442
#
#      ICE BofA 3-5 Year AAA US Fixed Rate CMBS Index  \
# ...

# %% [markdown]
# # Calculate Min/Max

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_3_Agg.max()
df_3_Agg_Max = column_maxes
column_mins = df_3_Agg.min()
df_3_Agg_Min = column_mins
df_3_Agg = (df_3_Agg - df_3_Agg_Min) / (df_3_Agg_Max - df_3_Agg_Min)

df_3_Agg.describe()

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_6_Agg.max()
df_6_Agg_Max = column_maxes
column_mins = df_6_Agg.min()
df_6_Agg_Min = column_mins
df_6_Agg = (df_6_Agg - df_6_Agg_Min) / (df_6_Agg_Max - df_6_Agg_Min)

df_6_Agg.describe()

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_9_Agg.max()
df_9_Agg_Max = column_maxes
column_mins = df_9_Agg.min()
df_9_Agg_Min = column_mins
df_9_Agg = (df_9_Agg - df_9_Agg_Min) / (df_9_Agg_Max - df_9_Agg_Min)

df_9_Agg.describe()

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_12_Agg.max()
df_12_Agg_Max = column_maxes
column_mins = df_12_Agg.min()
df_12_Agg_Min = column_mins
df_12_Agg = (df_12_Agg - df_12_Agg_Min) / (df_12_Agg_Max - df_12_Agg_Min)

df_12_Agg.describe()

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_24_Agg.max()
df_24_Agg_Max = column_maxes
column_mins = df_24_Agg.min()
df_24_Agg_Min = column_mins
df_24_Agg = (df_24_Agg - df_24_Agg_Min) / (df_24_Agg_Max - df_24_Agg_Min)

df_24_Agg.describe()

# %%
# Now lets normalize our data (for treasury)
column_maxes = df_36_Agg.max()
df_36_Agg_Max = column_maxes
column_mins = df_36_Agg.min()
df_36_Agg_Min = column_mins
df_36_Agg = (df_36_Agg - df_36_Agg_Min) / (df_36_Agg_Max - df_36_Agg_Min)

df_36_Agg.describe()

# %%
# Now lets normalize our OAS Data 
column_maxes = df_OAS.max()
df_OAS_Max = column_maxes
column_mins = df_OAS.min()
df_OAS_Min = column_mins
df_OAS = (df_OAS - df_OAS_Min) / (df_OAS_Max - df_OAS_Min)

df_OAS.describe()

# %%
# add dates back for natural join
df_3_Agg['Date'] = df['Date']
df_6_Agg['Date'] = df['Date']
df_9_Agg['Date'] = df['Date']
df_12_Agg['Date'] = df['Date']
df_24_Agg['Date'] = df['Date']
df_36_Agg['Date'] = df['Date']

# %%
# Joining the datasets
pd.options.display.max_columns  = 150 # want to see all columns

df_Agg_3 = pd.merge(df_3_Agg, df_OAS, on='Date', how='right')
df_Agg_6 = pd.merge(df_6_Agg, df_OAS, on='Date', how='right')
df_Agg_9 = pd.merge(df_9_Agg, df_OAS, on='Date', how='right')
df_Agg_12 = pd.merge(df_12_Agg, df_OAS, on='Date', how='right')
df_Agg_24 = pd.merge(df_24_Agg, df_OAS, on='Date', how='right')
df_Agg_36 = pd.merge(df_36_Agg, df_OAS, on='Date', how='right')

# %%
df_Agg_9.head(20)
# Out:
#     ICE BofA CCC & Lower US High Yield Index  \
# 0                                     7.8507
# 1                                     7.2709
# 2                                     3.7724
# 3                                     2.1050
# 4                                    -1.6901
# 5                                    -2.7515
# 6                                    -5.5854
# 7                                    -9.4733
# 8                                    -5.2603
# 9                                    -6.4330
# 10                                   -5.4075
# 11                                   -3.9644
# 12                                   -6.8258
# 13                                   -7.4000
# 14                                   -9.6605
# 15                                  -12.4595
# 16                                  -13.8009
# 17                                  -14.7226
# 18                                   -9.7622
# 19                                  -10.0461
#
# ...

# %%
#df_Date = df_Agg_3["Date"]
#df_Agg_3.drop()

# %%
#df_3_Agg['Date'] = df['Date']
#df_6_Agg['Date'] = df['Date']
#df_9_Agg['Date'] = df['Date']
#df_12_Agg['Date'] = df['Date']
#df_24_Agg['Date'] = df['Date']
#df_36_Agg['Date'] = df['Date']

# %%
# Drop all NaN to Keep Data consistent!
# Drop the columns where at least one element is missing.
#df_Agg_3 = df_Agg_3.dropna(axis='columns')

# %%
# TO DO:
# DROP 2007-2009
# get rid of outliers
# next Min Max that shit
# then we ready to analyze
