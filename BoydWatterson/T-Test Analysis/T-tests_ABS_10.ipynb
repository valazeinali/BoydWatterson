# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
! pip install --user researchpy
# Out:
# Requirement already satisfied: researchpy in /Users/valazeinali/.local/lib/python3.7/site-packages (0.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.4.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.18.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.0.1)
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->researchpy) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->researchpy) (2019.3)
# Requirement already satisfied: patsy>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from statsmodels->researchpy) (0.5.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->researchpy) (1.14.0)

# %%
import researchpy # for t-test stuff!

# %%
df = pd.read_csv('minmax_OAS_with_Returns_Final_NO_Outliers_ABS.csv')

# %%
df.head()
# Out:
#                   Date       OAS Total Return % 1-mo-LOC Agg Returns  \
# 0  1997-01-31 00:00:00  0.042424                 #VALUE!     #VALUE!
# 1  1997-02-28 00:00:00  0.030303                 #VALUE!     #VALUE!
# 2  1997-03-31 00:00:00  0.000000                 #VALUE!     #VALUE!
# 3  1997-04-30 00:00:00  0.024242                 #VALUE!     #VALUE!
# 4  1997-05-31 00:00:00  0.042424                 #VALUE!     #VALUE!
#
#    Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 0                         0.492825                    0.592149
# 1                         0.578927                    0.558017
# 2                         0.580438                    0.872439
# 3                         0.344789                    0.347304
# 4                         0.246601                    0.439709
#
#    Excess Return % 3-mo (Treasury)  Excess Return % 3-mo (Agg)  \
# 0                         0.576450                    0.738316
# 1                         0.514660                    0.624385
# 2                         0.375946                    0.569335
# 3                         0.305958                    0.347329
# 4                         0.341267                    0.257878
#
#    Excess Return % 6-mo (Treasury)  Excess Return % 6-mo (Agg)  \
# 0                         0.411216                    0.554485
# 1                         0.395695                    0.415181
# 2                         0.390152                    0.488696
# 3                         0.290743                    0.310726
# 4                         0.232354                    0.301562
#
#    Excess Return % 9-mo (Treasury)  Excess Return % 9-mo (Agg)  \
# 0                         0.367785                    0.483998
# 1                         0.289185                    0.404881
# 2                         0.212427                    0.369817
# 3                         0.209971                    0.260192
# 4                         0.217954                    0.296403
#
#    Excess Return % 12-mo (Treasury)  Excess Return % 12-mo (Agg)  \
# 0                          0.296604                     0.406063
# 1                          0.278218                     0.374875
# 2                          0.252937                     0.376553
# 3                          0.252681                     0.305611
# 4                          0.299157                     0.361117
#
#    Excess Return % 24-mo (Treasury)  Excess Return % 24-mo (Agg)  \
# 0                          0.181587                     0.370326
# 1                          0.161709                     0.338374
# 2                          0.251378                     0.443947
# 3                          0.243253                     0.382426
# 4                          0.265888                     0.431798
#
#    Excess Return % 36-mo (Treasury)  Excess Return % 36-mo (Agg)  Quadrant
# 0                          0.323947                     0.773659         4
# 1                          0.319785                     0.783264         4
# 2                          0.315132                     0.745390         4
# 3                          0.277057                     0.639667         4
# 4                          0.222821                     0.677654         4

# %%
df = df.drop(columns=["Total Return % 1-mo-LOC", "Agg Returns" ,
"Excess Return % 1-mo (Treasury)", "Excess Return % 1-mo (Agg)"], axis = 0) # get rid of these useless columns

# %%
df.describe()
# Out:
#               OAS  Excess Return % 3-mo (Treasury)  \
# count  277.000000                       278.000000
# mean     0.384531                         0.496887
# std      0.255453                         0.250317
# min      0.000000                         0.000000
# 25%      0.181818                         0.375000
# 50%      0.327273                         0.502995
# 75%      0.509091                         0.625000
# max      1.000000                         1.000000
#
#        Excess Return % 3-mo (Agg)  Excess Return % 6-mo (Treasury)  \
# count                  278.000000                       275.000000
# mean                     0.499424                         0.470617
# std                      0.183671                         0.252012
# min                      0.000000                        -0.581118
# 25%                      0.375000                         0.377956
# 50%                      0.487146                         0.472931
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 6-mo (Agg)  Excess Return % 9-mo (Treasury)  \
# count                  275.000000                       272.000000
# mean                     0.492462                         0.480718
# std                      0.194628                         0.242491
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.492441                         0.471254
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 9-mo (Agg)  Excess Return % 12-mo (Treasury)  \
# count                  272.000000                        269.000000
# mean                     0.500017                          0.489680
# std                      0.212772                          0.246996
# min                      0.000000                          0.000000
# 25%                      0.375000                          0.375000
# 50%                      0.507368                          0.490169
# 75%                      0.625000                          0.625000
# max                      1.000000                          1.000000
#
#        Excess Return % 12-mo (Agg)  Excess Return % 24-mo (Treasury)  \
# count                   269.000000                        257.000000
# mean                      0.492247                          0.481544
# std                       0.213931                          0.244801
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.499027                          0.496155
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 24-mo (Agg)  Excess Return % 36-mo (Treasury)  \
# count                   257.000000                        245.000000
# mean                      0.484984                          0.495937
# std                       0.213747                          0.269899
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.491617                          0.549094
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 36-mo (Agg)   Quadrant
# count                   245.000000  279.00000
# mean                      0.532766    2.55914
# std                       0.216243    1.08418
# min                       0.000000    1.00000
# 25%                       0.424237    2.00000
# 50%                       0.549190    3.00000
# 75%                       0.707061    3.00000
# max                       1.000000    4.00000

# %% [markdown]
# # drop outliers that we have identified as 0 and 1s (1 is > upper fence, 0 is < lower fence)

# %%
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])

df = df.dropna()

df['OAS'] = pd.to_numeric(df['OAS'],errors='coerce') # converting back to float64 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              245 non-null    object
#  1   OAS                               221 non-null    float64
#  2   Excess Return % 3-mo (Treasury)   245 non-null    float64
#  3   Excess Return % 3-mo (Agg)        245 non-null    float64
#  4   Excess Return % 6-mo (Treasury)   245 non-null    float64
#  5   Excess Return % 6-mo (Agg)        245 non-null    float64
#  6   Excess Return % 9-mo (Treasury)   245 non-null    float64
#  7   Excess Return % 9-mo (Agg)        245 non-null    float64
#  8   Excess Return % 12-mo (Treasury)  245 non-null    float64
#  9   Excess Return % 12-mo (Agg)       245 non-null    float64
#  10  Excess Return % 24-mo (Treasury)  245 non-null    float64
#  11  Excess Return % 24-mo (Agg)       245 non-null    float64
#  12  Excess Return % 36-mo (Treasury)  245 non-null    float64
#  13  Excess Return % 36-mo (Agg)       245 non-null    float64
#  14  Quadrant                          245 non-null    int64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 30.6+ KB

# %% [markdown]
# # Now lets select all OAS levels and their coresponding excess returns that are above the 90th percentile (top 10%)

# %%
# Select * 
# From OAS
# Where OAS >= 90th percentile
## SQL version above ## 
highspread = df["OAS"].quantile(.90) # every data point over the 90th percentile
print(highspread)

# pandas version of the SQL function 
df = df[(df['OAS'] > highspread)]
# Out:
# 0.56969697

# %%
df.describe()
# Out:
#              OAS  Excess Return % 3-mo (Treasury)  Excess Return % 3-mo (Agg)  \
# count  22.000000                        22.000000                   22.000000
# mean    0.698072                         0.647462                    0.492227
# std     0.119843                         0.350835                    0.164370
# min     0.575758                         0.000000                    0.203199
# 25%     0.596970                         0.415826                    0.386081
# 50%     0.681818                         0.733764                    0.528632
# 75%     0.745455                         0.998305                    0.583768
# max     0.987879                         1.000000                    0.763733
#
#        Excess Return % 6-mo (Treasury)  Excess Return % 6-mo (Agg)  \
# count                        22.000000                   22.000000
# mean                          0.647215                    0.477477
# std                           0.307728                    0.199906
# min                           0.000000                    0.047883
# 25%                           0.633222                    0.372500
# 50%                           0.694845                    0.500094
# 75%                           0.803585                    0.610844
# max                           1.000000                    0.772805
#
#        Excess Return % 9-mo (Treasury)  Excess Return % 9-mo (Agg)  \
# count                        22.000000                   22.000000
# mean                          0.638654                    0.466414
# std                           0.310496                    0.223041
# min                           0.000000                    0.000000
# 25%                           0.543714                    0.383784
# 50%                           0.639661                    0.481799
# 75%                           0.872851                    0.560176
# max                           1.000000                    0.850337
#
#        Excess Return % 12-mo (Treasury)  Excess Return % 12-mo (Agg)  \
# count                         22.000000                    22.000000
# mean                           0.644762                     0.456021
# std                            0.320228                     0.235484
# min                            0.000000                     0.000000
# 25%                            0.495340                     0.411387
# 50%                            0.683478                     0.469304
# 75%                            0.893195                     0.520666
# max                            1.000000                     0.911122
#
#        Excess Return % 24-mo (Treasury)  Excess Return % 24-mo (Agg)  \
# count                         22.000000                    22.000000
# mean                           0.549672                     0.371009
# std                            0.263979                     0.232465
# min                            0.000000                     0.000000
# 25%                            0.482879                     0.222787
# 50%                            0.625725                     0.377656
# 75%                            0.702300                     0.429179
# max                            0.979469                     0.804748
#
#        Excess Return % 36-mo (Treasury)  Excess Return % 36-mo (Agg)  \
# count                         22.000000                    22.000000
# mean                           0.649909                     0.425513
# std                            0.262739                     0.220088
# min                            0.003673                     0.030134
# 25%                            0.559776                     0.328856
# 50%                            0.680766                     0.420199
# 75%                            0.821988                     0.489287
# max                            1.000000                     0.879829
#
#         Quadrant
# count  22.000000
# mean    1.772727
# std     0.972567
# min     1.000000
# 25%     1.000000
# 50%     1.500000
# 75%     2.000000
# max     4.000000

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 3-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 3-mo (Treasury)  22.0  0.647462  0.350835  0.074798
#  2                         combined  44.0  0.672767  0.260347  0.039249
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.491911  0.803014
#  2   0.593614  0.751920  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 3-mo (Treasu...   0.0506
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    0.6403
#  3                           Two side test p value =    0.5255
#  4                          Difference < 0 p value =    0.7373
#  5                          Difference > 0 p value =    0.2627
#  6                                       Cohen's d =    0.1931
#  7                                       Hedge's g =    0.1896
#  8                                   Glass's delta =    0.4223
#  9                                               r =    0.0983)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 3-mo (Treasury)"], color="red", label="3M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 3-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 3-mo (Agg)  22.0  0.492227  0.164370  0.035044   0.419349
#  2                    combined  44.0  0.595149  0.176205  0.026564   0.541578
#
#     Interval
#  0  0.751207
#  1  0.565104
#  2  0.648720  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 3-mo (Agg)) =    0.2058
#  1                             Degrees of freedom =   42.0000
#  2                                              t =    4.7463
#  3                          Two side test p value =    0.0000
#  4                         Difference < 0 p value =    1.0000
#  5                         Difference > 0 p value =    0.0000
#  6                                      Cohen's d =    1.4311
#  7                                      Hedge's g =    1.4054
#  8                                  Glass's delta =    1.7176
#  9                                              r =    0.5909)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 3-mo (Agg)"], color="red", label="3M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 6-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 6-mo (Treasury)  22.0  0.647215  0.307728  0.065608
#  2                         combined  44.0  0.672643  0.232213  0.035007
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.510776  0.783654
#  2   0.602044  0.743243  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 6-mo (Treasu...   0.0509
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    0.7223
#  3                           Two side test p value =    0.4741
#  4                          Difference < 0 p value =    0.7629
#  5                          Difference > 0 p value =    0.2371
#  6                                       Cohen's d =    0.2178
#  7                                       Hedge's g =    0.2139
#  8                                   Glass's delta =    0.4244
#  9                                               r =    0.1108)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 6-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 6-mo (Agg)  22.0  0.477477  0.199906  0.042620   0.388843
#  2                    combined  44.0  0.587774  0.197431  0.029764   0.527750
#
#     Interval
#  0  0.751207
#  1  0.566110
#  2  0.647799  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 6-mo (Agg)) =    0.2206
#  1                             Degrees of freedom =   42.0000
#  2                                              t =    4.4392
#  3                          Two side test p value =    0.0001
#  4                         Difference < 0 p value =    1.0000
#  5                         Difference > 0 p value =    0.0000
#  6                                      Cohen's d =    1.3385
#  7                                      Hedge's g =    1.3144
#  8                                  Glass's delta =    1.8407
#  9                                              r =    0.5651)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 6-mo (Agg)"], color="red", label="6M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 9-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 9-mo (Treasury)  22.0  0.638654  0.310496  0.066198
#  2                         combined  44.0  0.668363  0.234521  0.035355
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.500988  0.776320
#  2   0.597062  0.739664  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 9-mo (Treasu...   0.0594
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    0.8374
#  3                           Two side test p value =    0.4071
#  4                          Difference < 0 p value =    0.7964
#  5                          Difference > 0 p value =    0.2036
#  6                                       Cohen's d =    0.2525
#  7                                       Hedge's g =    0.2479
#  8                                   Glass's delta =    0.4958
#  9                                               r =    0.1281)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 9-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 9-mo (Agg)  22.0  0.466414  0.223041  0.047553   0.367523
#  2                    combined  44.0  0.582243  0.212221  0.031994   0.517722
#
#     Interval
#  0  0.751207
#  1  0.565305
#  2  0.646764  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 9-mo (Agg)) =    0.2317
#  1                             Degrees of freedom =   42.0000
#  2                                              t =    4.2914
#  3                          Two side test p value =    0.0001
#  4                         Difference < 0 p value =    0.9999
#  5                         Difference > 0 p value =    0.0001
#  6                                      Cohen's d =    1.2939
#  7                                      Hedge's g =    1.2707
#  8                                  Glass's delta =    1.9330
#  9                                              r =    0.5521)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 9-mo (Agg)"], color="red", label="9M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 12-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 12-mo (Treasury)  22.0  0.644762  0.320228  0.068273
#  2                          combined  44.0  0.671417  0.240462  0.036251
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.502780  0.786743
#  2   0.598310  0.744524  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 12-mo (Treas...   0.0533
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    0.7313
#  3                           Two side test p value =    0.4687
#  4                          Difference < 0 p value =    0.7657
#  5                          Difference > 0 p value =    0.2343
#  6                                       Cohen's d =    0.2205
#  7                                       Hedge's g =    0.2165
#  8                                   Glass's delta =    0.4448
#  9                                               r =    0.1121)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 12-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 12-mo (Agg)  22.0  0.456021  0.235484  0.050205   0.351613
#  2                     combined  44.0  0.577046  0.221548  0.033400   0.509690
#
#     Interval
#  0  0.751207
#  1  0.560429
#  2  0.644403  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 12-mo (Agg)) =    0.2421
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    4.2968
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
#  6                                       Cohen's d =    1.2955
#  7                                       Hedge's g =    1.2723
#  8                                   Glass's delta =    2.0197
#  9                                               r =    0.5526)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 12-mo (Agg)"], color="red", label="12M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 24-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 24-mo (Treasury)  22.0  0.549672  0.263979  0.056280
#  2                          combined  44.0  0.623872  0.216055  0.032572
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.432631  0.666714
#  2   0.558185  0.689559  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 24-mo (Treas...   0.1484
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    2.4009
#  3                           Two side test p value =    0.0209
#  4                          Difference < 0 p value =    0.9896
#  5                          Difference > 0 p value =    0.0104
#  6                                       Cohen's d =    0.7239
#  7                                       Hedge's g =    0.7109
#  8                                   Glass's delta =    1.2383
#  9                                               r =    0.3474)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 24-mo (Treasury)"], color="red", label="24M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 24-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 24-mo (Agg)  22.0  0.371009  0.232465  0.049562   0.267939
#  2                     combined  44.0  0.534540  0.246516  0.037164   0.459592
#
#     Interval
#  0  0.751207
#  1  0.474078
#  2  0.609488  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 24-mo (Agg)) =    0.3271
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    5.8655
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.7685
#  7                                       Hedge's g =    1.7368
#  8                                   Glass's delta =    2.7291
#  9                                               r =    0.6710)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 24-mo (Agg)"], color="red", label="24M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 36-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 36-mo (Treasury)  22.0  0.649909  0.262739  0.056016
#  2                          combined  44.0  0.673990  0.203275  0.030645
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.533417  0.766401
#  2   0.612189  0.735792  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 36-mo (Treas...   0.0482
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    0.7823
#  3                           Two side test p value =    0.4384
#  4                          Difference < 0 p value =    0.7808
#  5                          Difference > 0 p value =    0.2192
#  6                                       Cohen's d =    0.2359
#  7                                       Hedge's g =    0.2316
#  8                                   Glass's delta =    0.4019
#  9                                               r =    0.1198)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 36-mo (Treasury)"], color="red", label="36M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 36-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 36-mo (Agg)  22.0  0.425513  0.220088  0.046923   0.327932
#  2                     combined  44.0  0.561793  0.222877  0.033600   0.494032
#
#     Interval
#  0  0.751207
#  1  0.523095
#  2  0.629553  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 36-mo (Agg)) =    0.2726
#  1                              Degrees of freedom =   42.0000
#  2                                               t =    5.1014
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.5381
#  7                                       Hedge's g =    1.5105
#  8                                   Glass's delta =    2.2743
#  9                                               r =    0.6185)

# %%
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df["Excess Return % 36-mo (Agg)"], color="red", label="36M_Agg._Normalized_Value")

# %% [markdown]
# # Now lets run the same t-test but with High spreads to all returns

# %%
df1 = pd.read_csv('minmax_OAS_with_Returns_Final_NO_Outliers_ABS.csv')

# %%
df1.describe()
# Out:
#               OAS  Excess Return % 1-mo (Treasury)  \
# count  277.000000                       279.000000
# mean     0.384531                         0.492726
# std      0.255453                         0.250628
# min      0.000000                         0.000000
# 25%      0.181818                         0.375000
# 50%      0.327273                         0.495846
# 75%      0.509091                         0.625000
# max      1.000000                         1.000000
#
#        Excess Return % 1-mo (Agg)  Excess Return % 3-mo (Treasury)  \
# count                  279.000000                       278.000000
# mean                     0.501825                         0.496887
# std                      0.200742                         0.250317
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.503522                         0.502995
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 3-mo (Agg)  Excess Return % 6-mo (Treasury)  \
# count                  278.000000                       275.000000
# mean                     0.499424                         0.470617
# std                      0.183671                         0.252012
# min                      0.000000                        -0.581118
# 25%                      0.375000                         0.377956
# 50%                      0.487146                         0.472931
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 6-mo (Agg)  Excess Return % 9-mo (Treasury)  \
# count                  275.000000                       272.000000
# mean                     0.492462                         0.480718
# std                      0.194628                         0.242491
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.492441                         0.471254
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 9-mo (Agg)  Excess Return % 12-mo (Treasury)  \
# count                  272.000000                        269.000000
# mean                     0.500017                          0.489680
# std                      0.212772                          0.246996
# min                      0.000000                          0.000000
# 25%                      0.375000                          0.375000
# 50%                      0.507368                          0.490169
# 75%                      0.625000                          0.625000
# max                      1.000000                          1.000000
#
#        Excess Return % 12-mo (Agg)  Excess Return % 24-mo (Treasury)  \
# count                   269.000000                        257.000000
# mean                      0.492247                          0.481544
# std                       0.213931                          0.244801
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.499027                          0.496155
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 24-mo (Agg)  Excess Return % 36-mo (Treasury)  \
# count                   257.000000                        245.000000
# mean                      0.484984                          0.495937
# std                       0.213747                          0.269899
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.491617                          0.549094
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 36-mo (Agg)   Quadrant
# count                   245.000000  279.00000
# mean                      0.532766    2.55914
# std                       0.216243    1.08418
# min                       0.000000    1.00000
# 25%                       0.424237    2.00000
# 50%                       0.549190    3.00000
# 75%                       0.707061    3.00000
# max                       1.000000    4.00000

# %%
des, res = researchpy.ttest(df['OAS'], 
df1['Excess Return % 3-mo (Treasury)']) # notice we are using the High Spread Data for OAS

des, res
# Out:
# (                          Variable      N      Mean        SD        SE  \
#  0                              OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 3-mo (Treasury)  278.0  0.496887  0.250317  0.015013
#  2                         combined  300.0  0.511641  0.248630  0.014355
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.467333  0.526441
#  2   0.483392  0.539890  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 3-mo (Treasu...    0.2012
#  1                              Degrees of freedom =   298.0000
#  2                                               t =     3.7317
#  3                           Two side test p value =     0.0002
#  4                          Difference < 0 p value =     0.9999
#  5                          Difference > 0 p value =     0.0001
#  6                                       Cohen's d =     0.8265
#  7                                       Hedge's g =     0.8244
#  8                                   Glass's delta =     1.6787
#  9                                               r =     0.2113)

# %%
df1["Excess Return % 3-mo (Treasury)"] = df1["Excess Return % 3-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 3-mo (Treasury)"] = df1["Excess Return % 3-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 3-mo (Treasury)"], color="red", label="3M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 3-mo (Agg)'])

des, res
# Out:
# (                     Variable      N      Mean        SD        SE  95% Conf.  \
#  0                         OAS   22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 3-mo (Agg)  278.0  0.499424  0.183671  0.011016   0.477739
#  2                    combined  300.0  0.513992  0.186955  0.010794   0.492750
#
#     Interval
#  0  0.751207
#  1  0.521110
#  2  0.535233  ,
#                                   Independent t-test   results
#  0  Difference (OAS - Excess Return % 3-mo (Agg)) =     0.1986
#  1                             Degrees of freedom =   298.0000
#  2                                              t =     4.9852
#  3                          Two side test p value =     0.0000
#  4                         Difference < 0 p value =     1.0000
#  5                         Difference > 0 p value =     0.0000
#  6                                      Cohen's d =     1.1041
#  7                                      Hedge's g =     1.1013
#  8                                  Glass's delta =     1.6576
#  9                                              r =     0.2774)

# %%
df1["Excess Return % 3-mo (Agg)"] = df1["Excess Return % 3-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 3-mo (Agg)"] = df1["Excess Return % 3-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 3-mo (Agg)"], color="red", label="3M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 6-mo (Treasury)'])

des, res
# Out:
# (                          Variable      N      Mean        SD        SE  \
#  0                              OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 6-mo (Treasury)  275.0  0.470617  0.252012  0.015197
#  2                         combined  297.0  0.487466  0.251732  0.014607
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.440700  0.500535
#  2   0.458719  0.516213  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 6-mo (Treasu...    0.2275
#  1                              Degrees of freedom =   295.0000
#  2                                               t =     4.1906
#  3                           Two side test p value =     0.0000
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
#  6                                       Cohen's d =     0.9285
#  7                                       Hedge's g =     0.9261
#  8                                   Glass's delta =     1.8979
#  9                                               r =     0.2370)

# %%
df1["Excess Return % 6-mo (Treasury)"] = df1["Excess Return % 6-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 6-mo (Treasury)"] = df1["Excess Return % 6-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 6-mo (Treasury)"], color="red", label="6M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 6-mo (Agg)'])

des, res
# Out:
# (                     Variable      N      Mean        SD        SE  95% Conf.  \
#  0                         OAS   22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 6-mo (Agg)  275.0  0.492462  0.194628  0.011736   0.469357
#  2                    combined  297.0  0.507692  0.197466  0.011458   0.485142
#
#     Interval
#  0  0.751207
#  1  0.515567
#  2  0.530242  ,
#                                   Independent t-test   results
#  0  Difference (OAS - Excess Return % 6-mo (Agg)) =     0.2056
#  1                             Degrees of freedom =   295.0000
#  2                                              t =     4.8770
#  3                          Two side test p value =     0.0000
#  4                         Difference < 0 p value =     1.0000
#  5                         Difference > 0 p value =     0.0000
#  6                                      Cohen's d =     1.0806
#  7                                      Hedge's g =     1.0778
#  8                                  Glass's delta =     1.7157
#  9                                              r =     0.2732)

# %%
df1["Excess Return % 6-mo (Agg)"] = df1["Excess Return % 6-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 6-mo (Agg)"] = df1["Excess Return % 6-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 6-mo (Agg)"], color="red", label="6M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 9-mo (Treasury)'])

des, res
# Out:
# (                          Variable      N      Mean        SD        SE  \
#  0                              OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 9-mo (Treasury)  272.0  0.480718  0.242491  0.014703
#  2                         combined  294.0  0.496983  0.242276  0.014130
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.451771  0.509665
#  2   0.469174  0.524791  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 9-mo (Treasu...    0.2174
#  1                              Degrees of freedom =   292.0000
#  2                                               t =     4.1584
#  3                           Two side test p value =     0.0000
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
#  6                                       Cohen's d =     0.9217
#  7                                       Hedge's g =     0.9194
#  8                                   Glass's delta =     1.8137
#  9                                               r =     0.2365)

# %%
df1["Excess Return % 9-mo (Treasury)"] = df1["Excess Return % 9-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 9-mo (Treasury)"] = df1["Excess Return % 9-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 9-mo (Treasury)"], color="red", label="9M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 9-mo (Agg)'])

des, res
# Out:
# (                     Variable      N      Mean        SD        SE  95% Conf.  \
#  0                         OAS   22.0  0.698072  0.119843  0.025551   0.644936
#  1  Excess Return % 9-mo (Agg)  272.0  0.500017  0.212772  0.012901   0.474618
#  2                    combined  294.0  0.514838  0.213604  0.012458   0.490320
#
#     Interval
#  0  0.751207
#  1  0.525416
#  2  0.539355  ,
#                                   Independent t-test   results
#  0  Difference (OAS - Excess Return % 9-mo (Agg)) =     0.1981
#  1                             Degrees of freedom =   292.0000
#  2                                              t =     4.3065
#  3                          Two side test p value =     0.0000
#  4                         Difference < 0 p value =     1.0000
#  5                         Difference > 0 p value =     0.0000
#  6                                      Cohen's d =     0.9546
#  7                                      Hedge's g =     0.9521
#  8                                  Glass's delta =     1.6526
#  9                                              r =     0.2444)

# %%
df1["Excess Return % 9-mo (Agg)"] = df1["Excess Return % 9-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 9-mo (Agg)"] = df1["Excess Return % 9-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 9-mo (Agg)"], color="red", label="9M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 12-mo (Treasury)'])

des, res
# Out:
# (                           Variable      N      Mean        SD        SE  \
#  0                               OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 12-mo (Treasury)  269.0  0.489680  0.246996  0.015060
#  2                          combined  291.0  0.505434  0.245895  0.014415
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.460029  0.519330
#  2   0.477064  0.533805  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 12-mo (Treas...    0.2084
#  1                              Degrees of freedom =   289.0000
#  2                                               t =     3.9151
#  3                           Two side test p value =     0.0001
#  4                          Difference < 0 p value =     0.9999
#  5                          Difference > 0 p value =     0.0001
#  6                                       Cohen's d =     0.8682
#  7                                       Hedge's g =     0.8659
#  8                                   Glass's delta =     1.7389
#  9                                               r =     0.2244)

# %%
df1["Excess Return % 12-mo (Treasury)"] = df1["Excess Return % 12-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 12-mo (Treasury)"] = df1["Excess Return % 12-mo (Treasury)"].replace([1],["NaN"])
plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 12-mo (Treasury)"], color="red", label="12M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 12-mo (Agg)'])

des, res
# Out:
# (                      Variable      N      Mean        SD        SE  \
#  0                          OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 12-mo (Agg)  269.0  0.492247  0.213931  0.013044
#  2                     combined  291.0  0.507807  0.215187  0.012614
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.466566  0.517928
#  2   0.482980  0.532635  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 12-mo (Agg)) =     0.2058
#  1                              Degrees of freedom =   289.0000
#  2                                               t =     4.4511
#  3                           Two side test p value =     0.0000
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
#  6                                       Cohen's d =     0.9870
#  7                                       Hedge's g =     0.9845
#  8                                   Glass's delta =     1.7175
#  9                                               r =     0.2533)

# %%
df1["Excess Return % 12-mo (Agg)"] = df1["Excess Return % 12-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 12-mo (Agg)"] = df1["Excess Return % 12-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 12-mo (Agg)"], color="red", label="12M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 24-mo (Treasury)'])

des, res
# Out:
# (                           Variable      N      Mean        SD        SE  \
#  0                               OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 24-mo (Treasury)  257.0  0.481544  0.244801  0.015270
#  2                          combined  279.0  0.498618  0.244310  0.014626
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.451473  0.511615
#  2   0.469825  0.527411  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 24-mo (Treas...    0.2165
#  1                              Degrees of freedom =   277.0000
#  2                                               t =     4.1017
#  3                           Two side test p value =     0.0001
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
#  6                                       Cohen's d =     0.9112
#  7                                       Hedge's g =     0.9087
#  8                                   Glass's delta =     1.8068
#  9                                               r =     0.2393)

# %%
df1["Excess Return % 24-mo (Treasury)"] = df1["Excess Return % 24-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 24-mo (Treasury)"] = df1["Excess Return % 24-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 24-mo (Treasury)"], color="red", label="24M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 24-mo (Agg)'])

des, res
# Out:
# (                      Variable      N      Mean        SD        SE  \
#  0                          OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 24-mo (Agg)  257.0  0.484984  0.213747  0.013333
#  2                     combined  279.0  0.501787  0.215562  0.012905
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.458727  0.511241
#  2   0.476382  0.527191  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 24-mo (Agg)) =     0.2131
#  1                              Degrees of freedom =   277.0000
#  2                                               t =     4.6092
#  3                           Two side test p value =     0.0000
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
#  6                                       Cohen's d =     1.0239
#  7                                       Hedge's g =     1.0211
#  8                                   Glass's delta =     1.7781
#  9                                               r =     0.2669)

# %%
df1["Excess Return % 24-mo (Agg)"] = df1["Excess Return % 24-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 24-mo (Agg)"] = df1["Excess Return % 24-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 24-mo (Agg)"], color="red", label="24M_Agg._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 36-mo (Treasury)'])

des, res
# Out:
# (                           Variable      N      Mean        SD        SE  \
#  0                               OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 36-mo (Treasury)  245.0  0.495937  0.269899  0.017243
#  2                          combined  267.0  0.512592  0.266562  0.016313
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.461972  0.529901
#  2   0.480472  0.544712  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 36-mo (Treas...    0.2021
#  1                              Degrees of freedom =   265.0000
#  2                                               t =     3.4774
#  3                           Two side test p value =     0.0006
#  4                          Difference < 0 p value =     0.9997
#  5                          Difference > 0 p value =     0.0003
#  6                                       Cohen's d =     0.7740
#  7                                       Hedge's g =     0.7718
#  8                                   Glass's delta =     1.6867
#  9                                               r =     0.2089)

# %%
df1["Excess Return % 36-mo (Treasury)"] = df1["Excess Return % 36-mo (Treasury)"].replace([0],["NaN"])
df1["Excess Return % 36-mo (Treasury)"] = df1["Excess Return % 36-mo (Treasury)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 36-mo (Treasury)"], color="red", label="36M_Tres._Normalized_Value")

# %%
des, res = researchpy.ttest(df['OAS'], df1['Excess Return % 36-mo (Agg)'])

des, res
# Out:
# (                      Variable      N      Mean        SD        SE  \
#  0                          OAS   22.0  0.698072  0.119843  0.025551
#  1  Excess Return % 36-mo (Agg)  245.0  0.532766  0.216243  0.013815
#  2                     combined  267.0  0.546387  0.214712  0.013140
#
#     95% Conf.  Interval
#  0   0.644936  0.751207
#  1   0.505554  0.559978
#  2   0.520515  0.572259  ,
#                                    Independent t-test   results
#  0  Difference (OAS - Excess Return % 36-mo (Agg)) =     0.1653
#  1                              Degrees of freedom =   265.0000
#  2                                               t =     3.5330
#  3                           Two side test p value =     0.0005
#  4                          Difference < 0 p value =     0.9998
#  5                          Difference > 0 p value =     0.0002
#  6                                       Cohen's d =     0.7863
#  7                                       Hedge's g =     0.7841
#  8                                   Glass's delta =     1.3794
#  9                                               r =     0.2121)

# %%
df1["Excess Return % 36-mo (Agg)"] = df1["Excess Return % 36-mo (Agg)"].replace([0],["NaN"])
df1["Excess Return % 36-mo (Agg)"] = df1["Excess Return % 36-mo (Agg)"].replace([1],["NaN"])

plt.figure(figsize=(22.5,10))
sns.distplot(df["OAS"], color="skyblue", label="OAS_Normalized_Value")
sns.distplot(df1["Excess Return % 36-mo (Agg)"], color="red", label="36M_Agg._Normalized_Value")
