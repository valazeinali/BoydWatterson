# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Arseny_Project.xlsx', sheet_name="MBS_Agg")

# %%
df.head()
df_copy = df.copy()

# %%
df.head(6)
# Out:
#         Date  ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0 1997-01-31                                                 32
# 1 1997-02-28                                                 32
# 2 1997-03-31                                                 39
# 3 1997-04-30                                                 33
# 4 1997-05-31                                                 32
# 5 1997-06-30                                                 29
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
# 5                                                 29
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 19 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Date                                                           269 non-null    datetime64[ns]
#  1   ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS      269 non-null    int64
#  2   ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS      269 non-null    int64
#  3   ICE BofA US 15-Year Mortgage Backed Securities Index OAS       269 non-null    int64
#  4   ICE BofA US 30-Year Mortgage Backed Securities Index OAS       269 non-null    int64
#  5   ICE BofA US FNMA Mortgage Backed Securities Index OAS          269 non-null    int64
#  6   ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS  269 non-null    int64
# ...

# %%
df.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           47.732342
# std                                            33.699989
# min                                           -26.000000
# 25%                                            24.000000
# 50%                                            44.000000
# 75%                                            62.000000
# max                                           173.000000
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           52.431227
# std                                            29.909065
# min                                             8.000000
# 25%                                            28.000000
# 50%                                            49.000000
# ...

# %% [markdown]
# # Drop Outliers!

# %%
df = df.drop(columns = ['Date'])

#q1 = df.quantile(0.25)
#q3 = df.quantile(0.75)

#iqr = q3 - q1

#lower_bound = q1 -(1.5 * iqr) 
#upper_bound = q3 +(1.5 * iqr)

#print(lower_bound)
#print(upper_bound)

#df = df[(df > lower_bound) & (df < upper_bound)] # gets rid of outliers on Agg Excess Returns
#df['Date'] = df_Date
#df.head()

# %%
def lower_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    lower_bounds = q1 -(1.5 * iqr) 
    
    return lower_bounds

# %%
def upper_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    upper_bounds = q3 +(1.5 * iqr) 
    
    return upper_bounds

# %%
lower_bound(df)
# Out:
# ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS       -33.000000
# ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS       -33.500000
# ICE BofA US 15-Year Mortgage Backed Securities Index OAS        -44.000000
# ICE BofA US 30-Year Mortgage Backed Securities Index OAS        -20.500000
# ICE BofA US FNMA Mortgage Backed Securities Index OAS           -25.500000
# ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS   -43.000000
# ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS   -19.000000
# ICE BofA US GNMA Mortgage Backed Securities Index OAS           -28.000000
# ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS   -28.000000
# ICE BofA 0-3 Year US Mortgage Backed Securities Index            -0.018025
# ICE BofA 3-5 Year US Mortgage Backed Securities Index            -0.011117
# ICE BofA US 15-Year Mortgage Backed Securities Index             -0.008909
# ...

# %%
upper_bound(df)
# Out:
# ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS        119.000000
# ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS        130.500000
# ICE BofA US 15-Year Mortgage Backed Securities Index OAS         132.000000
# ICE BofA US 30-Year Mortgage Backed Securities Index OAS         111.500000
# ICE BofA US FNMA Mortgage Backed Securities Index OAS            114.500000
# ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS    125.000000
# ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS    109.000000
# ICE BofA US GNMA Mortgage Backed Securities Index OAS            108.000000
# ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS    108.000000
# ICE BofA 0-3 Year US Mortgage Backed Securities Index              0.015827
# ICE BofA 3-5 Year US Mortgage Backed Securities Index              0.010110
# ICE BofA US 15-Year Mortgage Backed Securities Index               0.008246
# ...

# %%
df["Date"] = df_copy["Date"]
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
df.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           47.732342
# std                                            33.699989
# min                                           -26.000000
# 25%                                            24.000000
# 50%                                            44.000000
# 75%                                            62.000000
# max                                           173.000000
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           52.431227
# std                                            29.909065
# min                                             8.000000
# 25%                                            28.000000
# 50%                                            49.000000
# ...

# %%
df1 = df.drop(columns = ['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS','ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS','ICE BofA US 15-Year Mortgage Backed Securities Index OAS','ICE BofA US 30-Year Mortgage Backed Securities Index OAS','ICE BofA US FNMA Mortgage Backed Securities Index OAS','ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS','ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS','ICE BofA US GNMA Mortgage Backed Securities Index OAS','ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'])

# %%
df1.head(36)
# Out:
#     ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                            0.002748
# 1                                            0.000312
# 2                                            0.008472
# 3                                           -0.007949
# 4                                           -0.003343
# 5                                           -0.005179
# 6                                           -0.018723
# 7                                            0.012296
# 8                                           -0.008158
# 9                                           -0.008437
# 10                                          -0.001675
# 11                                          -0.003598
# 12                                          -0.004668
# 13                                           0.003683
# 14                                           0.000444
# 15                                           0.000590
# ...

# %% [markdown]
# # Create Excess returns

# %%
# Creating Excess Returns 3,6,9,12,24,36 for AGG
df_3_Agg = df1.rolling(3,win_type='boxcar',center=True).sum().shift(-1)
df_6_Agg = df1.rolling(6,win_type='boxcar',center=True).sum().shift(-3)
df_9_Agg = df1.rolling(9,win_type='boxcar',center=True).sum().shift(-4)
df_12_Agg = df1.rolling(12,win_type='boxcar',center=True).sum().shift(-6)
df_24_Agg = df1.rolling(24,win_type='boxcar',center=True).sum().shift(-12)
df_36_Agg = df1.rolling(36,win_type='boxcar',center=True).sum().shift(-18)

# %%
df_3_Agg.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                           0.011532
# 1                                           0.000835
# 2                                          -0.002820
# 3                                          -0.016471
# 4                                          -0.027245
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# 0                                           0.006752
# 1                                           0.002405
# 2                                           0.002310
# 3                                          -0.003651
# 4                                          -0.013375
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index  \
# 0                                           0.004552
# 1                                           0.000725
# 2                                           0.001570
# 3                                          -0.002321
# ...

# %%
df_12_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         258.000000
# mean                                           -0.011086
# std                                             0.022132
# min                                            -0.058334
# 25%                                            -0.027475
# 50%                                            -0.011167
# 75%                                             0.002571
# max                                             0.059617
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         258.000000
# mean                                           -0.004374
# std                                             0.014239
# min                                            -0.045282
# 25%                                            -0.013420
# 50%                                            -0.004694
# ...

# %% [markdown]
# # Calculate Min/Max

# %%
# Now lets normalize our data (for treasury)
#df_3_Agg = df_3_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_3_Agg)
df_3_Agg_Max = column_maxes
column_mins = lower_bound(df_3_Agg)
df_3_Agg_Min = column_mins
df_3_Agg = (df_3_Agg - df_3_Agg_Min) / (df_3_Agg_Max - df_3_Agg_Min)
df_3_Agg = df_3_Agg
#df_3_Agg['Date'] = df_Date

# %%
df_3_Agg.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                           0.729800
# 1                                           0.562293
# 2                                           0.505058
# 3                                           0.291293
# 4                                           0.122581
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# 0                                           0.709268
# 1                                           0.595329
# 2                                           0.592839
# 3                                           0.436596
# 4                                           0.181720
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index  \
# 0                                           0.664121
# 1                                           0.559535
# 2                                           0.582627
# 3                                           0.476293
# ...

# %%
# Now lets normalize our data (for treasury)
#df_6_Agg = df_6_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_6_Agg)
df_6_Agg_Max = column_maxes
column_mins = lower_bound(df_6_Agg)
df_6_Agg_Min = column_mins
df_6_Agg = (df_6_Agg - df_6_Agg_Min) / (df_6_Agg_Max - df_6_Agg_Min)
df_6_Agg = df_6_Agg
#df_6_Agg['Date'] = df_Date

# %%
df_6_Agg.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                           0.509828
# 1                                           0.288256
# 2                                           0.411926
# 3                                           0.240311
# 4                                           0.235275
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# 0                                           0.599573
# 1                                           0.334397
# 2                                           0.524624
# 3                                           0.364626
# 4                                           0.278539
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index  \
# 0                                           0.590451
# 1                                           0.343123
# 2                                           0.506339
# 3                                           0.382107
# ...

# %%
# Now lets normalize our data (for treasury)
#df_9_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_9_Agg)
df_9_Agg_Max = column_maxes
column_mins = lower_bound(df_9_Agg)
df_9_Agg_Min = column_mins
df_9_Agg = (df_9_Agg - df_9_Agg_Min) / (df_9_Agg_Max - df_9_Agg_Min)
df_9_Agg = df_9_Agg

#df_9_Agg['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_12_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_12_Agg)
df_12_Agg_Max = column_maxes
column_mins = lower_bound(df_12_Agg)
df_12_Agg_Min = column_mins
df_12_Agg = (df_12_Agg - df_12_Agg_Min) / (df_12_Agg_Max - df_12_Agg_Min)
df_12_Agg = df_12_Agg

#df_12_Agg['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_24_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_24_Agg)
df_24_Agg_Max = column_maxes
column_mins = lower_bound(df_24_Agg)
df_24_Agg_Min = column_mins
df_24_Agg = (df_24_Agg - df_24_Agg_Min) / (df_24_Agg_Max - df_24_Agg_Min)
df_24_Agg = df_24_Agg

#df_24_Agg['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_36_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_36_Agg)
df_36_Agg_Max = column_maxes
column_mins = lower_bound(df_36_Agg)
df_36_Agg_Min = column_mins
df_36_Agg = (df_36_Agg - df_36_Agg_Min) / (df_36_Agg_Max - df_36_Agg_Min)
df_36_Agg = df_36_Agg

#df_36_Agg['Date'] = df_Date

# %%
df_3_Agg = df_3_Agg[df_3_Agg >= 0]
df_3_Agg = df_3_Agg[df_3_Agg <= 1]
df_6_Agg = df_6_Agg[df_6_Agg >= 0]
df_6_Agg = df_6_Agg[df_6_Agg <= 1]
df_9_Agg = df_9_Agg[df_9_Agg >= 0]
df_9_Agg = df_9_Agg[df_9_Agg <= 1]
df_12_Agg = df_12_Agg[df_12_Agg >= 0]
df_12_Agg = df_12_Agg[df_12_Agg <= 1]
df_24_Agg = df_24_Agg[df_24_Agg >= 0]
df_24_Agg = df_24_Agg[df_24_Agg <= 1]
df_36_Agg = df_36_Agg[df_36_Agg >= 0]
df_36_Agg = df_36_Agg[df_36_Agg <= 1]

# %%
df_3_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         267.000000
# mean                                            0.503062
# std                                             0.177756
# min                                             0.075008
# 25%                                             0.375000
# 50%                                             0.485092
# 75%                                             0.625000
# max                                             0.982728
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         263.000000
# mean                                            0.497033
# std                                             0.185835
# min                                             0.000367
# 25%                                             0.375000
# 50%                                             0.489254
# ...

# %%
df_12_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         258.000000
# mean                                            0.511368
# std                                             0.184148
# min                                             0.118235
# 25%                                             0.375000
# 50%                                             0.510692
# 75%                                             0.625000
# max                                             1.099656
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         254.000000
# mean                                            0.501279
# std                                             0.199372
# min                                            -0.073029
# 25%                                             0.375000
# 50%                                             0.496471
# ...

# %%
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
pd.options.display.max_rows  = 280 # want to see all columns

df_36_Agg.head(280)
# Out:
#      ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                             0.633317
# 1                                             0.644721
# 2                                             0.625108
# 3                                             0.540711
# 4                                             0.607433
# 5                                             0.635137
# 6                                             0.623040
# 7                                             0.705557
# 8                                             0.626927
# 9                                             0.686523
# 10                                            0.717283
# 11                                            0.693367
# 12                                            0.677236
# 13                                            0.690262
# 14                                            0.654834
# 15                                            0.659660
# ...

# %%
df_3_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         267.000000
# mean                                            0.503062
# std                                             0.177756
# min                                             0.075008
# 25%                                             0.375000
# 50%                                             0.485092
# 75%                                             0.625000
# max                                             0.982728
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         263.000000
# mean                                            0.497033
# std                                             0.185835
# min                                             0.000367
# 25%                                             0.375000
# 50%                                             0.489254
# ...

# %%
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
# Adding back spreads so we can do the selective query 
df_3_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_3_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_3_Agg = df_3_Agg[df_3_Agg > 0]
df_3_Agg["Date"] = df_copy["Date"]

df_6_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_6_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_6_Agg = df_6_Agg[df_6_Agg > 0]
df_6_Agg["Date"] = df_copy["Date"]


df_9_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_9_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_9_Agg = df_9_Agg[df_9_Agg > 0]
df_9_Agg["Date"] = df_copy["Date"]


df_12_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_12_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_12_Agg = df_12_Agg[df_12_Agg > 0]
df_12_Agg["Date"] = df_copy["Date"]


df_24_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_24_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_24_Agg = df_24_Agg[df_24_Agg > 0]
df_24_Agg["Date"] = df_copy["Date"]


df_36_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_36_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_36_Agg = df_36_Agg[df_36_Agg > 0]
df_36_Agg["Date"] = df_copy["Date"]

# %%
pd.options.display.max_rows  = 280 # want to see all columns
pd.options.display.max_columns  = 280 # want to see all columns



df_3_Agg.head(280)
# Out:
#      ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                             0.729800
# 1                                             0.562293
# 2                                             0.505058
# 3                                             0.291293
# 4                                             0.122581
# 5                                             0.367476
# 6                                             0.320827
# 7                                             0.481898
# 8                                             0.263122
# 9                                             0.334529
# 10                                            0.393548
# 11                                            0.477451
# 12                                            0.540745
# 13                                            0.623082
# 14                                            0.496257
# 15                                            0.410993
# ...

# %%
df_3_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         267.000000
# mean                                            0.503062
# std                                             0.177756
# min                                             0.075008
# 25%                                             0.375000
# 50%                                             0.485092
# 75%                                             0.625000
# max                                             0.982728
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         263.000000
# mean                                            0.497033
# std                                             0.185835
# min                                             0.000367
# 25%                                             0.375000
# 50%                                             0.489254
# ...

# %% [markdown]
# # Now we move on to our Hypothesis Testing Segment
#
# ## Our hypothesis is that spreads that are in the 80th percentile have higher excess returns than average case.

# %%
import researchpy # for t-test stuff!

# %% [markdown]
# # 3 Month Below

# %%
# Selecting 
highspread_31 = df_3_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_3_Agg[(df_3_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.574386
# std                                             0.179452
# min                                             0.227967
# 25%                                             0.428018
# 50%                                             0.556796
# 75%                                             0.724890
# max                                             0.901660
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.573011
# std                                             0.202058
# min                                             0.043327
# 25%                                             0.477943
# 50%                                             0.577034
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_3_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.574386
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  267.0  0.503062
#  2                                           combined  321.0  0.515060
#
#           SD        SE  95% Conf.  Interval
#  0  0.179452  0.024420   0.525405  0.623367
#  1  0.177756  0.010878   0.481643  0.524481
#  2  0.179758  0.010033   0.495321  0.534800  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0713
#  1                              Degrees of freedom =   75.5294
#  2                                               t =    2.6679
#  3                           Two side test p value =    0.0093
#  4                          Difference < 0 p value =    0.9953
#  5                          Difference > 0 p value =    0.0047
# ...

# %%
# Selecting 
highspread_32 = df_3_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_3_Agg[(df_3_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.547436
# std                                             0.166663
# min                                             0.191654
# 25%                                             0.434928
# 50%                                             0.536815
# 75%                                             0.665824
# max                                             0.982728
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.536842
# std                                             0.191890
# min                                             0.000367
# 25%                                             0.413949
# 50%                                             0.535385
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_3_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   49.0  0.536842
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  263.0  0.497033
#  2                                           combined  312.0  0.503285
#
#           SD        SE  95% Conf.  Interval
#  0  0.191890  0.027413   0.481725  0.591960
#  1  0.185835  0.011459   0.474469  0.519596
#  2  0.187049  0.010590   0.482449  0.524121  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.0398
#  1                              Degrees of freedom =   65.8721
#  2                                               t =    1.3399
#  3                           Two side test p value =    0.1849
#  4                          Difference < 0 p value =    0.9076
#  5                          Difference > 0 p value =    0.0924
# ...

# %%
# Selecting 
highspread_33 = df_3_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_3_Agg[(df_3_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.540459
# std                                             0.163883
# min                                             0.186768
# 25%                                             0.433292
# 50%                                             0.536815
# 75%                                             0.665002
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.531463
# std                                             0.187609
# min                                             0.043327
# 25%                                             0.410594
# 50%                                             0.529802
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   50.0  0.556355
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  258.0  0.499120
#  2                                           combined  308.0  0.508411
#
#           SD        SE  95% Conf.  Interval
#  0  0.165304  0.023378   0.509376  0.603334
#  1  0.178396  0.011106   0.477249  0.520991
#  2  0.177342  0.010105   0.488527  0.528295  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.0572
#  1                              Degrees of freedom =   72.9077
#  2                                               t =    2.2114
#  3                           Two side test p value =    0.0301
#  4                          Difference < 0 p value =    0.9849
#  5                          Difference > 0 p value =    0.0151
# ...

# %%
# Selecting 
highspread_34 = df_3_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_3_Agg[(df_3_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.530996
# std                                             0.154884
# min                                             0.191654
# 25%                                             0.431534
# 50%                                             0.520435
# 75%                                             0.647287
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.520620
# std                                             0.182522
# min                                             0.000367
# 25%                                             0.408917
# 50%                                             0.513931
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   44.0  0.562678
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  254.0  0.503524
#  2                                           combined  298.0  0.512258
#
#           SD        SE  95% Conf.  Interval
#  0  0.153128  0.023085   0.516123  0.609234
#  1  0.173967  0.010916   0.482027  0.525021
#  2  0.172098  0.009969   0.492639  0.531878  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.0592
#  1                              Degrees of freedom =   63.8356
#  2                                               t =    2.3165
#  3                           Two side test p value =    0.0238
#  4                          Difference < 0 p value =    0.9881
#  5                          Difference > 0 p value =    0.0119
# ...

# %%
# Selecting 
highspread_35 = df_3_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_3_Agg[(df_3_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.535593
# std                                             0.160668
# min                                             0.191654
# 25%                                             0.431017
# 50%                                             0.520435
# 75%                                             0.662841
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.524124
# std                                             0.190037
# min                                             0.000367
# 25%                                             0.408917
# 50%                                             0.513931
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA US FNMA Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   48.0  0.557089
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  254.0  0.497376
#  2                                           combined  302.0  0.506867
#
#           SD        SE  95% Conf.  Interval
#  0  0.175653  0.025353   0.506085  0.608093
#  1  0.179115  0.011239   0.475243  0.519509
#  2  0.179616  0.010336   0.486527  0.527206  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0597
#  1                              Degrees of freedom =   66.8063
#  2                                               t =    2.1532
#  3                           Two side test p value =    0.0349
#  4                          Difference < 0 p value =    0.9825
#  5                          Difference > 0 p value =    0.0175
# ...

# %%
# Selecting 
highspread_36 = df_3_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_3_Agg[(df_3_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.531896
# std                                             0.162772
# min                                             0.186768
# 25%                                             0.428018
# 50%                                             0.520435
# 75%                                             0.657176
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.525925
# std                                             0.183044
# min                                             0.043327
# 25%                                             0.412272
# 50%                                             0.515989
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   52.0  0.560569
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  260.0  0.497171
#  2                                           combined  312.0  0.507737
#
#           SD        SE  95% Conf.  Interval
#  0  0.166427  0.023079   0.514236  0.606903
#  1  0.177244  0.010992   0.475526  0.518817
#  2  0.176819  0.010010   0.488041  0.527434  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0634
#  1                              Degrees of freedom =   75.9924
#  2                                               t =    2.4800
#  3                           Two side test p value =    0.0153
#  4                          Difference < 0 p value =    0.9923
#  5                          Difference > 0 p value =    0.0077
# ...

# %%
# Selecting 
highspread_37 = df_3_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_37 = df_3_Agg[(df_3_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_37)]

# %%
normalized_df_37.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.512845
# std                                             0.145743
# min                                             0.191654
# 25%                                             0.403304
# 50%                                             0.502067
# 75%                                             0.589653
# max                                             0.831256
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.502060
# std                                             0.170350
# min                                             0.000367
# 25%                                             0.395779
# 50%                                             0.490748
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_37['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   48.0  0.532310
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  256.0  0.498406
#  2                                           combined  304.0  0.503759
#
#           SD        SE  95% Conf.  Interval
#  0  0.154233  0.022262   0.487525  0.577094
#  1  0.177704  0.011106   0.476534  0.520278
#  2  0.174411  0.010003   0.484074  0.523443  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0339
#  1                              Degrees of freedom =   72.4817
#  2                                               t =    1.3628
#  3                           Two side test p value =    0.1772
#  4                          Difference < 0 p value =    0.9114
#  5                          Difference > 0 p value =    0.0886
# ...

# %%
# Selecting 
highspread_38 = df_3_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_38 = df_3_Agg[(df_3_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_38)]

# %%
normalized_df_38.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.547957
# std                                             0.161792
# min                                             0.191654
# 25%                                             0.434110
# 50%                                             0.538851
# 75%                                             0.666235
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.536073
# std                                             0.191124
# min                                             0.000367
# 25%                                             0.412272
# 50%                                             0.547599
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_38['ICE BofA US GNMA Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   46.0  0.578335
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  259.0  0.501613
#  2                                           combined  305.0  0.513184
#
#           SD        SE  95% Conf.  Interval
#  0  0.168023  0.024774   0.528438  0.628232
#  1  0.182003  0.011309   0.479343  0.523883
#  2  0.181791  0.010409   0.492701  0.533668  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.0767
#  1                              Degrees of freedom =   65.2152
#  2                                               t =    2.8172
#  3                           Two side test p value =    0.0064
#  4                          Difference < 0 p value =    0.9968
#  5                          Difference > 0 p value =    0.0032
# ...

# %%
# Selecting 
highspread_39 = df_3_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_39 = df_3_Agg[(df_3_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_39)]

# %%
normalized_df_39.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.541041
# std                                             0.162455
# min                                             0.191654
# 25%                                             0.430512
# 50%                                             0.529330
# 75%                                             0.665413
# max                                             0.891419
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.526636
# std                                             0.193541
# min                                             0.000367
# 25%                                             0.396722
# 50%                                             0.532593
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_39['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_3_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   48.0  0.567509
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  259.0  0.501460
#  2                                           combined  307.0  0.511787
#
#           SD        SE  95% Conf.  Interval
#  0  0.171628  0.024772   0.517673  0.617344
#  1  0.180322  0.011205   0.479396  0.523524
#  2  0.180325  0.010292   0.491535  0.532038  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.0660
#  1                              Degrees of freedom =   67.6814
#  2                                               t =    2.4293
#  3                           Two side test p value =    0.0178
#  4                          Difference < 0 p value =    0.9911
#  5                          Difference > 0 p value =    0.0089
# ...

# %% [markdown]
# # 6 Month Below

# %%
# Selecting 
highspread_61 = df_6_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_61 = df_6_Agg[(df_6_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_61)]

# %%
normalized_df_61.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.592732
# std                                             0.168454
# min                                             0.316150
# 25%                                             0.455299
# 50%                                             0.596864
# 75%                                             0.720121
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.575478
# std                                             0.172673
# min                                             0.210356
# 25%                                             0.472667
# 50%                                             0.547031
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_61['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_6_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   53.0  0.592732
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  263.0  0.498230
#  2                                           combined  316.0  0.514080
#
#           SD        SE  95% Conf.  Interval
#  0  0.168454  0.023139   0.546301  0.639164
#  1  0.164304  0.010131   0.478280  0.518179
#  2  0.168490  0.009478   0.495431  0.532729  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0945
#  1                              Degrees of freedom =   73.3148
#  2                                               t =    3.7412
#  3                           Two side test p value =    0.0004
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
# ...

# %%
# Selecting 
highspread_62 = df_6_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_62 = df_6_Agg[(df_6_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_62)]

# %%
normalized_df_62.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.579219
# std                                             0.147244
# min                                             0.316150
# 25%                                             0.461522
# 50%                                             0.568247
# 75%                                             0.710668
# max                                             0.858342
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.577231
# std                                             0.165684
# min                                             0.236834
# 25%                                             0.469981
# 50%                                             0.551347
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_62['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_6_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.577231
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  258.0  0.488140
#  2                                           combined  305.0  0.501868
#
#           SD        SE  95% Conf.  Interval
#  0  0.165684  0.024167   0.528584  0.625877
#  1  0.183236  0.011408   0.465675  0.510604
#  2  0.183238  0.010492   0.481222  0.522515  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.0891
#  1                              Degrees of freedom =   68.1765
#  2                                               t =    3.3337
#  3                           Two side test p value =    0.0014
#  4                          Difference < 0 p value =    0.9993
#  5                          Difference > 0 p value =    0.0007
# ...

# %%
# Selecting 
highspread_63 = df_6_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_63 = df_6_Agg[(df_6_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_63)]

# %%
normalized_df_63.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.578621
# std                                             0.163235
# min                                             0.305995
# 25%                                             0.451156
# 50%                                             0.551953
# 75%                                             0.707673
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.561195
# std                                             0.167931
# min                                             0.210356
# 25%                                             0.460309
# 50%                                             0.549189
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_63['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   51.0  0.630961
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  259.0  0.494872
#  2                                           combined  310.0  0.517260
#
#           SD        SE  95% Conf.  Interval
#  0  0.185808  0.026018   0.578702  0.683220
#  1  0.195230  0.012131   0.470983  0.518760
#  2  0.199911  0.011354   0.494919  0.539602  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.1361
#  1                              Degrees of freedom =   73.4291
#  2                                               t =    4.7406
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_64 = df_6_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_64 = df_6_Agg[(df_6_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_64)]

# %%
normalized_df_64.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.576595
# std                                             0.155992
# min                                             0.316150
# 25%                                             0.456855
# 50%                                             0.550895
# 75%                                             0.709670
# max                                             0.932426
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.565032
# std                                             0.164882
# min                                             0.236834
# 25%                                             0.453322
# 50%                                             0.547031
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_64['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   40.0  0.597688
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  253.0  0.492795
#  2                                           combined  293.0  0.507115
#
#           SD        SE  95% Conf.  Interval
#  0  0.156628  0.024765   0.547596  0.647781
#  1  0.185110  0.011638   0.469875  0.515715
#  2  0.184797  0.010796   0.485867  0.528363  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.1049
#  1                              Degrees of freedom =   57.6913
#  2                                               t =    3.8334
#  3                           Two side test p value =    0.0003
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
# ...

# %%
# Selecting 
highspread_65 = df_6_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_65 = df_6_Agg[(df_6_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_65)]

# %%
normalized_df_65.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.579819
# std                                             0.162402
# min                                             0.316150
# 25%                                             0.456855
# 50%                                             0.550895
# 75%                                             0.709670
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.559716
# std                                             0.171268
# min                                             0.169556
# 25%                                             0.446335
# 50%                                             0.549189
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_65['ICE BofA US FNMA Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   44.0  0.602760
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  253.0  0.491983
#  2                                           combined  297.0  0.508394
#
#           SD        SE  95% Conf.  Interval
#  0  0.178314  0.026882   0.548548  0.656972
#  1  0.192768  0.012119   0.468115  0.515851
#  2  0.194444  0.011283   0.486190  0.530599  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.1108
#  1                              Degrees of freedom =   61.8201
#  2                                               t =    3.7568
#  3                           Two side test p value =    0.0004
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
# ...

# %%
# Selecting 
highspread_66 = df_6_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_66 = df_6_Agg[(df_6_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_66)]

# %%
normalized_df_66.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.572363
# std                                             0.165402
# min                                             0.305995
# 25%                                             0.421802
# 50%                                             0.544585
# 75%                                             0.706674
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.557311
# std                                             0.167413
# min                                             0.210356
# 25%                                             0.439348
# 50%                                             0.540379
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_66['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   52.0  0.629951
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  258.0  0.494376
#  2                                           combined  310.0  0.517117
#
#           SD        SE  95% Conf.  Interval
#  0  0.190911  0.026475   0.576801  0.683101
#  1  0.198080  0.012332   0.470091  0.518660
#  2  0.203034  0.011532   0.494427  0.539808  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.1356
#  1                              Degrees of freedom =   74.8330
#  2                                               t =    4.6421
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_67 = df_6_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_67 = df_6_Agg[(df_6_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_67)]

# %%
normalized_df_67.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.552795
# std                                             0.149547
# min                                             0.316150
# 25%                                             0.421655
# 50%                                             0.521448
# 75%                                             0.696079
# max                                             0.858342
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.548837
# std                                             0.169767
# min                                             0.169556
# 25%                                             0.436116
# 50%                                             0.519262
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_67['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   44.0  0.569702
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  253.0  0.499864
#  2                                           combined  297.0  0.510210
#
#           SD        SE  95% Conf.  Interval
#  0  0.166948  0.025168   0.518946  0.620459
#  1  0.184878  0.011623   0.476973  0.522755
#  2  0.183754  0.010662   0.489226  0.531194  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0698
#  1                              Degrees of freedom =   62.8102
#  2                                               t =    2.5192
#  3                           Two side test p value =    0.0143
#  4                          Difference < 0 p value =    0.9928
#  5                          Difference > 0 p value =    0.0072
# ...

# %%
# Selecting 
highspread_68 = df_6_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_68 = df_6_Agg[(df_6_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_68)]

# %%
normalized_df_68.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.591366
# std                                             0.161886
# min                                             0.316150
# 25%                                             0.463013
# 50%                                             0.590558
# 75%                                             0.712737
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.570996
# std                                             0.165748
# min                                             0.236834
# 25%                                             0.453322
# 50%                                             0.551347
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_68['ICE BofA US GNMA Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   44.0  0.622628
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  257.0  0.498020
#  2                                           combined  301.0  0.516235
#
#           SD        SE  95% Conf.  Interval
#  0  0.190505  0.028720   0.564709  0.680546
#  1  0.193746  0.012086   0.474220  0.521819
#  2  0.197935  0.011409   0.493783  0.538686  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.1246
#  1                              Degrees of freedom =   59.2653
#  2                                               t =    3.9991
#  3                           Two side test p value =    0.0002
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
# ...

# %%
# Selecting 
highspread_69 = df_6_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_69 = df_6_Agg[(df_6_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_69)]

# %%
normalized_df_69.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.578904
# std                                             0.170334
# min                                             0.221602
# 25%                                             0.421802
# 50%                                             0.568247
# 75%                                             0.710668
# max                                             0.934211
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.550427
# std                                             0.188938
# min                                             0.046833
# 25%                                             0.426420
# 50%                                             0.547031
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_69['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_6_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   46.0  0.595450
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  257.0  0.498590
#  2                                           combined  303.0  0.513295
#
#           SD        SE  95% Conf.  Interval
#  0  0.222892  0.032864   0.529259  0.661641
#  1  0.192923  0.012034   0.474892  0.522289
#  2  0.200412  0.011513   0.490638  0.535952  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.0969
#  1                              Degrees of freedom =   57.6951
#  2                                               t =    2.7676
#  3                           Two side test p value =    0.0076
#  4                          Difference < 0 p value =    0.9962
#  5                          Difference > 0 p value =    0.0038
# ...

# %% [markdown]
# # 9 Month Below

# %%
# Selecting 
highspread_91 = df_9_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_91 = df_9_Agg[(df_9_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_91)]

# %%
normalized_df_91.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.633931
# std                                             0.182617
# min                                             0.307742
# 25%                                             0.484090
# 50%                                             0.622370
# 75%                                             0.748430
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.649160
# std                                             0.212960
# min                                             0.327190
# 25%                                             0.486894
# 50%                                             0.602744
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_91['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_9_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.633931
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  261.0  0.507812
#  2                                           combined  315.0  0.529432
#
#           SD        SE  95% Conf.  Interval
#  0  0.182617  0.024851   0.584087  0.683776
#  1  0.178434  0.011045   0.486063  0.529560
#  2  0.185091  0.010429   0.508913  0.549951  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.1261
#  1                              Degrees of freedom =   75.4059
#  2                                               t =    4.6376
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_92 = df_9_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_92 = df_9_Agg[(df_9_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_92)]

# %%
normalized_df_92.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.606042
# std                                             0.164956
# min                                             0.307742
# 25%                                             0.472464
# 50%                                             0.611091
# 75%                                             0.715218
# max                                             1.004731
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.617061
# std                                             0.191658
# min                                             0.327190
# 25%                                             0.475599
# 50%                                             0.588139
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_92['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_9_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.617061
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  257.0  0.503564
#  2                                           combined  304.0  0.521112
#
#           SD        SE  95% Conf.  Interval
#  0  0.191658  0.027956   0.560788  0.673334
#  1  0.204862  0.012779   0.478399  0.528730
#  2  0.206698  0.011855   0.497783  0.544440  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.1135
#  1                              Degrees of freedom =   66.7080
#  2                                               t =    3.6923
#  3                           Two side test p value =    0.0004
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
# ...

# %%
# Selecting 
highspread_93 = df_9_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_93 = df_9_Agg[(df_9_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_93)]

# %%
normalized_df_93.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.604231
# std                                             0.181097
# min                                             0.307742
# 25%                                             0.472307
# 50%                                             0.595436
# 75%                                             0.688885
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.618012
# std                                             0.205899
# min                                             0.327190
# 25%                                             0.460028
# 50%                                             0.563601
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_93['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.652170
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  252.0  0.505521
#  2                                           combined  301.0  0.529394
#
#           SD        SE  95% Conf.  Interval
#  0  0.169822  0.024260   0.603391  0.700949
#  1  0.193993  0.012220   0.481453  0.529588
#  2  0.197590  0.011389   0.506982  0.551806  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.1466
#  1                              Degrees of freedom =   74.5311
#  2                                               t =    5.3986
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_94 = df_9_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_94 = df_9_Agg[(df_9_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_94)]

# %%
normalized_df_94.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.603091
# std                                             0.174849
# min                                             0.307742
# 25%                                             0.471993
# 50%                                             0.593408
# 75%                                             0.678308
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.616793
# std                                             0.204092
# min                                             0.327190
# 25%                                             0.468281
# 50%                                             0.562130
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_94['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   43.0  0.668605
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  250.0  0.503983
#  2                                           combined  293.0  0.528142
#
#           SD        SE  95% Conf.  Interval
#  0  0.211059  0.032186   0.603650  0.733559
#  1  0.202731  0.012822   0.478729  0.529236
#  2  0.211802  0.012374   0.503789  0.552495  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.1646
#  1                              Degrees of freedom =   56.1496
#  2                                               t =    4.7515
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_95 = df_9_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_95 = df_9_Agg[(df_9_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_95)]

# %%
normalized_df_95.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.604326
# std                                             0.183939
# min                                             0.307742
# 25%                                             0.462668
# 50%                                             0.593408
# 75%                                             0.706440
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.616259
# std                                             0.216257
# min                                             0.190225
# 25%                                             0.462091
# 50%                                             0.562130
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_95['ICE BofA US FNMA Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   47.0  0.665787
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  249.0  0.499552
#  2                                           combined  296.0  0.525947
#
#           SD        SE  95% Conf.  Interval
#  0  0.231194  0.033723   0.597906  0.733668
#  1  0.211477  0.013402   0.473156  0.525948
#  2  0.222790  0.012949   0.500462  0.551432  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.1662
#  1                              Degrees of freedom =   61.3932
#  2                                               t =    4.5809
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_96 = df_9_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_96 = df_9_Agg[(df_9_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_96)]

# %%
normalized_df_96.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.603467
# std                                             0.178401
# min                                             0.307742
# 25%                                             0.472464
# 50%                                             0.593408
# 75%                                             0.680108
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.618361
# std                                             0.203012
# min                                             0.327190
# 25%                                             0.473975
# 50%                                             0.563787
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_96['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   51.0  0.659771
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  254.0  0.505943
#  2                                           combined  305.0  0.531665
#
#           SD        SE  95% Conf.  Interval
#  0  0.170850  0.023924   0.611718  0.707823
#  1  0.195316  0.012255   0.481808  0.530078
#  2  0.199638  0.011431   0.509171  0.554159  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.1538
#  1                              Degrees of freedom =   78.6143
#  2                                               t =    5.7227
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_97 = df_9_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_97 = df_9_Agg[(df_9_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_97)]

# %%
normalized_df_97.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.569997
# std                                             0.172725
# min                                             0.307742
# 25%                                             0.435707
# 50%                                             0.533196
# 75%                                             0.667220
# max                                             1.004731
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.581824
# std                                             0.202050
# min                                             0.190225
# 25%                                             0.442995
# 50%                                             0.531329
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_97['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   47.0  0.625433
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  251.0  0.500189
#  2                                           combined  298.0  0.519942
#
#           SD        SE  95% Conf.  Interval
#  0  0.243071  0.035456   0.554065  0.696802
#  1  0.206412  0.013029   0.474529  0.525849
#  2  0.217037  0.012573   0.495200  0.544685  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.1252
#  1                              Degrees of freedom =   59.0632
#  2                                               t =    3.3157
#  3                           Two side test p value =    0.0016
#  4                          Difference < 0 p value =    0.9992
#  5                          Difference > 0 p value =    0.0008
# ...

# %%
# Selecting 
highspread_98 = df_9_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_98 = df_9_Agg[(df_9_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_98)]

# %%
normalized_df_98.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.612515
# std                                             0.182343
# min                                             0.307742
# 25%                                             0.472150
# 50%                                             0.597464
# 75%                                             0.719274
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.627876
# std                                             0.212537
# min                                             0.327190
# 25%                                             0.472407
# 50%                                             0.563787
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_98['ICE BofA US GNMA Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   44.0  0.668289
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  255.0  0.498431
#  2                                           combined  299.0  0.523427
#
#           SD        SE  95% Conf.  Interval
#  0  0.214484  0.032335   0.603080  0.733499
#  1  0.217559  0.013624   0.471601  0.525262
#  2  0.224977  0.013011   0.497822  0.549032  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.1699
#  1                              Degrees of freedom =   59.3065
#  2                                               t =    4.8410
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_99 = df_9_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_99 = df_9_Agg[(df_9_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_99)]

# %%
normalized_df_99.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.606661
# std                                             0.184896
# min                                             0.307742
# 25%                                             0.468780
# 50%                                             0.593408
# 75%                                             0.717246
# max                                             1.018512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.618362
# std                                             0.219846
# min                                             0.190225
# 25%                                             0.460028
# 50%                                             0.562130
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_99['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_9_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   45.0  0.654788
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  255.0  0.500462
#  2                                           combined  300.0  0.523611
#
#           SD        SE  95% Conf.  Interval
#  0  0.223007  0.033244   0.587789  0.721787
#  1  0.214275  0.013418   0.474036  0.526887
#  2  0.222191  0.012828   0.498366  0.548856  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.1543
#  1                              Degrees of freedom =   59.2327
#  2                                               t =    4.3048
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %% [markdown]
# # 12 Month Below

# %%
# Selecting 
highspread_121 = df_12_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_121 = df_12_Agg[(df_12_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_121)]

# %%
normalized_df_121.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.643263
# std                                             0.193750
# min                                             0.340569
# 25%                                             0.492439
# 50%                                             0.606503
# 75%                                             0.785394
# max                                             1.099656
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.656969
# std                                             0.204662
# min                                             0.295370
# 25%                                             0.495546
# 50%                                             0.616563
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_121['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_12_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.643263
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  258.0  0.511368
#  2                                           combined  312.0  0.534196
#
#           SD        SE  95% Conf.  Interval
#  0  0.193750  0.026366   0.590379  0.696146
#  1  0.184148  0.011465   0.488792  0.533944
#  2  0.192140  0.010878   0.512793  0.555599  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.1319
#  1                              Degrees of freedom =   74.3879
#  2                                               t =    4.5875
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_122 = df_12_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_122 = df_12_Agg[(df_12_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_122)]

# %%
normalized_df_122.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.603281
# std                                             0.168072
# min                                             0.340569
# 25%                                             0.461784
# 50%                                             0.571690
# 75%                                             0.721602
# max                                             1.030512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.617462
# std                                             0.187178
# min                                             0.295370
# 25%                                             0.472179
# 50%                                             0.602783
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_122['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_12_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.617462
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  254.0  0.501279
#  2                                           combined  301.0  0.519420
#
#           SD        SE  95% Conf.  Interval
#  0  0.187178  0.027303   0.562505  0.672420
#  1  0.199372  0.012510   0.476642  0.525915
#  2  0.201689  0.011625   0.496543  0.542298  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.1162
#  1                              Degrees of freedom =   66.8059
#  2                                               t =    3.8686
#  3                           Two side test p value =    0.0003
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
# ...

# %%
# Selecting 
highspread_123 = df_12_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_123 = df_12_Agg[(df_12_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_123)]

# %%
normalized_df_123.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.611181
# std                                             0.194805
# min                                             0.181147
# 25%                                             0.457542
# 50%                                             0.571965
# 75%                                             0.756877
# max                                             1.050889
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.626170
# std                                             0.207396
# min                                             0.295370
# 25%                                             0.467332
# 50%                                             0.596870
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_123['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.654940
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  249.0  0.502471
#  2                                           combined  298.0  0.527542
#
#           SD        SE  95% Conf.  Interval
#  0  0.177311  0.025330   0.604010  0.705870
#  1  0.185973  0.011786   0.479259  0.525684
#  2  0.192784  0.011168   0.505564  0.549519  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.1525
#  1                              Degrees of freedom =   70.3936
#  2                                               t =    5.4575
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_124 = df_12_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_124 = df_12_Agg[(df_12_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_124)]

# %%
normalized_df_124.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.605976
# std                                             0.180901
# min                                             0.340569
# 25%                                             0.460585
# 50%                                             0.569373
# 75%                                             0.731530
# max                                             1.030512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.621926
# std                                             0.203410
# min                                             0.295370
# 25%                                             0.461644
# 50%                                             0.594458
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_124['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   43.0  0.699541
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  247.0  0.511137
#  2                                           combined  290.0  0.539073
#
#           SD        SE  95% Conf.  Interval
#  0  0.221845  0.033831   0.631268  0.767815
#  1  0.211581  0.013463   0.484620  0.537654
#  2  0.223062  0.013099   0.513292  0.564854  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.1884
#  1                              Degrees of freedom =   56.1146
#  2                                               t =    5.1743
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_125 = df_12_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_125 = df_12_Agg[(df_12_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_125)]

# %%
normalized_df_125.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.613714
# std                                             0.190928
# min                                             0.340569
# 25%                                             0.460186
# 50%                                             0.571690
# 75%                                             0.754418
# max                                             1.050889
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.629367
# std                                             0.210912
# min                                             0.295370
# 25%                                             0.460065
# 50%                                             0.598157
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_125['ICE BofA US FNMA Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   46.0  0.700435
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  246.0  0.507394
#  2                                           combined  292.0  0.537805
#
#           SD        SE  95% Conf.  Interval
#  0  0.224597  0.033115   0.633738  0.767132
#  1  0.211623  0.013493   0.480818  0.533971
#  2  0.224651  0.013147   0.511930  0.563680  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.1930
#  1                              Degrees of freedom =   60.8731
#  2                                               t =    5.3985
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_126 = df_12_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_126 = df_12_Agg[(df_12_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_126)]

# %%
normalized_df_126.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.607976
# std                                             0.194768
# min                                             0.181147
# 25%                                             0.460186
# 50%                                             0.571690
# 75%                                             0.754418
# max                                             1.050889
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.623548
# std                                             0.207389
# min                                             0.295370
# 25%                                             0.460065
# 50%                                             0.598157
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_126['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   51.0  0.657116
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  251.0  0.503712
#  2                                           combined  302.0  0.529618
#
#           SD        SE  95% Conf.  Interval
#  0  0.180111  0.025221   0.606459  0.707773
#  1  0.185043  0.011680   0.480709  0.526715
#  2  0.192722  0.011090   0.507794  0.551442  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.1534
#  1                              Degrees of freedom =   73.0744
#  2                                               t =    5.5194
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_127 = df_12_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_127 = df_12_Agg[(df_12_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_127)]

# %%
normalized_df_127.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.577205
# std                                             0.178660
# min                                             0.305432
# 25%                                             0.436547
# 50%                                             0.552311
# 75%                                             0.678634
# max                                             1.030512
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.592036
# std                                             0.197318
# min                                             0.295370
# 25%                                             0.431724
# 50%                                             0.577824
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_127['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   46.0  0.654065
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  248.0  0.502552
#  2                                           combined  294.0  0.526258
#
#           SD        SE  95% Conf.  Interval
#  0  0.248421  0.036628   0.580293  0.727836
#  1  0.212967  0.013523   0.475916  0.529188
#  2  0.225284  0.013139   0.500399  0.552116  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.1515
#  1                              Degrees of freedom =   57.9089
#  2                                               t =    3.8805
#  3                           Two side test p value =    0.0003
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
# ...

# %%
# Selecting 
highspread_128 = df_12_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_128 = df_12_Agg[(df_12_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_128)]

# %%
normalized_df_128.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.613339
# std                                             0.189683
# min                                             0.340569
# 25%                                             0.460985
# 50%                                             0.571690
# 75%                                             0.727838
# max                                             1.050889
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.622033
# std                                             0.206000
# min                                             0.295370
# 25%                                             0.463222
# 50%                                             0.598157
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_128['ICE BofA US GNMA Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   44.0  0.673836
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  252.0  0.496232
#  2                                           combined  296.0  0.522633
#
#           SD        SE  95% Conf.  Interval
#  0  0.211095  0.031824   0.609657  0.738014
#  1  0.224059  0.014114   0.468434  0.524030
#  2  0.230685  0.013408   0.496245  0.549021  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.1776
#  1                              Degrees of freedom =   61.1753
#  2                                               t =    5.1016
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_129 = df_12_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_129 = df_12_Agg[(df_12_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_129)]

# %%
normalized_df_129.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.613339
# std                                             0.189683
# min                                             0.340569
# 25%                                             0.460985
# 50%                                             0.571690
# 75%                                             0.727838
# max                                             1.050889
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.622033
# std                                             0.206000
# min                                             0.295370
# 25%                                             0.463222
# 50%                                             0.598157
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_129['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_12_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   44.0  0.671042
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  252.0  0.495285
#  2                                           combined  296.0  0.521411
#
#           SD        SE  95% Conf.  Interval
#  0  0.209622  0.031602   0.607311  0.734773
#  1  0.223206  0.014061   0.467593  0.522977
#  2  0.229603  0.013345   0.495147  0.547675  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.1758
#  1                              Degrees of freedom =   61.2987
#  2                                               t =    5.0814
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %% [markdown]
# # 24 Month Below

# %%
# Selecting 
highspread_241 = df_24_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_241 = df_24_Agg[(df_24_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_241)]

# %%
normalized_df_241.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.552157
# std                                             0.171364
# min                                             0.213052
# 25%                                             0.429212
# 50%                                             0.487890
# 75%                                             0.655791
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.596571
# std                                             0.204784
# min                                             0.244324
# 25%                                             0.442782
# 50%                                             0.528244
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_241['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_24_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.552157
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  246.0  0.510568
#  2                                           combined  300.0  0.518054
#
#           SD        SE  95% Conf.  Interval
#  0  0.171364  0.023320   0.505383  0.598930
#  1  0.167691  0.010692   0.489509  0.531627
#  2  0.168829  0.009747   0.498872  0.537236  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0416
#  1                              Degrees of freedom =   76.8885
#  2                                               t =    1.6212
#  3                           Two side test p value =    0.1091
#  4                          Difference < 0 p value =    0.9455
#  5                          Difference > 0 p value =    0.0545
# ...

# %%
# Selecting 
highspread_242 = df_24_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_242 = df_24_Agg[(df_24_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_242)]

# %%
normalized_df_242.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.525419
# std                                             0.157687
# min                                             0.213052
# 25%                                             0.427565
# 50%                                             0.473025
# 75%                                             0.610432
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.575170
# std                                             0.203196
# min                                             0.244324
# 25%                                             0.437820
# 50%                                             0.467480
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_242['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_24_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.575170
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  242.0  0.500254
#  2                                           combined  289.0  0.512438
#
#           SD        SE  95% Conf.  Interval
#  0  0.203196  0.029639   0.515510  0.634830
#  1  0.188018  0.012086   0.476446  0.524063
#  2  0.192206  0.011306   0.490185  0.534691  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.0749
#  1                              Degrees of freedom =   62.2416
#  2                                               t =    2.3405
#  3                           Two side test p value =    0.0225
#  4                          Difference < 0 p value =    0.9888
#  5                          Difference > 0 p value =    0.0112
# ...

# %%
# Selecting 
highspread_243 = df_24_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_243 = df_24_Agg[(df_24_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_243)]

# %%
normalized_df_243.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.538000
# std                                             0.175784
# min                                             0.213052
# 25%                                             0.423187
# 50%                                             0.474020
# 75%                                             0.638357
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.588368
# std                                             0.211047
# min                                             0.244324
# 25%                                             0.433861
# 50%                                             0.468964
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_243['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.580335
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  238.0  0.494435
#  2                                           combined  287.0  0.509101
#
#           SD        SE  95% Conf.  Interval
#  0  0.151645  0.021664   0.536778  0.623893
#  1  0.203930  0.013219   0.468394  0.520477
#  2  0.198419  0.011712   0.486048  0.532155  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.0859
#  1                              Degrees of freedom =   87.9292
#  2                                               t =    3.3848
#  3                           Two side test p value =    0.0011
#  4                          Difference < 0 p value =    0.9995
#  5                          Difference > 0 p value =    0.0005
# ...

# %%
# Selecting 
highspread_244 = df_24_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_244 = df_24_Agg[(df_24_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_244)]

# %%
normalized_df_244.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.532346
# std                                             0.169563
# min                                             0.213052
# 25%                                             0.424302
# 50%                                             0.471112
# 75%                                             0.614956
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.583934
# std                                             0.214701
# min                                             0.244324
# 25%                                             0.435142
# 50%                                             0.466165
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_244['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   43.0  0.569854
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  236.0  0.506035
#  2                                           combined  279.0  0.515871
#
#           SD        SE  95% Conf.  Interval
#  0  0.200213  0.030532   0.508237  0.631470
#  1  0.181995  0.011847   0.482696  0.529375
#  2  0.185978  0.011134   0.493953  0.537789  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.0638
#  1                              Degrees of freedom =   55.3741
#  2                                               t =    1.9487
#  3                           Two side test p value =    0.0564
#  4                          Difference < 0 p value =    0.9718
#  5                          Difference > 0 p value =    0.0282
# ...

# %%
# Selecting 
highspread_245 = df_24_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_245 = df_24_Agg[(df_24_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_245)]

# %%
normalized_df_245.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.540512
# std                                             0.169584
# min                                             0.213052
# 25%                                             0.427565
# 50%                                             0.475015
# 75%                                             0.633851
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.589405
# std                                             0.211340
# min                                             0.244324
# 25%                                             0.437820
# 50%                                             0.470448
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_245['ICE BofA US FNMA Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   46.0  0.571980
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  235.0  0.497131
#  2                                           combined  281.0  0.509384
#
#           SD        SE  95% Conf.  Interval
#  0  0.184963  0.027271   0.517052  0.626907
#  1  0.190761  0.012444   0.472615  0.521647
#  2  0.191519  0.011425   0.486894  0.531874  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0748
#  1                              Degrees of freedom =   65.1465
#  2                                               t =    2.4969
#  3                           Two side test p value =    0.0151
#  4                          Difference < 0 p value =    0.9925
#  5                          Difference > 0 p value =    0.0075
# ...

# %%
# Selecting 
highspread_246 = df_24_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_246 = df_24_Agg[(df_24_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_246)]

# %%
normalized_df_246.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.537598
# std                                             0.173129
# min                                             0.213052
# 25%                                             0.423214
# 50%                                             0.473025
# 75%                                             0.633900
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.586537
# std                                             0.209538
# min                                             0.244324
# 25%                                             0.434502
# 50%                                             0.470448
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_246['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   51.0  0.584545
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  240.0  0.495453
#  2                                           combined  291.0  0.511067
#
#           SD        SE  95% Conf.  Interval
#  0  0.148363  0.020775   0.542817  0.626273
#  1  0.203540  0.013138   0.469571  0.521335
#  2  0.197710  0.011590   0.488256  0.533878  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0891
#  1                              Degrees of freedom =   94.8203
#  2                                               t =    3.6244
#  3                           Two side test p value =    0.0005
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
# ...

# %%
# Selecting 
highspread_247 = df_24_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_247 = df_24_Agg[(df_24_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_247)]

# %%
normalized_df_247.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.527589
# std                                             0.157823
# min                                             0.213052
# 25%                                             0.427565
# 50%                                             0.475015
# 75%                                             0.610432
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.573476
# std                                             0.203214
# min                                             0.244324
# 25%                                             0.437820
# 50%                                             0.470448
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_247['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   46.0  0.543773
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  237.0  0.505103
#  2                                           combined  283.0  0.511388
#
#           SD        SE  95% Conf.  Interval
#  0  0.185054  0.027285   0.488819  0.598727
#  1  0.178753  0.011611   0.482228  0.527978
#  2  0.180026  0.010701   0.490323  0.532453  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0387
#  1                              Degrees of freedom =   62.3846
#  2                                               t =    1.3041
#  3                           Two side test p value =    0.1970
#  4                          Difference < 0 p value =    0.9015
#  5                          Difference > 0 p value =    0.0985
# ...

# %%
# Selecting 
highspread_248 = df_24_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_248 = df_24_Agg[(df_24_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_248)]

# %%
normalized_df_248.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.536329
# std                                             0.172554
# min                                             0.213052
# 25%                                             0.425389
# 50%                                             0.473025
# 75%                                             0.625182
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.579936
# std                                             0.213792
# min                                             0.244324
# 25%                                             0.435783
# 50%                                             0.464851
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_248['ICE BofA US GNMA Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   44.0  0.582675
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  240.0  0.500891
#  2                                           combined  284.0  0.513561
#
#           SD        SE  95% Conf.  Interval
#  0  0.227861  0.034351   0.513399  0.651950
#  1  0.191526  0.012363   0.476537  0.525245
#  2  0.199365  0.011830   0.490275  0.536848  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.0818
#  1                              Degrees of freedom =   54.6955
#  2                                               t =    2.2401
#  3                           Two side test p value =    0.0292
#  4                          Difference < 0 p value =    0.9854
#  5                          Difference > 0 p value =    0.0146
# ...

# %%
# Selecting 
highspread_249 = df_24_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_249 = df_24_Agg[(df_24_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_249)]

# %%
normalized_df_249.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.536329
# std                                             0.172554
# min                                             0.213052
# 25%                                             0.425389
# 50%                                             0.473025
# 75%                                             0.625182
# max                                             0.966919
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.579936
# std                                             0.213792
# min                                             0.244324
# 25%                                             0.435783
# 50%                                             0.464851
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_249['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_24_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   44.0  0.582319
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  240.0  0.501814
#  2                                           combined  284.0  0.514287
#
#           SD        SE  95% Conf.  Interval
#  0  0.228292  0.034416   0.512912  0.651726
#  1  0.191394  0.012354   0.477477  0.526152
#  2  0.199266  0.011824   0.491012  0.537561  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.0805
#  1                              Degrees of freedom =   54.6328
#  2                                               t =    2.2016
#  3                           Two side test p value =    0.0319
#  4                          Difference < 0 p value =    0.9840
#  5                          Difference > 0 p value =    0.0160
# ...

# %% [markdown]
# # 36 Month Below

# %%
# Selecting 
highspread_361 = df_36_Agg["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_361 = df_36_Agg[(df_36_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_361)]

# %%
normalized_df_361.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.476390
# std                                             0.146101
# min                                             0.214689
# 25%                                             0.364052
# 50%                                             0.462334
# 75%                                             0.539413
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.523070
# std                                             0.140984
# min                                             0.262734
# 25%                                             0.399459
# 50%                                             0.532847
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_361['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_36_Agg['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.476390
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  234.0  0.500938
#  2                                           combined  288.0  0.496336
#
#           SD        SE  95% Conf.  Interval
#  0  0.146101  0.019882   0.436513  0.516268
#  1  0.147081  0.009615   0.481995  0.519882
#  2  0.146958  0.008660   0.479291  0.513380  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...  -0.0245
#  1                              Degrees of freedom =   79.6984
#  2                                               t =   -1.1115
#  3                           Two side test p value =    0.2697
#  4                          Difference < 0 p value =    0.1348
#  5                          Difference > 0 p value =    0.8652
# ...

# %%
# Selecting 
highspread_362 = df_36_Agg["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_362 = df_36_Agg[(df_36_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_362)]

# %%
normalized_df_362.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.435546
# std                                             0.122283
# min                                             0.214689
# 25%                                             0.355268
# 50%                                             0.383461
# 75%                                             0.509769
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.488459
# std                                             0.132838
# min                                             0.262734
# 25%                                             0.376043
# 50%                                             0.465694
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_362['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_36_Agg['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.488459
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  230.0  0.505035
#  2                                           combined  277.0  0.502222
#
#           SD        SE  95% Conf.  Interval
#  0  0.132838  0.019376   0.449456  0.527462
#  1  0.165769  0.010931   0.483498  0.526572
#  2  0.160561  0.009647   0.483231  0.521214  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0166
#  1                              Degrees of freedom =   78.3411
#  2                                               t =   -0.7451
#  3                           Two side test p value =    0.4584
#  4                          Difference < 0 p value =    0.2292
#  5                          Difference > 0 p value =    0.7708
# ...

# %%
# Selecting 
highspread_363 = df_36_Agg["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_363 = df_36_Agg[(df_36_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_363)]

# %%
normalized_df_363.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.450308
# std                                             0.144076
# min                                             0.214689
# 25%                                             0.351846
# 50%                                             0.381886
# 75%                                             0.523926
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.504020
# std                                             0.146963
# min                                             0.262734
# 25%                                             0.376341
# 50%                                             0.470467
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_363['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.483815
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  226.0  0.487763
#  2                                           combined  275.0  0.487060
#
#           SD        SE  95% Conf.  Interval
#  0  0.140226  0.020032   0.443537  0.524092
#  1  0.184291  0.012259   0.463607  0.511920
#  2  0.177021  0.010675   0.466045  0.508075  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...  -0.0039
#  1                              Degrees of freedom =   88.0488
#  2                                               t =   -0.1681
#  3                           Two side test p value =    0.8669
#  4                          Difference < 0 p value =    0.4334
#  5                          Difference > 0 p value =    0.5666
# ...

# %%
# Selecting 
highspread_364 = df_36_Agg["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_364 = df_36_Agg[(df_36_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_364)]

# %%
normalized_df_364.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.437805
# std                                             0.132451
# min                                             0.214689
# 25%                                             0.355190
# 50%                                             0.378919
# 75%                                             0.515992
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.493380
# std                                             0.141317
# min                                             0.262734
# 25%                                             0.375191
# 50%                                             0.459888
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_364['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   43.0  0.473257
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  224.0  0.501646
#  2                                           combined  267.0  0.497074
#
#           SD        SE  95% Conf.  Interval
#  0  0.167117  0.025485   0.421826  0.524688
#  1  0.169674  0.011337   0.479305  0.523987
#  2  0.169276  0.010360   0.476677  0.517471  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...  -0.0284
#  1                              Degrees of freedom =   59.8255
#  2                                               t =   -1.0178
#  3                           Two side test p value =    0.3129
#  4                          Difference < 0 p value =    0.1564
#  5                          Difference > 0 p value =    0.8436
# ...

# %%
# Selecting 
highspread_365 = df_36_Agg["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_365 = df_36_Agg[(df_36_Agg['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_365)]

# %%
normalized_df_365.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.448252
# std                                             0.138177
# min                                             0.214689
# 25%                                             0.355268
# 50%                                             0.383461
# 75%                                             0.520070
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.500131
# std                                             0.141620
# min                                             0.262734
# 25%                                             0.376043
# 50%                                             0.475241
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_365['ICE BofA US FNMA Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   46.0  0.477591
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  223.0  0.499337
#  2                                           combined  269.0  0.495619
#
#           SD        SE  95% Conf.  Interval
#  0  0.150287  0.022159   0.432961  0.522221
#  1  0.181889  0.012180   0.475334  0.523341
#  2  0.176819  0.010781   0.474393  0.516845  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...  -0.0217
#  1                              Degrees of freedom =   74.9156
#  2                                               t =   -0.8600
#  3                           Two side test p value =    0.3925
#  4                          Difference < 0 p value =    0.1963
#  5                          Difference > 0 p value =    0.8037
# ...

# %%
# Selecting 
highspread_366 = df_36_Agg["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_366 = df_36_Agg[(df_36_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_366)]

# %%
normalized_df_366.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.452526
# std                                             0.142842
# min                                             0.214689
# 25%                                             0.355164
# 50%                                             0.383461
# 75%                                             0.524634
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.505670
# std                                             0.147419
# min                                             0.262734
# 25%                                             0.376043
# 50%                                             0.475241
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_366['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   51.0  0.495669
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  228.0  0.491969
#  2                                           combined  279.0  0.492645
#
#           SD        SE  95% Conf.  Interval
#  0  0.141312  0.019788   0.455924  0.535413
#  1  0.184910  0.012246   0.467838  0.516099
#  2  0.177518  0.010628   0.471724  0.513566  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0037
#  1                              Degrees of freedom =   92.6414
#  2                                               t =    0.1590
#  3                           Two side test p value =    0.8740
#  4                          Difference < 0 p value =    0.5630
#  5                          Difference > 0 p value =    0.4370
# ...

# %%
# Selecting 
highspread_367 = df_36_Agg["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_367 = df_36_Agg[(df_36_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_367)]

# %%
normalized_df_367.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.430536
# std                                             0.119899
# min                                             0.214689
# 25%                                             0.355268
# 50%                                             0.383461
# 75%                                             0.502801
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.484783
# std                                             0.132806
# min                                             0.262734
# 25%                                             0.376043
# 50%                                             0.460809
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_367['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   46.0  0.445697
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  225.0  0.493928
#  2                                           combined  271.0  0.485741
#
#           SD        SE  95% Conf.  Interval
#  0  0.154792  0.022823   0.399729  0.491664
#  1  0.185323  0.012355   0.469581  0.518274
#  2  0.181151  0.011004   0.464076  0.507406  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...  -0.0482
#  1                              Degrees of freedom =   73.9627
#  2                                               t =   -1.8585
#  3                           Two side test p value =    0.0671
#  4                          Difference < 0 p value =    0.0335
#  5                          Difference > 0 p value =    0.9665
# ...

# %%
# Selecting 
highspread_368 = df_36_Agg["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_368 = df_36_Agg[(df_36_Agg['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_368)]

# %%
normalized_df_368.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.445147
# std                                             0.140594
# min                                             0.214689
# 25%                                             0.355216
# 50%                                             0.380311
# 75%                                             0.521880
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.492463
# std                                             0.142905
# min                                             0.262734
# 25%                                             0.375287
# 50%                                             0.454083
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_368['ICE BofA US GNMA Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   44.0  0.502571
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  228.0  0.505071
#  2                                           combined  272.0  0.504666
#
#           SD        SE  95% Conf.  Interval
#  0  0.197888  0.029833   0.442407  0.562734
#  1  0.166511  0.011027   0.483341  0.526800
#  2  0.171577  0.010403   0.484185  0.525148  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...  -0.0025
#  1                              Degrees of freedom =   55.3578
#  2                                               t =   -0.0786
#  3                           Two side test p value =    0.9376
#  4                          Difference < 0 p value =    0.4688
#  5                          Difference > 0 p value =    0.5312
# ...

# %%
# Selecting 
highspread_369 = df_36_Agg["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_369 = df_36_Agg[(df_36_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_369)]

# %%
normalized_df_369.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.445147
# std                                             0.140594
# min                                             0.214689
# 25%                                             0.355216
# 50%                                             0.380311
# 75%                                             0.521880
# max                                             0.796857
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.492463
# std                                             0.142905
# min                                             0.262734
# 25%                                             0.375287
# 50%                                             0.454083
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_369['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_36_Agg['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   44.0  0.501279
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  228.0  0.504680
#  2                                           combined  272.0  0.504130
#
#           SD        SE  95% Conf.  Interval
#  0  0.196683  0.029651   0.441482  0.561076
#  1  0.164823  0.010916   0.483171  0.526189
#  2  0.169987  0.010307   0.483838  0.524422  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...  -0.0034
#  1                              Degrees of freedom =   55.2528
#  2                                               t =   -0.1076
#  3                           Two side test p value =    0.9147
#  4                          Difference < 0 p value =    0.4573
#  5                          Difference > 0 p value =    0.5427
# ...
