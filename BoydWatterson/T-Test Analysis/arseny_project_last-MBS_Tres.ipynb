# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Arseny_Project.xlsx', sheet_name="MBS_Tres")

# %%
df.head()
df_copy = df.copy()

# %%
df.head(6)
# Out:
#         Date  ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0 1997-01-31                                                 32
# 1 1997-02-28                                                 32
# 2 1997-03-31                                                 39
# 3 1997-04-30                                                 33
# 4 1997-05-31                                                 32
# 5 1997-06-30                                                 29
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
# 5                                                 29
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 19 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Date                                                           269 non-null    datetime64[ns]
#  1   ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS      269 non-null    int64
#  2   ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS      269 non-null    int64
#  3   ICE BofA US 15-Year Mortgage Backed Securities Index OAS       269 non-null    int64
#  4   ICE BofA US 30-Year Mortgage Backed Securities Index OAS       269 non-null    int64
#  5   ICE BofA US FNMA Mortgage Backed Securities Index OAS          269 non-null    int64
#  6   ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS  269 non-null    int64
# ...

# %%
df.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           47.732342
# std                                            33.699989
# min                                           -26.000000
# 25%                                            24.000000
# 50%                                            44.000000
# 75%                                            62.000000
# max                                           173.000000
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           52.431227
# std                                            29.909065
# min                                             8.000000
# 25%                                            28.000000
# 50%                                            49.000000
# ...

# %% [markdown]
# # Drop Outliers!

# %%
df = df.drop(columns = ['Date'])

#q1 = df.quantile(0.25)
#q3 = df.quantile(0.75)

#iqr = q3 - q1

#lower_bound = q1 -(1.5 * iqr) 
#upper_bound = q3 +(1.5 * iqr)

#print(lower_bound)
#print(upper_bound)

#df = df[(df > lower_bound) & (df < upper_bound)] # gets rid of outliers on Agg Excess Returns
#df['Date'] = df_Date
#df.head()

# %%
def lower_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    lower_bounds = q1 -(1.5 * iqr) 
    
    return lower_bounds

# %%
def upper_bound(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    upper_bounds = q3 +(1.5 * iqr) 
    
    return upper_bounds

# %%
lower_bound(df)
# Out:
# ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS       -33.000000
# ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS       -33.500000
# ICE BofA US 15-Year Mortgage Backed Securities Index OAS        -44.000000
# ICE BofA US 30-Year Mortgage Backed Securities Index OAS        -20.500000
# ICE BofA US FNMA Mortgage Backed Securities Index OAS           -25.500000
# ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS   -43.000000
# ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS   -19.000000
# ICE BofA US GNMA Mortgage Backed Securities Index OAS           -28.000000
# ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS   -28.000000
# ICE BofA 0-3 Year US Mortgage Backed Securities Index            -0.005530
# ICE BofA 3-5 Year US Mortgage Backed Securities Index            -0.006225
# ICE BofA US 15-Year Mortgage Backed Securities Index             -0.006525
# ...

# %%
upper_bound(df)
# Out:
# ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS        119.000000
# ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS        130.500000
# ICE BofA US 15-Year Mortgage Backed Securities Index OAS         132.000000
# ICE BofA US 30-Year Mortgage Backed Securities Index OAS         111.500000
# ICE BofA US FNMA Mortgage Backed Securities Index OAS            114.500000
# ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS    125.000000
# ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS    109.000000
# ICE BofA US GNMA Mortgage Backed Securities Index OAS            108.000000
# ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS    108.000000
# ICE BofA 0-3 Year US Mortgage Backed Securities Index              0.006710
# ICE BofA 3-5 Year US Mortgage Backed Securities Index              0.007335
# ICE BofA US 15-Year Mortgage Backed Securities Index               0.007115
# ...

# %%
df["Date"] = df_copy["Date"]
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
df.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           47.732342
# std                                            33.699989
# min                                           -26.000000
# 25%                                            24.000000
# 50%                                            44.000000
# 75%                                            62.000000
# max                                           173.000000
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# count                                         269.000000
# mean                                           52.431227
# std                                            29.909065
# min                                             8.000000
# 25%                                            28.000000
# 50%                                            49.000000
# ...

# %%
df1 = df.drop(columns = ['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS','ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS','ICE BofA US 15-Year Mortgage Backed Securities Index OAS','ICE BofA US 30-Year Mortgage Backed Securities Index OAS','ICE BofA US FNMA Mortgage Backed Securities Index OAS','ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS','ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS','ICE BofA US GNMA Mortgage Backed Securities Index OAS','ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'])

# %%
df1.head(36)
# Out:
#     ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                             0.00330
# 1                                             0.00067
# 2                                            -0.00168
# 3                                             0.00221
# 4                                             0.00107
# 5                                             0.00128
# 6                                            -0.00286
# 7                                             0.00292
# 8                                            -0.00094
# 9                                            -0.00148
# 10                                            0.00029
# 11                                           -0.00049
# 12                                           -0.00133
# 13                                            0.00210
# 14                                            0.00010
# 15                                            0.00140
# ...

# %% [markdown]
# # Create Excess returns

# %%
# Creating Excess Returns 3,6,9,12,24,36 for AGG
df_3_Agg = df1.rolling(3,win_type='boxcar',center=True).sum().shift(-1)
df_6_Agg = df1.rolling(6,win_type='boxcar',center=True).sum().shift(-3)
df_9_Agg = df1.rolling(9,win_type='boxcar',center=True).sum().shift(-4)
df_12_Agg = df1.rolling(12,win_type='boxcar',center=True).sum().shift(-6)
df_24_Agg = df1.rolling(24,win_type='boxcar',center=True).sum().shift(-12)
df_36_Agg = df1.rolling(36,win_type='boxcar',center=True).sum().shift(-18)

# %%
df_36_Agg.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                            0.03282
# 1                                            0.03147
# 2                                            0.03285
# 3                                            0.02990
# 4                                            0.02869
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# 0                                            0.02826
# 1                                            0.02177
# 2                                            0.02458
# 3                                            0.01965
# 4                                            0.01872
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index  \
# 0                                            0.01165
# 1                                            0.00182
# 2                                            0.00479
# 3                                           -0.00072
# ...

# %%
df_12_Agg.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         258.000000
# mean                                            0.005773
# std                                             0.009028
# min                                            -0.021050
# 25%                                            -0.000367
# 50%                                             0.005150
# 75%                                             0.011660
# max                                             0.032120
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         258.000000
# mean                                            0.004109
# std                                             0.009566
# min                                            -0.031920
# 25%                                            -0.001062
# 50%                                             0.003525
# ...

# %% [markdown]
# # Calculate Min/Max

# %%
# Now lets normalize our data (for treasury)
#df_3_Agg = df_3_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_3_Agg)
df_3_Agg_Max = column_maxes
column_mins = lower_bound(df_3_Agg)
df_3_Agg_Min = column_mins
df_3_Agg_Normal = (df_3_Agg - df_3_Agg_Min) / (df_3_Agg_Max - df_3_Agg_Min)

#df_3_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_6_Agg = df_6_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_6_Agg)
df_6_Agg_Max = column_maxes
column_mins = lower_bound(df_6_Agg)
df_6_Agg_Min = column_mins
df_6_Agg_Normal = (df_6_Agg - df_6_Agg_Min) / (df_6_Agg_Max - df_6_Agg_Min)

#df_6_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_9_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_9_Agg)
df_9_Agg_Max = column_maxes
column_mins = lower_bound(df_9_Agg)
df_9_Agg_Min = column_mins
df_9_Agg_Normal = (df_9_Agg - df_9_Agg_Min) / (df_9_Agg_Max - df_9_Agg_Min)

#df_9_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_12_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_12_Agg)
df_12_Agg_Max = column_maxes
column_mins = lower_bound(df_12_Agg)
df_12_Agg_Min = column_mins
df_12_Agg_Normal = (df_12_Agg - df_12_Agg_Min) / (df_12_Agg_Max - df_12_Agg_Min)

#df_12_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_24_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_24_Agg)
df_24_Agg_Max = column_maxes
column_mins = lower_bound(df_24_Agg)
df_24_Agg_Min = column_mins
df_24_Agg_Normal = (df_24_Agg - df_24_Agg_Min) / (df_24_Agg_Max - df_24_Agg_Min)

#df_24_Agg_Normal['Date'] = df_Date

# %%
# Now lets normalize our data (for treasury)
#df_36_Agg = df_9_Agg.drop(columns = ["Date"])

column_maxes = upper_bound(df_36_Agg)
df_36_Agg_Max = column_maxes
column_mins = lower_bound(df_36_Agg)
df_36_Agg_Min = column_mins
df_36_Agg_Normal = (df_36_Agg - df_36_Agg_Min) / (df_36_Agg_Max - df_36_Agg_Min)

#df_36_Agg_Normal['Date'] = df_Date

# %%
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal >= 0]
df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal <= 1]
df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal >= 0]
df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal <= 1]
df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal >= 0]
df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal <= 1]
df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal >= 0]
df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal <= 1]
df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal >= 0]
df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal <= 1]
df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal >= 0]
df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal <= 1]

# %%
df_3_Agg_Normal.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                           0.536290
# 1                                           0.486060
# 2                                           0.504493
# 3                                           0.640899
# 4                                           0.407258
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# 0                                           0.581070
# 1                                           0.530985
# 2                                           0.521647
# 3                                           0.618421
# 4                                           0.403650
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index  \
# 0                                           0.552727
# 1                                           0.511156
# 2                                           0.526411
# 3                                           0.639302
# ...

# %%
df_12_Agg_Normal.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         256.000000
# mean                                            0.502679
# std                                             0.181912
# min                                             0.044455
# 25%                                             0.375104
# 50%                                             0.489685
# 75%                                             0.624584
# max                                             0.971290
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         247.000000
# mean                                            0.501229
# std                                             0.199994
# min                                             0.008006
# 25%                                             0.378942
# 50%                                             0.486172
# ...

# %%
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
pd.options.display.max_rows  = 280 # want to see all columns

df_36_Agg.head(280)
# Out:
#      ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                              0.03282
# 1                                              0.03147
# 2                                              0.03285
# 3                                              0.02990
# 4                                              0.02869
# 5                                              0.02497
# 6                                              0.02494
# 7                                              0.02889
# 8                                              0.02790
# 9                                              0.03151
# 10                                             0.03162
# 11                                             0.03034
# 12                                             0.03014
# 13                                             0.03337
# 14                                             0.03068
# 15                                             0.02954
# ...

# %%
df_3_Agg_Normal.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                         253.000000
# mean                                            0.504710
# std                                             0.184225
# min                                             0.010484
# 25%                                             0.386521
# 50%                                             0.492512
# 75%                                             0.624309
# max                                             0.988364
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                         257.000000
# mean                                            0.521589
# std                                             0.199754
# min                                             0.043718
# 25%                                             0.396435
# 50%                                             0.514856
# ...

# %%
df.head()
# Out:
#    ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# 4                                                 32
#
#    ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS  \
# 0                                                 26
# 1                                                 26
# 2                                                 37
# 3                                                 33
# 4                                                 31
#
#    ICE BofA US 15-Year Mortgage Backed Securities Index OAS  \
# 0                                                 32
# 1                                                 32
# 2                                                 39
# 3                                                 33
# ...

# %%
# Adding back spreads so we can do the selective query 
df_3_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_3_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_3_Agg_Normal = df_3_Agg_Normal[df_3_Agg_Normal > 0]
df_3_Agg_Normal["Date"] = df_copy["Date"]

df_6_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_6_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_6_Agg_Normal = df_6_Agg_Normal[df_6_Agg_Normal > 0]
df_6_Agg_Normal["Date"] = df_copy["Date"]


df_9_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_9_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_9_Agg_Normal = df_9_Agg_Normal[df_9_Agg_Normal > 0]
df_9_Agg_Normal["Date"] = df_copy["Date"]


df_12_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_12_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_12_Agg_Normal = df_12_Agg_Normal[df_12_Agg_Normal > 0]
df_12_Agg_Normal["Date"] = df_copy["Date"]


df_24_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_24_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_24_Agg_Normal = df_24_Agg_Normal[df_24_Agg_Normal > 0]
df_24_Agg_Normal["Date"] = df_copy["Date"]


df_36_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"] = df["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA Mortgage Backed Securities Index OAS"]
df_36_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"] = df["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"]
#df_36_Agg_Normal = df_36_Agg_Normal[df_36_Agg_Normal > 0]
df_36_Agg_Normal["Date"] = df_copy["Date"]

# %%
pd.options.display.max_rows  = 280 # want to see all columns
pd.options.display.max_columns  = 280 # want to see all columns



df_3_Agg_Normal.head(280)
# Out:
#      ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# 0                                             0.536290
# 1                                             0.486060
# 2                                             0.504493
# 3                                             0.640899
# 4                                             0.407258
# 5                                             0.492512
# 6                                             0.390207
# 7                                             0.453802
# 8                                             0.332604
# 9                                             0.353341
# 10                                            0.360253
# 11                                            0.443664
# 12                                            0.470853
# 13                                            0.596659
# 14                                            0.524309
# 15                                            0.482373
# ...

# %% [markdown]
# # Now we move on to our Hypothesis Testing Segment
#
# ## Our hypothesis is that spreads that are in the 80th percentile have higher excess returns than average case.

# %%
import researchpy # for t-test stuff!

# %% [markdown]
# # 3 Month Below

# %%
# Selecting 
highspread_31 = df_3_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_31 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_31)]

# %%
normalized_df_31.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.517069
# std                                             0.207769
# min                                             0.059793
# 25%                                             0.412327
# 50%                                             0.532604
# 75%                                             0.676382
# max                                             0.950115
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.528394
# std                                             0.238186
# min                                             0.052207
# 25%                                             0.390174
# 50%                                             0.493846
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_31['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   45.0  0.517069
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  253.0  0.504710
#  2                                           combined  298.0  0.506576
#
#           SD        SE  95% Conf.  Interval
#  0  0.207769  0.030972   0.454648  0.579489
#  1  0.184225  0.011582   0.481900  0.527520
#  2  0.187648  0.010870   0.485184  0.527968  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0124
#  1                              Degrees of freedom =   56.9718
#  2                                               t =    0.3737
#  3                           Two side test p value =    0.7100
#  4                          Difference < 0 p value =    0.6450
#  5                          Difference > 0 p value =    0.3550
# ...

# %%
# Selecting 
highspread_32 = df_3_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_32 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_32)]

# %%
normalized_df_32.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.469491
# std                                             0.176820
# min                                             0.059793
# 25%                                             0.349654
# 50%                                             0.491129
# 75%                                             0.580184
# max                                             0.778687
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.481103
# std                                             0.235072
# min                                             0.052207
# 25%                                             0.330751
# 50%                                             0.473472
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_32['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   46.0  0.481103
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  257.0  0.521589
#  2                                           combined  303.0  0.515443
#
#           SD        SE  95% Conf.  Interval
#  0  0.235072  0.034659   0.411295  0.550911
#  1  0.199754  0.012460   0.497051  0.546127
#  2  0.205596  0.011811   0.492200  0.538685  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0405
#  1                              Degrees of freedom =   57.2157
#  2                                               t =   -1.0992
#  3                           Two side test p value =    0.2763
#  4                          Difference < 0 p value =    0.1381
#  5                          Difference > 0 p value =    0.8619
# ...

# %%
# Selecting 
highspread_33 = df_3_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_33 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_33)]

# %%
normalized_df_33.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.478569
# std                                             0.206543
# min                                             0.059793
# 25%                                             0.307488
# 50%                                             0.509562
# 75%                                             0.578456
# max                                             0.984677
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.485292
# std                                             0.254132
# min                                             0.052207
# 25%                                             0.292445
# 50%                                             0.473472
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_33['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   50.0  0.473093
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  261.0  0.502448
#  2                                           combined  311.0  0.497729
#
#           SD        SE  95% Conf.  Interval
#  0  0.253585  0.035862   0.401025  0.545161
#  1  0.180410  0.011167   0.480459  0.524437
#  2  0.193853  0.010992   0.476099  0.519358  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...  -0.0294
#  1                              Degrees of freedom =   58.8587
#  2                                               t =   -0.7815
#  3                           Two side test p value =    0.4376
#  4                          Difference < 0 p value =    0.2188
#  5                          Difference > 0 p value =    0.7812
# ...

# %%
# Selecting 
highspread_34 = df_3_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_34 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_34)]

# %%
normalized_df_34.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          40.000000
# mean                                            0.465806
# std                                             0.175003
# min                                             0.059793
# 25%                                             0.349654
# 50%                                             0.491129
# 75%                                             0.577880
# max                                             0.778687
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.487800
# std                                             0.234490
# min                                             0.052207
# 25%                                             0.336375
# 50%                                             0.482598
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_34['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   44.0  0.468339
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  259.0  0.499200
#  2                                           combined  303.0  0.494718
#
#           SD        SE  95% Conf.  Interval
#  0  0.221224  0.033351   0.401081  0.535598
#  1  0.182682  0.011351   0.476847  0.521553
#  2  0.188673  0.010839   0.473389  0.516048  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...  -0.0309
#  1                              Degrees of freedom =   53.4202
#  2                                               t =   -0.8760
#  3                           Two side test p value =    0.3850
#  4                          Difference < 0 p value =    0.1925
#  5                          Difference > 0 p value =    0.8075
# ...

# %%
# Selecting 
highspread_35 = df_3_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_35 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_35)]

# %%
normalized_df_35.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.469219
# std                                             0.186195
# min                                             0.059793
# 25%                                             0.323502
# 50%                                             0.469470
# 75%                                             0.577880
# max                                             0.950115
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.484395
# std                                             0.240015
# min                                             0.052207
# 25%                                             0.323430
# 50%                                             0.482598
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_35['ICE BofA US FNMA Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   46.0  0.478056
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  255.0  0.504463
#  2                                           combined  301.0  0.500427
#
#           SD        SE  95% Conf.  Interval
#  0  0.230670  0.034010   0.409555  0.546556
#  1  0.184846  0.011576   0.481667  0.527259
#  2  0.192356  0.011087   0.478609  0.522246  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...  -0.0264
#  1                              Degrees of freedom =   55.8965
#  2                                               t =   -0.7350
#  3                           Two side test p value =    0.4654
#  4                          Difference < 0 p value =    0.2327
#  5                          Difference > 0 p value =    0.7673
# ...

# %%
# Selecting 
highspread_36 = df_3_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_36 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_36)]

# %%
normalized_df_36.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.463123
# std                                             0.189394
# min                                             0.059793
# 25%                                             0.316129
# 50%                                             0.452189
# 75%                                             0.571083
# max                                             0.950115
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.478136
# std                                             0.243417
# min                                             0.052207
# 25%                                             0.302207
# 50%                                             0.464346
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_36['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   49.0  0.478842
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  259.0  0.508408
#  2                                           combined  308.0  0.503705
#
#           SD        SE  95% Conf.  Interval
#  0  0.246146  0.035164   0.408140  0.549543
#  1  0.184048  0.011436   0.485888  0.530929
#  2  0.195084  0.011116   0.481832  0.525578  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...  -0.0296
#  1                              Degrees of freedom =   58.5693
#  2                                               t =   -0.7996
#  3                           Two side test p value =    0.4272
#  4                          Difference < 0 p value =    0.2136
#  5                          Difference > 0 p value =    0.7864
# ...

# %%
# Selecting 
highspread_37 = df_3_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_37 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_37)]

# %%
normalized_df_37.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.466429
# std                                             0.174787
# min                                             0.059793
# 25%                                             0.324770
# 50%                                             0.479608
# 75%                                             0.577304
# max                                             0.780069
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.484295
# std                                             0.235414
# min                                             0.052207
# 25%                                             0.323430
# 50%                                             0.482598
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_37['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   47.0  0.467124
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  257.0  0.496568
#  2                                           combined  304.0  0.492016
#
#           SD        SE  95% Conf.  Interval
#  0  0.220773  0.032203   0.402303  0.531945
#  1  0.183216  0.011429   0.474062  0.519074
#  2  0.189406  0.010863   0.470639  0.513393  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...  -0.0294
#  1                              Degrees of freedom =   58.1515
#  2                                               t =   -0.8617
#  3                           Two side test p value =    0.3924
#  4                          Difference < 0 p value =    0.1962
#  5                          Difference > 0 p value =    0.8038
# ...

# %%
# Selecting 
highspread_38 = df_3_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_38 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_38)]

# %%
normalized_df_38.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.492233
# std                                             0.195838
# min                                             0.059793
# 25%                                             0.372926
# 50%                                             0.527074
# 75%                                             0.597120
# max                                             0.950115
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.499188
# std                                             0.239487
# min                                             0.052207
# 25%                                             0.353141
# 50%                                             0.490662
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_38['ICE BofA US GNMA Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   50.0  0.499237
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  264.0  0.504205
#  2                                           combined  314.0  0.503414
#
#           SD        SE  95% Conf.  Interval
#  0  0.201064  0.028435   0.442096  0.556379
#  1  0.178548  0.010989   0.482568  0.525842
#  2  0.181986  0.010270   0.483207  0.523621  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...  -0.0050
#  1                              Degrees of freedom =   64.4615
#  2                                               t =   -0.1630
#  3                           Two side test p value =    0.8711
#  4                          Difference < 0 p value =    0.4355
#  5                          Difference > 0 p value =    0.5645
# ...

# %%
# Selecting 
highspread_39 = df_3_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_39 = df_3_Agg_Normal[(df_3_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_39)]

# %%
normalized_df_39.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.490965
# std                                             0.193874
# min                                             0.059793
# 25%                                             0.357949
# 50%                                             0.527074
# 75%                                             0.607719
# max                                             0.950115
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.489132
# std                                             0.239400
# min                                             0.052207
# 25%                                             0.324278
# 50%                                             0.486630
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_39['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_3_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   52.0  0.487601
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  263.0  0.506033
#  2                                           combined  315.0  0.502990
#
#           SD        SE  95% Conf.  Interval
#  0  0.206678  0.028661   0.430061  0.545140
#  1  0.176837  0.010904   0.484562  0.527504
#  2  0.181872  0.010247   0.482828  0.523152  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...  -0.0184
#  1                              Degrees of freedom =   66.5611
#  2                                               t =   -0.6011
#  3                           Two side test p value =    0.5498
#  4                          Difference < 0 p value =    0.2749
#  5                          Difference > 0 p value =    0.7251
# ...

# %% [markdown]
# # 6 Month Below

# %%
# Selecting 
highspread_61 = df_6_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_61 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_61)]

# %%
normalized_df_61.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.524709
# std                                             0.213068
# min                                             0.092881
# 25%                                             0.430960
# 50%                                             0.538907
# 75%                                             0.621358
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.474973
# std                                             0.227206
# min                                             0.050102
# 25%                                             0.350165
# 50%                                             0.480061
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_61['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   49.0  0.524709
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  251.0  0.499968
#  2                                           combined  300.0  0.504009
#
#           SD        SE  95% Conf.  Interval
#  0  0.213068  0.030438   0.463509  0.585910
#  1  0.188029  0.011868   0.476593  0.523342
#  2  0.192179  0.011095   0.482174  0.525844  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0247
#  1                              Degrees of freedom =   63.4230
#  2                                               t =    0.7573
#  3                           Two side test p value =    0.4517
#  4                          Difference < 0 p value =    0.7742
#  5                          Difference > 0 p value =    0.2258
# ...

# %%
# Selecting 
highspread_62 = df_6_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_62 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_62)]

# %%
normalized_df_62.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.490460
# std                                             0.203248
# min                                             0.092881
# 25%                                             0.366060
# 50%                                             0.489901
# 75%                                             0.600166
# max                                             0.935596
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.450631
# std                                             0.211392
# min                                             0.050102
# 25%                                             0.345464
# 50%                                             0.455774
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_62['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   46.0  0.450631
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  253.0  0.500907
#  2                                           combined  299.0  0.493172
#
#           SD        SE  95% Conf.  Interval
#  0  0.211392  0.031168   0.387855  0.513406
#  1  0.201616  0.012675   0.475943  0.525870
#  2  0.203599  0.011774   0.470000  0.516343  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0503
#  1                              Degrees of freedom =   60.8190
#  2                                               t =   -1.4942
#  3                           Two side test p value =    0.1403
#  4                          Difference < 0 p value =    0.0701
#  5                          Difference > 0 p value =    0.9299
# ...

# %%
# Selecting 
highspread_63 = df_6_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_63 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_63)]

# %%
normalized_df_63.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.512720
# std                                             0.217698
# min                                             0.092881
# 25%                                             0.389238
# 50%                                             0.505629
# 75%                                             0.614983
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.471071
# std                                             0.221364
# min                                             0.050102
# 25%                                             0.347657
# 50%                                             0.490246
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_63['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   46.0  0.503036
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  246.0  0.513888
#  2                                           combined  292.0  0.512178
#
#           SD        SE  95% Conf.  Interval
#  0  0.246487  0.036343   0.429839  0.576234
#  1  0.199054  0.012691   0.488890  0.538886
#  2  0.206809  0.012103   0.488359  0.535998  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...  -0.0109
#  1                              Degrees of freedom =   56.4903
#  2                                               t =   -0.2819
#  3                           Two side test p value =    0.7791
#  4                          Difference < 0 p value =    0.3895
#  5                          Difference > 0 p value =    0.6105
# ...

# %%
# Selecting 
highspread_64 = df_6_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_64 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_64)]

# %%
normalized_df_64.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          41.000000
# mean                                            0.483222
# std                                             0.209291
# min                                             0.092881
# 25%                                             0.337583
# 50%                                             0.487583
# 75%                                             0.575331
# max                                             0.935596
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.452126
# std                                             0.224603
# min                                             0.050102
# 25%                                             0.308798
# 50%                                             0.465959
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_64['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   44.0  0.494221
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  257.0  0.501868
#  2                                           combined  301.0  0.500750
#
#           SD        SE  95% Conf.  Interval
#  0  0.205942  0.031047   0.431608  0.556833
#  1  0.192074  0.011981   0.478274  0.525463
#  2  0.193824  0.011172   0.478765  0.522735  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...  -0.0076
#  1                              Degrees of freedom =   56.5504
#  2                                               t =   -0.2298
#  3                           Two side test p value =    0.8191
#  4                          Difference < 0 p value =    0.4095
#  5                          Difference > 0 p value =    0.5905
# ...

# %%
# Selecting 
highspread_65 = df_6_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_65 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_65)]

# %%
normalized_df_65.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.498076
# std                                             0.213557
# min                                             0.092881
# 25%                                             0.366060
# 50%                                             0.489901
# 75%                                             0.600166
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.467386
# std                                             0.229711
# min                                             0.050102
# 25%                                             0.331362
# 50%                                             0.472853
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_65['ICE BofA US FNMA Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   48.0  0.497237
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  257.0  0.494669
#  2                                           combined  305.0  0.495073
#
#           SD        SE  95% Conf.  Interval
#  0  0.215738  0.031139   0.434593  0.559881
#  1  0.198289  0.012369   0.470311  0.519027
#  2  0.200766  0.011496   0.472452  0.517695  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0026
#  1                              Degrees of freedom =   62.7147
#  2                                               t =    0.0766
#  3                           Two side test p value =    0.9392
#  4                          Difference < 0 p value =    0.5304
#  5                          Difference > 0 p value =    0.4696
# ...

# %%
# Selecting 
highspread_66 = df_6_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_66 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_66)]

# %%
normalized_df_66.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.504245
# std                                             0.210334
# min                                             0.092881
# 25%                                             0.370695
# 50%                                             0.496854
# 75%                                             0.613576
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.471900
# std                                             0.223043
# min                                             0.050102
# 25%                                             0.348754
# 50%                                             0.480061
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_66['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   47.0  0.519828
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  248.0  0.520904
#  2                                           combined  295.0  0.520733
#
#           SD        SE  95% Conf.  Interval
#  0  0.240840  0.035130   0.449115  0.590541
#  1  0.203957  0.012951   0.495395  0.546413
#  2  0.209819  0.012216   0.496691  0.544775  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...  -0.0011
#  1                              Degrees of freedom =   59.1504
#  2                                               t =   -0.0287
#  3                           Two side test p value =    0.9772
#  4                          Difference < 0 p value =    0.4886
#  5                          Difference > 0 p value =    0.5114
# ...

# %%
# Selecting 
highspread_67 = df_6_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_67 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_67)]

# %%
normalized_df_67.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.495515
# std                                             0.203150
# min                                             0.092881
# 25%                                             0.368377
# 50%                                             0.493377
# 75%                                             0.608113
# max                                             0.935596
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.465706
# std                                             0.226287
# min                                             0.050102
# 25%                                             0.331362
# 50%                                             0.472853
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_67['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   48.0  0.499995
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  257.0  0.499020
#  2                                           combined  305.0  0.499174
#
#           SD        SE  95% Conf.  Interval
#  0  0.201647  0.029105   0.441442  0.558547
#  1  0.186252  0.011618   0.476141  0.521900
#  2  0.188412  0.010788   0.477944  0.520403  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0010
#  1                              Degrees of freedom =   62.8783
#  2                                               t =    0.0311
#  3                           Two side test p value =    0.9753
#  4                          Difference < 0 p value =    0.5124
#  5                          Difference > 0 p value =    0.4876
# ...

# %%
# Selecting 
highspread_68 = df_6_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_68 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_68)]

# %%
normalized_df_68.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.505587
# std                                             0.210544
# min                                             0.092881
# 25%                                             0.370695
# 50%                                             0.496854
# 75%                                             0.603311
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.469086
# std                                             0.216077
# min                                             0.050102
# 25%                                             0.348754
# 50%                                             0.472853
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_68['ICE BofA US GNMA Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   47.0  0.507545
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  262.0  0.501030
#  2                                           combined  309.0  0.502021
#
#           SD        SE  95% Conf.  Interval
#  0  0.179943  0.026247   0.454712  0.560379
#  1  0.189196  0.011689   0.478014  0.524046
#  2  0.187548  0.010669   0.481027  0.523015  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.0065
#  1                              Degrees of freedom =   65.5992
#  2                                               t =    0.2268
#  3                           Two side test p value =    0.8213
#  4                          Difference < 0 p value =    0.5893
#  5                          Difference > 0 p value =    0.4107
# ...

# %%
# Selecting 
highspread_69 = df_6_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_69 = df_6_Agg_Normal[(df_6_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_69)]

# %%
normalized_df_69.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.506891
# std                                             0.206918
# min                                             0.092881
# 25%                                             0.375331
# 50%                                             0.496854
# 75%                                             0.606457
# max                                             0.950828
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.465339
# std                                             0.212492
# min                                             0.050102
# 25%                                             0.346561
# 50%                                             0.465959
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_69['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_6_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   49.0  0.493657
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  262.0  0.500323
#  2                                           combined  311.0  0.499272
#
#           SD        SE  95% Conf.  Interval
#  0  0.189312  0.027045   0.439280  0.548033
#  1  0.193974  0.011984   0.476726  0.523920
#  2  0.192961  0.010942   0.477743  0.520802  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...  -0.0067
#  1                              Degrees of freedom =   68.2162
#  2                                               t =   -0.2254
#  3                           Two side test p value =    0.8224
#  4                          Difference < 0 p value =    0.4112
#  5                          Difference > 0 p value =    0.5888
# ...

# %% [markdown]
# # 9 Month Below

# %%
# Selecting 
highspread_91 = df_9_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_91 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_91)]

# %%
normalized_df_91.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.542941
# std                                             0.172267
# min                                             0.251004
# 25%                                             0.447289
# 50%                                             0.517319
# 75%                                             0.625126
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.504085
# std                                             0.187913
# min                                             0.104323
# 25%                                             0.374664
# 50%                                             0.518126
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_91['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   51.0  0.542941
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  256.0  0.492957
#  2                                           combined  307.0  0.501261
#
#           SD        SE  95% Conf.  Interval
#  0  0.172267  0.024122   0.494491  0.591392
#  1  0.186422  0.011651   0.470012  0.515902
#  2  0.184817  0.010548   0.480505  0.522017  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0500
#  1                              Degrees of freedom =   75.2488
#  2                                               t =    1.8659
#  3                           Two side test p value =    0.0660
#  4                          Difference < 0 p value =    0.9670
#  5                          Difference > 0 p value =    0.0330
# ...

# %%
# Selecting 
highspread_92 = df_9_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_92 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_92)]

# %%
normalized_df_92.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.514815
# std                                             0.152838
# min                                             0.251004
# 25%                                             0.425326
# 50%                                             0.515437
# 75%                                             0.605233
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.480760
# std                                             0.179626
# min                                             0.104323
# 25%                                             0.373792
# 50%                                             0.491810
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_92['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   47.0  0.480760
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  253.0  0.510166
#  2                                           combined  300.0  0.505559
#
#           SD        SE  95% Conf.  Interval
#  0  0.179626  0.026201   0.428020  0.533501
#  1  0.202435  0.012727   0.485102  0.535231
#  2  0.199040  0.011492   0.482945  0.528174  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0294
#  1                              Degrees of freedom =   69.5608
#  2                                               t =   -1.0095
#  3                           Two side test p value =    0.3162
#  4                          Difference < 0 p value =    0.1581
#  5                          Difference > 0 p value =    0.8419
# ...

# %%
# Selecting 
highspread_93 = df_9_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_93 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_93)]

# %%
normalized_df_93.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.534372
# std                                             0.162287
# min                                             0.251004
# 25%                                             0.444716
# 50%                                             0.519578
# 75%                                             0.625063
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.485990
# std                                             0.171151
# min                                             0.104323
# 25%                                             0.375537
# 50%                                             0.514098
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_93['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.495590
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  254.0  0.495734
#  2                                           combined  303.0  0.495711
#
#           SD        SE  95% Conf.  Interval
#  0  0.192829  0.027547   0.440203  0.550977
#  1  0.187567  0.011769   0.472556  0.518912
#  2  0.188104  0.010806   0.474446  0.516976  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...  -0.0001
#  1                              Degrees of freedom =   66.7004
#  2                                               t =   -0.0048
#  3                           Two side test p value =    0.9962
#  4                          Difference < 0 p value =    0.4981
#  5                          Difference > 0 p value =    0.5019
# ...

# %%
# Selecting 
highspread_94 = df_9_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_94 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_94)]

# %%
normalized_df_94.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          43.000000
# mean                                            0.505481
# std                                             0.150567
# min                                             0.251004
# 25%                                             0.419679
# 50%                                             0.513052
# 75%                                             0.570156
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.468430
# std                                             0.170516
# min                                             0.104323
# 25%                                             0.371845
# 50%                                             0.484023
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_94['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   44.0  0.486833
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  255.0  0.507024
#  2                                           combined  299.0  0.504053
#
#           SD        SE  95% Conf.  Interval
#  0  0.151400  0.022824   0.440803  0.532863
#  1  0.188755  0.011820   0.483746  0.530302
#  2  0.183648  0.010621   0.483152  0.524954  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...  -0.0202
#  1                              Degrees of freedom =   68.3262
#  2                                               t =   -0.7855
#  3                           Two side test p value =    0.4349
#  4                          Difference < 0 p value =    0.2174
#  5                          Difference > 0 p value =    0.7826
# ...

# %%
# Selecting 
highspread_95 = df_9_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_95 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_95)]

# %%
normalized_df_95.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.520374
# std                                             0.155869
# min                                             0.251004
# 25%                                             0.430974
# 50%                                             0.516566
# 75%                                             0.618223
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.482081
# std                                             0.175691
# min                                             0.104323
# 25%                                             0.374664
# 50%                                             0.492750
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_95['ICE BofA US FNMA Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   48.0  0.489045
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  254.0  0.505923
#  2                                           combined  302.0  0.503241
#
#           SD        SE  95% Conf.  Interval
#  0  0.163894  0.023656   0.441455  0.536634
#  1  0.186824  0.011722   0.482838  0.529009
#  2  0.183221  0.010543   0.482493  0.523988  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...  -0.0169
#  1                              Degrees of freedom =   72.1085
#  2                                               t =   -0.6393
#  3                           Two side test p value =    0.5246
#  4                          Difference < 0 p value =    0.2623
#  5                          Difference > 0 p value =    0.7377
# ...

# %%
# Selecting 
highspread_96 = df_9_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_96 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_96)]

# %%
normalized_df_96.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.527180
# std                                             0.156356
# min                                             0.251004
# 25%                                             0.442269
# 50%                                             0.517319
# 75%                                             0.623494
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.488733
# std                                             0.171565
# min                                             0.104323
# 25%                                             0.376477
# 50%                                             0.506713
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_96['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   50.0  0.501600
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  255.0  0.490179
#  2                                           combined  305.0  0.492052
#
#           SD        SE  95% Conf.  Interval
#  0  0.173154  0.024488   0.452390  0.550810
#  1  0.184571  0.011558   0.467417  0.512942
#  2  0.182521  0.010451   0.471486  0.512617  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0114
#  1                              Degrees of freedom =   72.5702
#  2                                               t =    0.4218
#  3                           Two side test p value =    0.6744
#  4                          Difference < 0 p value =    0.6628
#  5                          Difference > 0 p value =    0.3372
# ...

# %%
# Selecting 
highspread_97 = df_9_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_97 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_97)]

# %%
normalized_df_97.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.510900
# std                                             0.140592
# min                                             0.251004
# 25%                                             0.430974
# 50%                                             0.516566
# 75%                                             0.599398
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.490518
# std                                             0.188740
# min                                             0.104323
# 25%                                             0.374664
# 50%                                             0.492750
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_97['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   48.0  0.499581
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  255.0  0.501557
#  2                                           combined  303.0  0.501244
#
#           SD        SE  95% Conf.  Interval
#  0  0.171177  0.024707   0.449877  0.549286
#  1  0.185329  0.011606   0.478701  0.524412
#  2  0.182889  0.010507   0.480568  0.521919  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...  -0.0020
#  1                              Degrees of freedom =   69.4035
#  2                                               t =   -0.0724
#  3                           Two side test p value =    0.9425
#  4                          Difference < 0 p value =    0.4713
#  5                          Difference > 0 p value =    0.5287
# ...

# %%
# Selecting 
highspread_98 = df_9_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_98 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_98)]

# %%
normalized_df_98.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.523845
# std                                             0.155263
# min                                             0.251004
# 25%                                             0.436621
# 50%                                             0.516943
# 75%                                             0.617344
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.483602
# std                                             0.165916
# min                                             0.104323
# 25%                                             0.376477
# 50%                                             0.492750
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_98['ICE BofA US GNMA Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   46.0  0.502411
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  253.0  0.502976
#  2                                           combined  299.0  0.502889
#
#           SD        SE  95% Conf.  Interval
#  0  0.126173  0.018603   0.464943   0.53988
#  1  0.184416  0.011594   0.480142   0.52581
#  2  0.176532  0.010209   0.482798   0.52298  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...  -0.0006
#  1                              Degrees of freedom =   84.4717
#  2                                               t =   -0.0258
#  3                           Two side test p value =    0.9795
#  4                          Difference < 0 p value =    0.4898
#  5                          Difference > 0 p value =    0.5102
# ...

# %%
# Selecting 
highspread_99 = df_9_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_99 = df_9_Agg_Normal[(df_9_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_99)]

# %%
normalized_df_99.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.526216
# std                                             0.154310
# min                                             0.251004
# 25%                                             0.442269
# 50%                                             0.517319
# 75%                                             0.619980
# max                                             0.988454
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.481869
# std                                             0.164533
# min                                             0.104323
# 25%                                             0.377417
# 50%                                             0.491810
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_99['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_9_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   47.0  0.492430
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  254.0  0.498859
#  2                                           combined  301.0  0.497855
#
#           SD        SE  95% Conf.  Interval
#  0  0.128224  0.018703   0.454782  0.530078
#  1  0.182241  0.011435   0.476339  0.521378
#  2  0.174742  0.010072   0.478034  0.517676  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...  -0.0064
#  1                              Degrees of freedom =   84.6638
#  2                                               t =   -0.2933
#  3                           Two side test p value =    0.7700
#  4                          Difference < 0 p value =    0.3850
#  5                          Difference > 0 p value =    0.6150
# ...

# %% [markdown]
# # 12 Month Below

# %%
# Selecting 
highspread_121 = df_12_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_121 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_121)]

# %%
normalized_df_121.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.573255
# std                                             0.168478
# min                                             0.219679
# 25%                                             0.455389
# 50%                                             0.572620
# 75%                                             0.672391
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.496723
# std                                             0.216454
# min                                             0.010189
# 25%                                             0.376759
# 50%                                             0.489811
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_121['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   53.0  0.573255
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  256.0  0.502679
#  2                                           combined  309.0  0.514785
#
#           SD        SE  95% Conf.  Interval
#  0  0.168478  0.023142   0.526817  0.619694
#  1  0.181912  0.011369   0.480289  0.525069
#  2  0.181383  0.010319   0.494481  0.535088  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.0706
#  1                              Degrees of freedom =   79.1902
#  2                                               t =    2.7372
#  3                           Two side test p value =    0.0076
#  4                          Difference < 0 p value =    0.9962
#  5                          Difference > 0 p value =    0.0038
# ...

# %%
# Selecting 
highspread_122 = df_12_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_122 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_122)]

# %%
normalized_df_122.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.533028
# std                                             0.146594
# min                                             0.219679
# 25%                                             0.422391
# 50%                                             0.531464
# 75%                                             0.622869
# max                                             0.942813
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.458884
# std                                             0.206683
# min                                             0.010189
# 25%                                             0.346798
# 50%                                             0.473799
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_122['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   46.0  0.458884
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  247.0  0.501229
#  2                                           combined  293.0  0.494581
#
#           SD        SE  95% Conf.  Interval
#  0  0.206683  0.030474   0.397507  0.520262
#  1  0.199994  0.012725   0.476164  0.526293
#  2  0.201291  0.011760   0.471437  0.517725  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0423
#  1                              Degrees of freedom =   61.7189
#  2                                               t =   -1.2822
#  3                           Two side test p value =    0.2046
#  4                          Difference < 0 p value =    0.1023
#  5                          Difference > 0 p value =    0.8977
# ...

# %%
# Selecting 
highspread_123 = df_12_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_123 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_123)]

# %%
normalized_df_123.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.552311
# std                                             0.169069
# min                                             0.219679
# 25%                                             0.427536
# 50%                                             0.548301
# 75%                                             0.625208
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          50.000000
# mean                                            0.466696
# std                                             0.223917
# min                                             0.010189
# 25%                                             0.346798
# 50%                                             0.474648
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_123['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   49.0  0.516303
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  249.0  0.508387
#  2                                           combined  298.0  0.509688
#
#           SD        SE  95% Conf.  Interval
#  0  0.236445  0.033778   0.448388  0.584217
#  1  0.190841  0.012094   0.484566  0.532207
#  2  0.198635  0.011507   0.487043  0.532333  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.0079
#  1                              Degrees of freedom =   60.9022
#  2                                               t =    0.2206
#  3                           Two side test p value =    0.8261
#  4                          Difference < 0 p value =    0.5869
#  5                          Difference > 0 p value =    0.4131
# ...

# %%
# Selecting 
highspread_124 = df_12_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_124 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_124)]

# %%
normalized_df_124.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.534878
# std                                             0.158711
# min                                             0.219679
# 25%                                             0.419429
# 50%                                             0.528762
# 75%                                             0.619388
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          44.000000
# mean                                            0.461564
# std                                             0.213831
# min                                             0.010189
# 25%                                             0.361111
# 50%                                             0.473799
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_124['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   46.0  0.502843
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  249.0  0.513574
#  2                                           combined  295.0  0.511901
#
#           SD        SE  95% Conf.  Interval
#  0  0.215842  0.031824   0.438746  0.566940
#  1  0.193371  0.012254   0.489438  0.537710
#  2  0.196692  0.011452   0.489363  0.534439  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...  -0.0107
#  1                              Degrees of freedom =   59.0984
#  2                                               t =   -0.3147
#  3                           Two side test p value =    0.7541
#  4                          Difference < 0 p value =    0.3771
#  5                          Difference > 0 p value =    0.6229
# ...

# %%
# Selecting 
highspread_125 = df_12_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_125 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_125)]

# %%
normalized_df_125.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.544343
# std                                             0.165468
# min                                             0.219679
# 25%                                             0.422391
# 50%                                             0.531464
# 75%                                             0.625208
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.476860
# std                                             0.226656
# min                                             0.010189
# 25%                                             0.353954
# 50%                                             0.474527
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_125['ICE BofA US FNMA Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   48.0  0.524368
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  249.0  0.519197
#  2                                           combined  297.0  0.520033
#
#           SD        SE  95% Conf.  Interval
#  0  0.219824  0.031729   0.460538  0.588198
#  1  0.191798  0.012155   0.495257  0.543137
#  2  0.196208  0.011385   0.497627  0.542439  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0052
#  1                              Degrees of freedom =   61.5556
#  2                                               t =    0.1522
#  3                           Two side test p value =    0.8795
#  4                          Difference < 0 p value =    0.5602
#  5                          Difference > 0 p value =    0.4398
# ...

# %%
# Selecting 
highspread_126 = df_12_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_126 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_126)]

# %%
normalized_df_126.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.545958
# std                                             0.163755
# min                                             0.219679
# 25%                                             0.422391
# 50%                                             0.541234
# 75%                                             0.625208
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.468400
# std                                             0.223839
# min                                             0.010189
# 25%                                             0.353954
# 50%                                             0.474527
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_126['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   53.0  0.501994
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  255.0  0.500327
#  2                                           combined  308.0  0.500614
#
#           SD        SE  95% Conf.  Interval
#  0  0.228320  0.031362   0.439061  0.564927
#  1  0.189081  0.011841   0.477009  0.523646
#  2  0.195984  0.011167   0.478640  0.522588  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0017
#  1                              Degrees of freedom =   67.5998
#  2                                               t =    0.0497
#  3                           Two side test p value =    0.9605
#  4                          Difference < 0 p value =    0.5198
#  5                          Difference > 0 p value =    0.4802
# ...

# %%
# Selecting 
highspread_127 = df_12_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_127 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_127)]

# %%
normalized_df_127.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.534418
# std                                             0.144457
# min                                             0.219679
# 25%                                             0.422391
# 50%                                             0.541234
# 75%                                             0.625208
# max                                             0.942813
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.483075
# std                                             0.223701
# min                                             0.010189
# 25%                                             0.368874
# 50%                                             0.483746
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_127['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   48.0  0.523891
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  249.0  0.510110
#  2                                           combined  297.0  0.512337
#
#           SD        SE  95% Conf.  Interval
#  0  0.206614  0.029822   0.463897  0.583886
#  1  0.188407  0.011940   0.486594  0.533626
#  2  0.191168  0.011093   0.490507  0.534168  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0138
#  1                              Degrees of freedom =   62.9686
#  2                                               t =    0.4290
#  3                           Two side test p value =    0.6694
#  4                          Difference < 0 p value =    0.6653
#  5                          Difference > 0 p value =    0.3347
# ...

# %%
# Selecting 
highspread_128 = df_12_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_128 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_128)]

# %%
normalized_df_128.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.556258
# std                                             0.155667
# min                                             0.340652
# 25%                                             0.432472
# 50%                                             0.541234
# 75%                                             0.624428
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.489034
# std                                             0.202007
# min                                             0.012615
# 25%                                             0.369481
# 50%                                             0.483746
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_128['ICE BofA US GNMA Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   47.0  0.538732
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  247.0  0.498872
#  2                                           combined  294.0  0.505244
#
#           SD        SE  95% Conf.  Interval
#  0  0.189658  0.027664   0.483046  0.594417
#  1  0.184836  0.011761   0.475708  0.522037
#  2  0.185864  0.010840   0.483911  0.526578  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.0399
#  1                              Degrees of freedom =   63.7404
#  2                                               t =    1.3260
#  3                           Two side test p value =    0.1896
#  4                          Difference < 0 p value =    0.9052
#  5                          Difference > 0 p value =    0.0948
# ...

# %%
# Selecting 
highspread_129 = df_12_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_129 = df_12_Agg_Normal[(df_12_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_129)]

# %%
normalized_df_129.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.556258
# std                                             0.155667
# min                                             0.340652
# 25%                                             0.432472
# 50%                                             0.541234
# 75%                                             0.624428
# max                                             0.948218
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.489034
# std                                             0.202007
# min                                             0.012615
# 25%                                             0.369481
# 50%                                             0.483746
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_129['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_12_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   47.0  0.536975
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  247.0  0.498784
#  2                                           combined  294.0  0.504890
#
#           SD        SE  95% Conf.  Interval
#  0  0.190476  0.027784   0.481049  0.592901
#  1  0.186257  0.011851   0.475441  0.522127
#  2  0.187135  0.010914   0.483410  0.526369  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.0382
#  1                              Degrees of freedom =   63.8666
#  2                                               t =    1.2644
#  3                           Two side test p value =    0.2107
#  4                          Difference < 0 p value =    0.8947
#  5                          Difference > 0 p value =    0.1053
# ...

# %% [markdown]
# # 24 Month Below

# %%
# Selecting 
highspread_241 = df_24_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_241 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_241)]

# %%
normalized_df_241.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.662190
# std                                             0.148569
# min                                             0.348950
# 25%                                             0.558558
# 50%                                             0.625605
# 75%                                             0.770758
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.551836
# std                                             0.180179
# min                                             0.203782
# 25%                                             0.427590
# 50%                                             0.522799
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_241['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   53.0  0.662190
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  245.0  0.512302
#  2                                           combined  298.0  0.538960
#
#           SD        SE  95% Conf.  Interval
#  0  0.148569  0.020407   0.621239  0.703140
#  1  0.197252  0.012602   0.487480  0.537125
#  2  0.197802  0.011458   0.516410  0.561510  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...   0.1499
#  1                              Degrees of freedom =   96.2369
#  2                                               t =    6.2492
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_242 = df_24_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_242 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_242)]

# %%
normalized_df_242.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.642608
# std                                             0.158370
# min                                             0.340656
# 25%                                             0.547240
# 50%                                             0.622235
# 75%                                             0.747127
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.534585
# std                                             0.185948
# min                                             0.203782
# 25%                                             0.398750
# 50%                                             0.501696
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_242['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   49.0  0.534585
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  240.0  0.499610
#  2                                           combined  289.0  0.505540
#
#           SD        SE  95% Conf.  Interval
#  0  0.185948  0.026564   0.481175  0.587996
#  1  0.176888  0.011418   0.477117  0.522103
#  2  0.178610  0.010506   0.484861  0.526220  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...   0.0350
#  1                              Degrees of freedom =   66.9164
#  2                                               t =    1.2096
#  3                           Two side test p value =    0.2307
#  4                          Difference < 0 p value =    0.8847
#  5                          Difference > 0 p value =    0.1153
# ...

# %%
# Selecting 
highspread_243 = df_24_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_243 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_243)]

# %%
normalized_df_243.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          51.000000
# mean                                            0.646060
# std                                             0.164994
# min                                             0.340656
# 25%                                             0.532551
# 50%                                             0.623013
# 75%                                             0.762377
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.518960
# std                                             0.185529
# min                                             0.151978
# 25%                                             0.395978
# 50%                                             0.502772
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_243['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   52.0  0.564677
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  236.0  0.507268
#  2                                           combined  288.0  0.517633
#
#           SD        SE  95% Conf.  Interval
#  0  0.173241  0.024024   0.516446  0.612907
#  1  0.175067  0.011396   0.484817  0.529719
#  2  0.175835  0.010361   0.497240  0.538027  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.0574
#  1                              Degrees of freedom =   75.7012
#  2                                               t =    2.1590
#  3                           Two side test p value =    0.0340
#  4                          Difference < 0 p value =    0.9830
#  5                          Difference > 0 p value =    0.0170
# ...

# %%
# Selecting 
highspread_244 = df_24_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_244 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_244)]

# %%
normalized_df_244.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          45.000000
# mean                                            0.654889
# std                                             0.163837
# min                                             0.340656
# 25%                                             0.552683
# 50%                                             0.626987
# 75%                                             0.770758
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.530952
# std                                             0.183883
# min                                             0.203782
# 25%                                             0.390434
# 50%                                             0.508565
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_244['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   44.0  0.563967
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  235.0  0.497925
#  2                                           combined  279.0  0.508340
#
#           SD        SE  95% Conf.  Interval
#  0  0.161310  0.024318   0.514924  0.613009
#  1  0.177014  0.011547   0.475175  0.520674
#  2  0.176014  0.010538   0.487596  0.529084  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.0660
#  1                              Degrees of freedom =   63.9783
#  2                                               t =    2.4532
#  3                           Two side test p value =    0.0169
#  4                          Difference < 0 p value =    0.9916
#  5                          Difference > 0 p value =    0.0084
# ...

# %%
# Selecting 
highspread_245 = df_24_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_245 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_245)]

# %%
normalized_df_245.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.651475
# std                                             0.162995
# min                                             0.340656
# 25%                                             0.533027
# 50%                                             0.625000
# 75%                                             0.772875
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.533927
# std                                             0.180031
# min                                             0.203782
# 25%                                             0.398750
# 50%                                             0.515434
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_245['ICE BofA US FNMA Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   47.0  0.561361
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  232.0  0.502584
#  2                                           combined  279.0  0.512485
#
#           SD        SE  95% Conf.  Interval
#  0  0.164728  0.024028   0.512995  0.609727
#  1  0.173972  0.011422   0.480080  0.525088
#  2  0.173566  0.010391   0.492030  0.532941  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0588
#  1                              Degrees of freedom =   68.4413
#  2                                               t =    2.2093
#  3                           Two side test p value =    0.0305
#  4                          Difference < 0 p value =    0.9847
#  5                          Difference > 0 p value =    0.0153
# ...

# %%
# Selecting 
highspread_246 = df_24_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_246 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_246)]

# %%
normalized_df_246.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.644234
# std                                             0.166927
# min                                             0.340656
# 25%                                             0.530478
# 50%                                             0.625000
# 75%                                             0.758186
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.523022
# std                                             0.190853
# min                                             0.151978
# 25%                                             0.387661
# 50%                                             0.501696
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_246['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   53.0  0.580911
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  239.0  0.501258
#  2                                           combined  292.0  0.515715
#
#           SD        SE  95% Conf.  Interval
#  0  0.177274  0.024350   0.532049  0.629774
#  1  0.184408  0.011928   0.477759  0.524756
#  2  0.185403  0.010850   0.494361  0.537070  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.0797
#  1                              Degrees of freedom =   78.9574
#  2                                               t =    2.9376
#  3                           Two side test p value =    0.0043
#  4                          Difference < 0 p value =    0.9978
#  5                          Difference > 0 p value =    0.0022
# ...

# %%
# Selecting 
highspread_247 = df_24_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_247 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_247)]

# %%
normalized_df_247.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          48.000000
# mean                                            0.639458
# std                                             0.161154
# min                                             0.340656
# 25%                                             0.530478
# 50%                                             0.622235
# 75%                                             0.747127
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.535717
# std                                             0.180334
# min                                             0.203782
# 25%                                             0.398750
# 50%                                             0.519571
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_247['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   47.0  0.565890
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  235.0  0.502118
#  2                                           combined  282.0  0.512746
#
#           SD        SE  95% Conf.  Interval
#  0  0.163739  0.023884   0.517814  0.613965
#  1  0.176595  0.011520   0.479422  0.524813
#  2  0.175856  0.010472   0.492133  0.533360  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0638
#  1                              Degrees of freedom =   69.1567
#  2                                               t =    2.4050
#  3                           Two side test p value =    0.0189
#  4                          Difference < 0 p value =    0.9906
#  5                          Difference > 0 p value =    0.0094
# ...

# %%
# Selecting 
highspread_248 = df_24_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_248 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_248)]

# %%
normalized_df_248.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.654459
# std                                             0.165410
# min                                             0.340656
# 25%                                             0.538297
# 50%                                             0.634418
# 75%                                             0.777108
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.534034
# std                                             0.182614
# min                                             0.203782
# 25%                                             0.393206
# 50%                                             0.515434
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_248['ICE BofA US GNMA Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   46.0  0.622335
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  245.0  0.501767
#  2                                           combined  291.0  0.520826
#
#           SD        SE  95% Conf.  Interval
#  0  0.146659  0.021624   0.578783  0.665888
#  1  0.195360  0.012481   0.477183  0.526352
#  2  0.193366  0.011335   0.498516  0.543136  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.1206
#  1                              Degrees of freedom =   78.3740
#  2                                               t =    4.8290
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_249 = df_24_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_249 = df_24_Agg_Normal[(df_24_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_249)]

# %%
normalized_df_249.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.654459
# std                                             0.165410
# min                                             0.340656
# 25%                                             0.538297
# 50%                                             0.634418
# 75%                                             0.777108
# max                                             0.992116
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.534034
# std                                             0.182614
# min                                             0.203782
# 25%                                             0.393206
# 50%                                             0.515434
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_249['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_24_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   46.0  0.623097
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  245.0  0.504844
#  2                                           combined  291.0  0.523537
#
#           SD        SE  95% Conf.  Interval
#  0  0.148187  0.021849   0.579091  0.667103
#  1  0.196354  0.012545   0.480134  0.529553
#  2  0.194202  0.011384   0.501130  0.545943  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.1183
#  1                              Degrees of freedom =   77.9955
#  2                                               t =    4.6937
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %% [markdown]
# # 36 Month Below

# %%
# Selecting 
highspread_361 = df_36_Agg_Normal["ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_361 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index OAS'] > highspread_361)]

# %%
normalized_df_361.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.627873
# std                                             0.124216
# min                                             0.367802
# 25%                                             0.549527
# 50%                                             0.625904
# 75%                                             0.685535
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          54.000000
# mean                                            0.506771
# std                                             0.191116
# min                                             0.128723
# 25%                                             0.380189
# 50%                                             0.473463
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_361['ICE BofA 0-3 Year US Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA 0-3 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 0-3 Year US Mortgage Backed Securitie...   54.0  0.627873
#  1  ICE BofA 0-3 Year US Mortgage Backed Securitie...  234.0  0.507241
#  2                                           combined  288.0  0.529860
#
#           SD        SE  95% Conf.  Interval
#  0  0.124216  0.016904   0.593969  0.661778
#  1  0.165944  0.010848   0.485868  0.528614
#  2  0.165620  0.009759   0.510651  0.549068  ,
#                                        Welch's t-test   results
#  0  Difference (ICE BofA 0-3 Year US Mortgage Back...    0.1206
#  1                              Degrees of freedom =   101.7216
#  2                                               t =     6.0060
#  3                           Two side test p value =     0.0000
#  4                          Difference < 0 p value =     1.0000
#  5                          Difference > 0 p value =     0.0000
# ...

# %%
# Selecting 
highspread_362 = df_36_Agg_Normal["ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_362 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index OAS'] > highspread_362)]

# %%
normalized_df_362.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.620312
# std                                             0.131585
# min                                             0.367802
# 25%                                             0.543082
# 50%                                             0.607171
# 75%                                             0.687161
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.495634
# std                                             0.195684
# min                                             0.128723
# 25%                                             0.377139
# 50%                                             0.454610
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_362['ICE BofA 3-5 Year US Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA 3-5 Year US Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA 3-5 Year US Mortgage Backed Securitie...   49.0  0.495634
#  1  ICE BofA 3-5 Year US Mortgage Backed Securitie...  230.0  0.496287
#  2                                           combined  279.0  0.496172
#
#           SD        SE  95% Conf.  Interval
#  0  0.195684  0.027955   0.439427  0.551840
#  1  0.190109  0.012535   0.471587  0.520986
#  2  0.190742  0.011419   0.473692  0.518651  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA 3-5 Year US Mortgage Back...  -0.0007
#  1                              Degrees of freedom =   68.6622
#  2                                               t =   -0.0213
#  3                           Two side test p value =    0.9831
#  4                          Difference < 0 p value =    0.4915
#  5                          Difference > 0 p value =    0.5085
# ...

# %%
# Selecting 
highspread_363 = df_36_Agg_Normal["ICE BofA US 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_363 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index OAS'] > highspread_363)]

# %%
normalized_df_363.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.625322
# std                                             0.128212
# min                                             0.367802
# 25%                                             0.543624
# 50%                                             0.625904
# 75%                                             0.702641
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          52.000000
# mean                                            0.493492
# std                                             0.186003
# min                                             0.128723
# 25%                                             0.382169
# 50%                                             0.458809
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_363['ICE BofA US 15-Year Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 15-Year Mortgage Backed Securities...   52.0  0.578361
#  1  ICE BofA US 15-Year Mortgage Backed Securities...  232.0  0.491691
#  2                                           combined  284.0  0.507561
#
#           SD        SE  95% Conf.  Interval
#  0  0.150823  0.020915   0.536372  0.620350
#  1  0.187140  0.012286   0.467484  0.515899
#  2  0.183883  0.010911   0.486083  0.529038  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 15-Year Mortgage Backe...   0.0867
#  1                              Degrees of freedom =   89.9069
#  2                                               t =    3.5730
#  3                           Two side test p value =    0.0006
#  4                          Difference < 0 p value =    0.9997
#  5                          Difference > 0 p value =    0.0003
# ...

# %%
# Selecting 
highspread_364 = df_36_Agg_Normal["ICE BofA US 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_364 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index OAS'] > highspread_364)]

# %%
normalized_df_364.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.628075
# std                                             0.133895
# min                                             0.367802
# 25%                                             0.543263
# 50%                                             0.625904
# 75%                                             0.706075
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          46.000000
# mean                                            0.491028
# std                                             0.194742
# min                                             0.128723
# 25%                                             0.377654
# 50%                                             0.458809
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_364['ICE BofA US 30-Year Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US 30-Year Mortgage Backed Securities...   43.0  0.547256
#  1  ICE BofA US 30-Year Mortgage Backed Securities...  222.0  0.513177
#  2                                           combined  265.0  0.518707
#
#           SD        SE  95% Conf.  Interval
#  0  0.173298  0.026428   0.493922  0.600589
#  1  0.205655  0.013803   0.485976  0.540379
#  2  0.200852  0.012338   0.494413  0.543001  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US 30-Year Mortgage Backe...   0.0341
#  1                              Degrees of freedom =   67.0895
#  2                                               t =    1.1430
#  3                           Two side test p value =    0.2571
#  4                          Difference < 0 p value =    0.8714
#  5                          Difference > 0 p value =    0.1286
# ...

# %%
# Selecting 
highspread_365 = df_36_Agg_Normal["ICE BofA US FNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_365 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index OAS'] > highspread_365)]

# %%
normalized_df_365.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.625878
# std                                             0.130201
# min                                             0.367802
# 25%                                             0.543805
# 50%                                             0.622109
# 75%                                             0.703545
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.497276
# std                                             0.196743
# min                                             0.128723
# 25%                                             0.379198
# 50%                                             0.463007
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_365['ICE BofA US FNMA Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US FNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA Mortgage Backed Securities Index   47.0  0.560860
#  1  ICE BofA US FNMA Mortgage Backed Securities Index  224.0  0.517487
#  2                                           combined  271.0  0.525009
#
#           SD        SE  95% Conf.  Interval
#  0  0.182845  0.026671   0.507175  0.614545
#  1  0.197889  0.013222   0.491431  0.543543
#  2  0.195729  0.011890   0.501601  0.548418  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA Mortgage Backed S...   0.0434
#  1                              Degrees of freedom =   70.5107
#  2                                               t =    1.4570
#  3                           Two side test p value =    0.1496
#  4                          Difference < 0 p value =    0.9252
#  5                          Difference > 0 p value =    0.0748
# ...

# %%
# Selecting 
highspread_366 = df_36_Agg_Normal["ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_366 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index OAS'] > highspread_366)]

# %%
normalized_df_366.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.622070
# std                                             0.126923
# min                                             0.367802
# 25%                                             0.543805
# 50%                                             0.613315
# 75%                                             0.687161
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          53.000000
# mean                                            0.494956
# std                                             0.187009
# min                                             0.128723
# 25%                                             0.383159
# 50%                                             0.463007
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_366['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US FNMA 15-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 15-Year Mortgage Backed Secur...   53.0  0.587807
#  1  ICE BofA US FNMA 15-Year Mortgage Backed Secur...  234.0  0.487491
#  2                                           combined  287.0  0.506016
#
#           SD        SE  95% Conf.  Interval
#  0  0.140964  0.019363   0.548953  0.626662
#  1  0.181109  0.011839   0.464165  0.510817
#  2  0.178481  0.010535   0.485279  0.526753  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 15-Year Mortgage ...   0.1003
#  1                              Degrees of freedom =   95.1823
#  2                                               t =    4.4201
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_367 = df_36_Agg_Normal["ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_367 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_367)]

# %%
normalized_df_367.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.621393
# std                                             0.130305
# min                                             0.367802
# 25%                                             0.543805
# 50%                                             0.603075
# 75%                                             0.687161
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          49.000000
# mean                                            0.518117
# std                                             0.210910
# min                                             0.128723
# 25%                                             0.379198
# 50%                                             0.466968
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_367['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US FNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US FNMA 30-Year Mortgage Backed Secur...   48.0  0.580869
#  1  ICE BofA US FNMA 30-Year Mortgage Backed Secur...  228.0  0.519125
#  2                                           combined  276.0  0.529863
#
#           SD        SE  95% Conf.  Interval
#  0  0.197184  0.028461   0.523613  0.638125
#  1  0.204854  0.013567   0.492392  0.545858
#  2  0.204537  0.012312   0.505626  0.554100  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US FNMA 30-Year Mortgage ...   0.0617
#  1                              Degrees of freedom =   70.0367
#  2                                               t =    1.9583
#  3                           Two side test p value =    0.0542
#  4                          Difference < 0 p value =    0.9729
#  5                          Difference > 0 p value =    0.0271
# ...

# %%
# Selecting 
highspread_368 = df_36_Agg_Normal["ICE BofA US GNMA Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_368 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index OAS'] > highspread_368)]

# %%
normalized_df_368.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.627481
# std                                             0.132418
# min                                             0.367802
# 25%                                             0.543444
# 50%                                             0.622109
# 75%                                             0.705231
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.492195
# std                                             0.191682
# min                                             0.128723
# 25%                                             0.378169
# 50%                                             0.463007
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_368['ICE BofA US GNMA Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US GNMA Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA Mortgage Backed Securities Index   47.0  0.604126
#  1  ICE BofA US GNMA Mortgage Backed Securities Index  234.0  0.496717
#  2                                           combined  281.0  0.514683
#
#           SD        SE  95% Conf.  Interval
#  0  0.120227  0.017537   0.568826  0.639427
#  1  0.169881  0.011105   0.474837  0.518597
#  2  0.167340  0.009983   0.495032  0.534333  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA Mortgage Backed S...   0.1074
#  1                              Degrees of freedom =   87.5128
#  2                                               t =    5.1745
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...

# %%
# Selecting 
highspread_369 = df_36_Agg_Normal["ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS"].quantile(.80) # every data point over the 75th percentile

# pandas version of the SQL function 
normalized_df_369 = df_36_Agg_Normal[(df_36_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index OAS'] > highspread_369)]

# %%
normalized_df_369.describe()
# Out:
#        ICE BofA 0-3 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.627481
# std                                             0.132418
# min                                             0.367802
# 25%                                             0.543444
# 50%                                             0.622109
# 75%                                             0.705231
# max                                             0.930987
#
#        ICE BofA 3-5 Year US Mortgage Backed Securities Index  \
# count                                          47.000000
# mean                                            0.492195
# std                                             0.191682
# min                                             0.128723
# 25%                                             0.378169
# 50%                                             0.463007
# ...

# %%
# start with Agg
# top 80 with rest of pop.
des, res = researchpy.ttest(normalized_df_369['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'], df_36_Agg_Normal['ICE BofA US GNMA 30-Year Mortgage Backed Securities Index'],equal_variances= False)

des, res
# Out:
# (                                            Variable      N      Mean  \
#  0  ICE BofA US GNMA 30-Year Mortgage Backed Secur...   47.0  0.600672
#  1  ICE BofA US GNMA 30-Year Mortgage Backed Secur...  234.0  0.496891
#  2                                           combined  281.0  0.514249
#
#           SD        SE  95% Conf.  Interval
#  0  0.119793  0.017474   0.565499  0.635845
#  1  0.168322  0.011004   0.475212  0.518570
#  2  0.165649  0.009882   0.494797  0.533701  ,
#                                        Welch's t-test  results
#  0  Difference (ICE BofA US GNMA 30-Year Mortgage ...   0.1038
#  1                              Degrees of freedom =   87.0148
#  2                                               t =    5.0258
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
# ...
