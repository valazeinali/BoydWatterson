# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_excel('IG Excess Returns (Duration).xlsx')

# %%
df.head()
# Out:
#   Bond/Index                  Description       Date    OAS  \
# 0       C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1       C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2       C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3       C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4       C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
#
#    Total Return % 1-mo-LOC  Excess Return % 1-mo  Effective Duration  \
# 0                    1.290                -1.878                7.92
# 1                    2.376                -0.637                7.83
# 2                    0.315                 1.061                7.65
# 3                    0.217                 0.622                7.67
# 4                    0.612                 0.579                7.64
#
#    Yield/Duration  Agg Returns  Excess Return % 1-mo (Agg)
# 0       16.414141       1.8000                     -0.5100
# 1       13.920817       1.9245                      0.4515
# ...

# %%
# To do: from jan 2015 OAS paired with 3 month excess return (treasury)
df['Excess Return % 3-mo (Treasury)'] = df['Excess Return % 1-mo'].rolling(3,win_type='boxcar',center=True).sum().shift(-1)

# %%
df.head()
# Out:
#   Bond/Index                  Description       Date    OAS  \
# 0       C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1       C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2       C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3       C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4       C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
#
#    Total Return % 1-mo-LOC  Excess Return % 1-mo  Effective Duration  \
# 0                    1.290                -1.878                7.92
# 1                    2.376                -0.637                7.83
# 2                    0.315                 1.061                7.65
# 3                    0.217                 0.622                7.67
# 4                    0.612                 0.579                7.64
#
#    Yield/Duration  Agg Returns  Excess Return % 1-mo (Agg)  \
# 0       16.414141       1.8000                     -0.5100
# 1       13.920817       1.9245                      0.4515
# ...

# %%
df.head(279)
# Out:
#     Bond/Index                  Description       Date    OAS  \
# 0         C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1         C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2         C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3         C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4         C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
# ..         ...                          ...        ...    ...
# 274       C0A0  ICE BofA US Corporate Index 1997-04-30   59.0
# 275       C0A0  ICE BofA US Corporate Index 1997-03-31   57.0
# 276       C0A0  ICE BofA US Corporate Index 1997-02-28   59.0
# 277       C0A0  ICE BofA US Corporate Index 1997-01-31   61.0
# 278       C0A0  ICE BofA US Corporate Index 1996-12-31   60.0
#
#      Total Return % 1-mo-LOC  Excess Return % 1-mo  Effective Duration  \
# 0                      1.290                -1.878                7.92
# 1                      2.376                -0.637                7.83
# ...

# %%
# To do: from jan 2015 OAS paired with 3 month excess return (Agg)
df['Excess Return % 3-mo (Agg)'] = df['Excess Return % 1-mo (Agg)'].rolling(3,win_type='boxcar',center=True).sum().shift(-1)

# %%
df.head()
# Out:
#   Bond/Index                  Description       Date    OAS  \
# 0       C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1       C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2       C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3       C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4       C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
#
#    Total Return % 1-mo-LOC  Excess Return % 1-mo  Effective Duration  \
# 0                    1.290                -1.878                7.92
# 1                    2.376                -0.637                7.83
# 2                    0.315                 1.061                7.65
# 3                    0.217                 0.622                7.67
# 4                    0.612                 0.579                7.64
#
#    Yield/Duration  Agg Returns  Excess Return % 1-mo (Agg)  \
# 0       16.414141       1.8000                     -0.5100
# 1       13.920817       1.9245                      0.4515
# ...

# %%
df.drop("Excess Return % 3-mo(Treasury)", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c404dc80fc43> in <module>
# ----> 1 df.drop("Excess Return % 3-mo(Treasury)", axis=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %% [markdown]
# ### match current OAS month value to the excess return in 6 months from that date. OAS level for Jan 2015 matched with june 2015 excess return (treasury)

# %%
# To do: from jan 2015 OAS paired with 6 month excess return (treasury)
df['Excess Return % 6-mo (Treasury)'] = df['Excess Return % 1-mo'].rolling(6,win_type='boxcar',center=True).sum().shift(-3)

# %%
df.head()
# Out:
#   Bond/Index                  Description       Date    OAS  \
# 0       C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1       C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2       C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3       C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4       C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
#
#    Total Return % 1-mo-LOC  Excess Return % 1-mo  Effective Duration  \
# 0                    1.290                -1.878                7.92
# 1                    2.376                -0.637                7.83
# 2                    0.315                 1.061                7.65
# 3                    0.217                 0.622                7.67
# 4                    0.612                 0.579                7.64
#
#    Yield/Duration  Agg Returns  Excess Return % 1-mo (Agg)  \
# 0       16.414141       1.8000                     -0.5100
# 1       13.920817       1.9245                      0.4515
# ...

# %% [markdown]
# ### match current OAS month value to the excess return in 6 months from that date. OAS level for Jan 2015 matched with june 2015 excess return (AGG)

# %%
# To do: from jan 2015 OAS paired with 6 month excess return (Agg)
df['Excess Return % 6-mo (Agg)'] = df['Excess Return % 1-mo (Agg)'].rolling(6,win_type='boxcar',center=True).sum().shift(-3)

# %% [markdown]
# ### match current OAS month value to the excess return in 9 months from that date. OAS level for Jan 2015 matched with Sep 2015 excess return (treasury)

# %%
# To do: from jan 2015 OAS paired with 9 month excess return (treasury)
df['Excess Return % 9-mo (Treasury)'] = df['Excess Return % 1-mo'].rolling(9,win_type='boxcar',center=True).sum().shift(-5)

# %% [markdown]
# ### match current OAS month value to the excess return in 6 months from that date. OAS level for Jan 2015 matched with Sep 2015 excess return (AGG)

# %%
# To do: from jan 2015 OAS paired with 9 month excess return (Agg)
df['Excess Return % 9-mo (Agg)'] = df['Excess Return % 1-mo (Agg)'].rolling(9,win_type='boxcar',center=True).sum().shift(-5)

# %% [markdown]
# ### match current OAS month value to the excess return in 12 months from that date. OAS level for Jan 2015 matched with jan 2016 excess return (treasury)

# %%
# To do: from jan 2015 OAS paired with 12 month excess return (treasury)
df['Excess Return % 12-mo (Treasury)'] = df['Excess Return % 1-mo'].rolling(12,win_type='boxcar',center=True).sum().shift(-7)

# %% [markdown]
# ### match current OAS month value to the excess return in 12 months from that date. OAS level for Jan 2015 matched with jan 2016 excess return (AGG)

# %%
# To do: from jan 2015 OAS paired with 9 month excess return (Agg)
df['Excess Return % 12-mo (Agg)'] = df['Excess Return % 1-mo (Agg)'].rolling(12,win_type='boxcar',center=True).sum().shift(-7)

# %% [markdown]
# ### match current OAS month value to the excess return in 24 months from that date. OAS level for Jan 2015 matched with jan 2017 excess return (treasury)

# %%
# To do: from jan 2015 OAS paired with 24 month excess return (treasury)
df['Excess Return % 24-mo (Treasury)'] = df['Excess Return % 1-mo'].rolling(24,win_type='boxcar',center=True).sum().shift(-9)

# %% [markdown]
# ### match current OAS month value to the excess return in 24 months from that date. OAS level for Jan 2015 matched with jan 2017 excess return (AGG)

# %%
# To do: from jan 2015 OAS paired with 24 month excess return (Agg)
df['Excess Return % 24-mo (Agg)'] = df['Excess Return % 1-mo (Agg)'].rolling(24,win_type='boxcar',center=True).sum().shift(-9)

# %%
df.head(20)
# Out:
#    Bond/Index                  Description       Date    OAS  \
# 0        C0A0  ICE BofA US Corporate Index 2020-02-29  130.0
# 1        C0A0  ICE BofA US Corporate Index 2020-01-31  109.0
# 2        C0A0  ICE BofA US Corporate Index 2019-12-31  101.0
# 3        C0A0  ICE BofA US Corporate Index 2019-11-30  111.0
# 4        C0A0  ICE BofA US Corporate Index 2019-10-31  117.0
# 5        C0A0  ICE BofA US Corporate Index 2019-09-30  122.0
# 6        C0A0  ICE BofA US Corporate Index 2019-08-31  126.0
# 7        C0A0  ICE BofA US Corporate Index 2019-07-31  114.0
# 8        C0A0  ICE BofA US Corporate Index 2019-06-30  122.0
# 9        C0A0  ICE BofA US Corporate Index 2019-05-31  135.0
# 10       C0A0  ICE BofA US Corporate Index 2019-04-30  117.0
# 11       C0A0  ICE BofA US Corporate Index 2019-03-31  127.0
# 12       C0A0  ICE BofA US Corporate Index 2019-02-28  129.0
# 13       C0A0  ICE BofA US Corporate Index 2019-01-31  138.0
# ...
