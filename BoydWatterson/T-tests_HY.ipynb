# %%
import numpy as np
import pandas as pd

# %%
! pip install --user researchpy
# Out:
# Requirement already satisfied: researchpy in /Users/valazeinali/.local/lib/python3.7/site-packages (0.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.4.1)
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (0.11.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.18.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (from researchpy) (1.0.1)
# Requirement already satisfied: patsy>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from statsmodels->researchpy) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->researchpy) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->researchpy) (2.8.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from patsy>=0.5->statsmodels->researchpy) (1.14.0)

# %%
import researchpy # for t-test stuff!

# %%
df = pd.read_csv('minmax_OAS_with_Returns_Final_NO_Outliers_HY.csv')

# %%
df.head()
# Out:
#                   Date       OAS Total Return % 1-mo-LOC Agg Returns  \
# 0  1997-01-31 00:00:00  0.069440                 #VALUE!     #VALUE!
# 1  1997-02-28 00:00:00  0.032326                 #VALUE!     #VALUE!
# 2  1997-03-31 00:00:00  0.045495                 #VALUE!     #VALUE!
# 3  1997-04-30 00:00:00  0.057468                 #VALUE!     #VALUE!
# 4  1997-05-31 00:00:00  0.026339                 #VALUE!     #VALUE!
#
#    Excess Return % 1-mo (Treasury)  Excess Return % 1-mo (Agg)  \
# 0                         0.538337                    0.523856
# 1                         0.645266                    0.628310
# 2                         0.419861                    0.435726
# 3                         0.454503                    0.442154
# 4                         0.624827                    0.612519
#
#    Excess Return % 3-mo (Treasury)  Excess Return % 3-mo (Agg)  \
# 0                         0.552975                    0.540099
# 1                         0.510908                    0.501898
# 2                         0.500652                    0.494515
# 3                         0.556336                    0.530701
# 4                         0.566418                    0.540580
#
#    Excess Return % 6-mo (Treasury)  Excess Return % 6-mo (Agg)  \
# 0                         0.581964                    0.567813
# 1                         0.563598                    0.549749
# 2                         0.538145                    0.529193
# 3                         0.565062                    0.551020
# 4                         0.536349                    0.524214
#
#    Excess Return % 9-mo (Treasury)  Excess Return % 9-mo (Agg)  \
# 0                         0.599813                    0.574392
# 1                         0.559457                    0.537504
# 2                         0.536575                    0.515894
# 3                         0.547063                    0.521778
# 4                         0.552625                    0.535758
#
#    Excess Return % 12-mo (Treasury)  Excess Return % 12-mo (Agg)  \
# 0                          0.555659                     0.534345
# 1                          0.545353                     0.531499
# 2                          0.527484                     0.514412
# 3                          0.550781                     0.532880
# 4                          0.554074                     0.535458
#
#    Excess Return % 24-mo (Treasury)  Excess Return % 24-mo (Agg)  \
# 0                          0.439221                     0.405844
# 1                          0.443249                     0.408951
# 2                          0.446856                     0.405322
# 3                          0.462201                     0.419587
# 4                          0.487060                     0.447773
#
#    Excess Return % 36-mo (Treasury)  Excess Return % 36-mo (Agg) Quadrant
# 0                          0.475692                     0.420076     four
# 1                          0.467950                     0.413271     four
# 2                          0.441483                     0.382216     four
# 3                          0.406354                     0.347965     four
# 4                          0.412596                     0.354794     four

# %%
df = df.drop(columns=["Total Return % 1-mo-LOC", "Agg Returns" ,
"Excess Return % 1-mo (Treasury)", "Excess Return % 1-mo (Agg)"], axis = 0) # get rid of these useless columns

# %%
df.describe()
# Out:
#               OAS  Excess Return % 3-mo (Treasury)  \
# count  279.000000                       278.000000
# mean     0.351159                         0.490379
# std      0.247503                         0.235178
# min      0.000000                         0.000000
# 25%      0.155043                         0.375000
# 50%      0.289734                         0.512762
# 75%      0.489075                         0.625000
# max      1.000000                         1.000000
#
#        Excess Return % 3-mo (Agg)  Excess Return % 6-mo (Treasury)  \
# count                  278.000000                       275.000000
# mean                     0.489711                         0.495175
# std                      0.219736                         0.223090
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.514750                         0.512260
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 6-mo (Agg)  Excess Return % 9-mo (Treasury)  \
# count                  275.000000                       272.000000
# mean                     0.499683                         0.507613
# std                      0.225057                         0.219753
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.523454                         0.533540
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 9-mo (Agg)  Excess Return % 12-mo (Treasury)  \
# count                  272.000000                        269.000000
# mean                     0.505828                          0.497147
# std                      0.213179                          0.207683
# min                      0.000000                          0.000000
# 25%                      0.375000                          0.375000
# 50%                      0.522281                          0.512685
# 75%                      0.625000                          0.625000
# max                      1.000000                          1.000000
#
#        Excess Return % 12-mo (Agg)  Excess Return % 24-mo (Treasury)  \
# count                   269.000000                        257.000000
# mean                      0.499497                          0.507319
# std                       0.201386                          0.215835
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.503557                          0.541286
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 24-mo (Agg)  Excess Return % 36-mo (Treasury)  \
# count                   257.000000                        245.000000
# mean                      0.498248                          0.493073
# std                       0.219765                          0.208462
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.537844                          0.517038
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 36-mo (Agg)
# count                   245.000000
# mean                      0.484863
# std                       0.217124
# min                       0.000000
# 25%                       0.375000
# 50%                       0.523230
# 75%                       0.625000
# max                       1.000000

# %% [markdown]
# # drop outliers that we have identified as 0 and 1s (1 is > upper fence)

# %%
# Getting rid of outliers below. When we ran the script to label outliers, the script
# would label a number an outlier a 1 if it was above the Upper fence and would label
# it a 0 if it was an outlier below the lower fence.
# This script replaces all outliers as "NaN"

df["OAS"] = df["OAS"].replace([0],["NaN"])
df["OAS"] = df["OAS"].replace([1],["Nan"])

df = df.dropna()

df['OAS'] = pd.to_numeric(df['OAS'],errors='coerce') # converting back to float64 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              245 non-null    object
#  1   OAS                               235 non-null    float64
#  2   Excess Return % 3-mo (Treasury)   245 non-null    float64
#  3   Excess Return % 3-mo (Agg)        245 non-null    float64
#  4   Excess Return % 6-mo (Treasury)   245 non-null    float64
#  5   Excess Return % 6-mo (Agg)        245 non-null    float64
#  6   Excess Return % 9-mo (Treasury)   245 non-null    float64
#  7   Excess Return % 9-mo (Agg)        245 non-null    float64
#  8   Excess Return % 12-mo (Treasury)  245 non-null    float64
#  9   Excess Return % 12-mo (Agg)       245 non-null    float64
#  10  Excess Return % 24-mo (Treasury)  245 non-null    float64
#  11  Excess Return % 24-mo (Agg)       245 non-null    float64
#  12  Excess Return % 36-mo (Treasury)  245 non-null    float64
#  13  Excess Return % 36-mo (Agg)       245 non-null    float64
#  14  Quadrant                          245 non-null    object
# dtypes: float64(13), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# # Now lets select all OAS levels and their coresponding excess returns that are above the 75th percentile (top 25%)

# %%
# Select * 
# From OAS
# Where OAS >= 75th percentile
## SQL version above ## 
highspread = df["OAS"].quantile(.85) # every data point over the 85th percentile
print(highspread)

# pandas version of the SQL function 
df = df[(df['OAS'] > highspread)]
# Out:
# 0.6271176297000001

# %%
df.describe()
# Out:
#              OAS  Excess Return % 3-mo (Treasury)  Excess Return % 3-mo (Agg)  \
# count  36.000000                        36.000000                   36.000000
# mean    0.736606                         0.510875                    0.502483
# std     0.100483                         0.343910                    0.327027
# min     0.627357                         0.000000                    0.000000
# 25%     0.666268                         0.266731                    0.293080
# 50%     0.696797                         0.552917                    0.548059
# 75%     0.787489                         0.807915                    0.790198
# max     0.973361                         1.000000                    1.000000
#
#        Excess Return % 6-mo (Treasury)  Excess Return % 6-mo (Agg)  \
# count                        36.000000                   36.000000
# mean                          0.521582                    0.526253
# std                           0.318240                    0.325133
# min                           0.000000                    0.000000
# 25%                           0.278671                    0.263691
# 50%                           0.534835                    0.530227
# 75%                           0.817832                    0.817877
# max                           1.000000                    1.000000
#
#        Excess Return % 9-mo (Treasury)  Excess Return % 9-mo (Agg)  \
# count                        36.000000                   36.000000
# mean                          0.500669                    0.502038
# std                           0.344400                    0.335793
# min                           0.000000                    0.000000
# 25%                           0.231095                    0.236869
# 50%                           0.435800                    0.436138
# 75%                           0.846746                    0.842211
# max                           1.000000                    1.000000
#
#        Excess Return % 12-mo (Treasury)  Excess Return % 12-mo (Agg)  \
# count                         36.000000                    36.000000
# mean                           0.502134                     0.508854
# std                            0.309195                     0.300023
# min                            0.000000                     0.000000
# 25%                            0.213475                     0.238230
# 50%                            0.407526                     0.428171
# 75%                            0.827162                     0.838205
# max                            0.981908                     0.977471
#
#        Excess Return % 24-mo (Treasury)  Excess Return % 24-mo (Agg)  \
# count                         36.000000                    36.000000
# mean                           0.594967                     0.595538
# std                            0.271799                     0.269026
# min                            0.000000                     0.000000
# 25%                            0.425262                     0.445815
# 50%                            0.639225                     0.634857
# 75%                            0.823257                     0.824762
# max                            0.954957                     0.932568
#
#        Excess Return % 36-mo (Treasury)  Excess Return % 36-mo (Agg)
# count                         36.000000                    36.000000
# mean                           0.629589                     0.633944
# std                            0.142252                     0.141966
# min                            0.305142                     0.297485
# 25%                            0.506290                     0.518933
# 50%                            0.661163                     0.664751
# 75%                            0.746492                     0.754433
# max                            0.841299                     0.851915

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 3-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 3-mo (Treasury)  36.0  0.510875  0.343910  0.057318
#  2                         combined  72.0  0.623740  0.276042  0.032532
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.394513  0.627237
#  2   0.558874  0.688607  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 3-mo (Treasu...   0.2257
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    3.7801
#  3                           Two side test p value =    0.0003
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
#  6                                       Cohen's d =    0.8910
#  7                                       Hedge's g =    0.8814
#  8                                   Glass's delta =    2.2465
#  9                                               r =    0.4117)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 3-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 3-mo (Agg)  36.0  0.502483  0.327027  0.054504   0.391833
#  2                    combined  72.0  0.619544  0.267570  0.031533   0.556668
#
#     Interval
#  0  0.770604
#  1  0.613133
#  2  0.682420  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 3-mo (Agg)) =    0.2341
#  1                             Degrees of freedom =   70.0000
#  2                                              t =    4.1060
#  3                          Two side test p value =    0.0001
#  4                         Difference < 0 p value =    0.9999
#  5                         Difference > 0 p value =    0.0001
#  6                                      Cohen's d =    0.9678
#  7                                      Hedge's g =    0.9574
#  8                                  Glass's delta =    2.3300
#  9                                              r =    0.4406)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 6-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 6-mo (Treasury)  36.0  0.521582  0.318240  0.053040
#  2                         combined  72.0  0.629094  0.258116  0.030419
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.413905  0.629259
#  2   0.568439  0.689748  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 6-mo (Treasu...   0.2150
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    3.8659
#  3                           Two side test p value =    0.0002
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
#  6                                       Cohen's d =    0.9112
#  7                                       Hedge's g =    0.9014
#  8                                   Glass's delta =    2.1399
#  9                                               r =    0.4194)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 6-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 6-mo (Agg)  36.0  0.526253  0.325133  0.054189   0.416244
#  2                    combined  72.0  0.631429  0.261355  0.030801   0.570014
#
#     Interval
#  0  0.770604
#  1  0.636262
#  2  0.692845  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 6-mo (Agg)) =    0.2104
#  1                             Degrees of freedom =   70.0000
#  2                                              t =    3.7088
#  3                          Two side test p value =    0.0004
#  4                         Difference < 0 p value =    0.9998
#  5                         Difference > 0 p value =    0.0002
#  6                                      Cohen's d =    0.8742
#  7                                      Hedge's g =    0.8648
#  8                                  Glass's delta =    2.0934
#  9                                              r =    0.4053)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 9-mo (Treasury)'])

des, res
# Out:
# (                          Variable     N      Mean        SD        SE  \
#  0                              OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 9-mo (Treasury)  36.0  0.500669  0.344400  0.057400
#  2                         combined  72.0  0.618637  0.278496  0.032821
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.384141  0.617197
#  2   0.553194  0.684081  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 9-mo (Treasu...   0.2359
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    3.9459
#  3                           Two side test p value =    0.0002
#  4                          Difference < 0 p value =    0.9999
#  5                          Difference > 0 p value =    0.0001
#  6                                       Cohen's d =    0.9301
#  7                                       Hedge's g =    0.9201
#  8                                   Glass's delta =    2.3480
#  9                                               r =    0.4266)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 9-mo (Agg)'])

des, res
# Out:
# (                     Variable     N      Mean        SD        SE  95% Conf.  \
#  0                         OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 9-mo (Agg)  36.0  0.502038  0.335793  0.055965   0.388422
#  2                    combined  72.0  0.619322  0.272967  0.032169   0.555178
#
#     Interval
#  0  0.770604
#  1  0.615654
#  2  0.683466  ,
#                                   Independent t-test  results
#  0  Difference (OAS - Excess Return % 9-mo (Agg)) =    0.2346
#  1                             Degrees of freedom =   70.0000
#  2                                              t =    4.0154
#  3                          Two side test p value =    0.0001
#  4                         Difference < 0 p value =    0.9999
#  5                         Difference > 0 p value =    0.0001
#  6                                      Cohen's d =    0.9464
#  7                                      Hedge's g =    0.9363
#  8                                  Glass's delta =    2.3344
#  9                                              r =    0.4327)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 12-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 12-mo (Treasury)  36.0  0.502134  0.309195  0.051533
#  2                          combined  72.0  0.619370  0.256988  0.030286
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.397517  0.606751
#  2   0.558981  0.679759  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 12-mo (Treas...   0.2345
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    4.3272
#  3                           Two side test p value =    0.0000
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.0199
#  7                                       Hedge's g =    1.0090
#  8                                   Glass's delta =    2.3334
#  9                                               r =    0.4594)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 12-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 12-mo (Agg)  36.0  0.508854  0.300023  0.050004   0.407340
#  2                     combined  72.0  0.622730  0.250002  0.029463   0.563982
#
#     Interval
#  0  0.770604
#  1  0.610367
#  2  0.681477  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 12-mo (Agg)) =    0.2278
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    4.3189
#  3                           Two side test p value =    0.0001
#  4                          Difference < 0 p value =    1.0000
#  5                          Difference > 0 p value =    0.0000
#  6                                       Cohen's d =    1.0180
#  7                                       Hedge's g =    1.0070
#  8                                   Glass's delta =    2.2666
#  9                                               r =    0.4587)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 24-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 24-mo (Treasury)  36.0  0.594967  0.271799  0.045300
#  2                          combined  72.0  0.665787  0.215593  0.025408
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.503004  0.686931
#  2   0.615125  0.716449  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 24-mo (Treas...   0.1416
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    2.9327
#  3                           Two side test p value =    0.0045
#  4                          Difference < 0 p value =    0.9977
#  5                          Difference > 0 p value =    0.0023
#  6                                       Cohen's d =    0.6912
#  7                                       Hedge's g =    0.6838
#  8                                   Glass's delta =    1.4096
#  9                                               r =    0.3308)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 24-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 24-mo (Agg)  36.0  0.595538  0.269026  0.044838   0.504512
#  2                     combined  72.0  0.666072  0.213776  0.025194   0.615837
#
#     Interval
#  0  0.770604
#  1  0.686563
#  2  0.716307  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 24-mo (Agg)) =    0.1411
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    2.9473
#  3                           Two side test p value =    0.0044
#  4                          Difference < 0 p value =    0.9978
#  5                          Difference > 0 p value =    0.0022
#  6                                       Cohen's d =    0.6947
#  7                                       Hedge's g =    0.6872
#  8                                   Glass's delta =    1.4039
#  9                                               r =    0.3323)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 36-mo (Treasury)'])

des, res
# Out:
# (                           Variable     N      Mean        SD        SE  \
#  0                               OAS  36.0  0.736606  0.100483  0.016747
#  1  Excess Return % 36-mo (Treasury)  36.0  0.629589  0.142252  0.023709
#  2                          combined  72.0  0.683098  0.133627  0.015748
#
#     95% Conf.  Interval
#  0   0.702607  0.770604
#  1   0.581458  0.677720
#  2   0.651697  0.714498  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 36-mo (Treas...   0.1070
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    3.6868
#  3                           Two side test p value =    0.0004
#  4                          Difference < 0 p value =    0.9998
#  5                          Difference > 0 p value =    0.0002
#  6                                       Cohen's d =    0.8690
#  7                                       Hedge's g =    0.8596
#  8                                   Glass's delta =    1.0650
#  9                                               r =    0.4032)

# %%
des, res = researchpy.ttest(df['OAS'], df['Excess Return % 36-mo (Agg)'])

des, res
# Out:
# (                      Variable     N      Mean        SD        SE  95% Conf.  \
#  0                          OAS  36.0  0.736606  0.100483  0.016747   0.702607
#  1  Excess Return % 36-mo (Agg)  36.0  0.633944  0.141966  0.023661   0.585909
#  2                     combined  72.0  0.685275  0.132607  0.015628   0.654114
#
#     Interval
#  0  0.770604
#  1  0.681978
#  2  0.716436  ,
#                                    Independent t-test  results
#  0  Difference (OAS - Excess Return % 36-mo (Agg)) =    0.1027
#  1                              Degrees of freedom =   70.0000
#  2                                               t =    3.5415
#  3                           Two side test p value =    0.0007
#  4                          Difference < 0 p value =    0.9996
#  5                          Difference > 0 p value =    0.0004
#  6                                       Cohen's d =    0.8347
#  7                                       Hedge's g =    0.8258
#  8                                   Glass's delta =    1.0217
#  9                                               r =    0.3898)

# %% [markdown]
# # Now lets run the same t-test but with High spreads to all returns

# %%
df1 = pd.read_csv('minmax_OAS_with_Returns_Final_NO_Outliers_HY.csv')

# %%
df1.describe()
# Out:
#               OAS  Excess Return % 1-mo (Treasury)  \
# count  279.000000                       279.000000
# mean     0.351159                         0.492857
# std      0.247503                         0.237344
# min      0.000000                         0.000000
# 25%      0.155043                         0.371940
# 50%      0.289734                         0.500462
# 75%      0.489075                         0.624134
# max      1.000000                         1.000000
#
#        Excess Return % 1-mo (Agg)  Excess Return % 3-mo (Treasury)  \
# count                  279.000000                       278.000000
# mean                     0.494827                         0.490379
# std                      0.233785                         0.235178
# min                      0.000000                         0.000000
# 25%                      0.372569                         0.375000
# 50%                      0.504350                         0.512762
# 75%                      0.622223                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 3-mo (Agg)  Excess Return % 6-mo (Treasury)  \
# count                  278.000000                       275.000000
# mean                     0.489711                         0.495175
# std                      0.219736                         0.223090
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.514750                         0.512260
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 6-mo (Agg)  Excess Return % 9-mo (Treasury)  \
# count                  275.000000                       272.000000
# mean                     0.499683                         0.507613
# std                      0.225057                         0.219753
# min                      0.000000                         0.000000
# 25%                      0.375000                         0.375000
# 50%                      0.523454                         0.533540
# 75%                      0.625000                         0.625000
# max                      1.000000                         1.000000
#
#        Excess Return % 9-mo (Agg)  Excess Return % 12-mo (Treasury)  \
# count                  272.000000                        269.000000
# mean                     0.505828                          0.497147
# std                      0.213179                          0.207683
# min                      0.000000                          0.000000
# 25%                      0.375000                          0.375000
# 50%                      0.522281                          0.512685
# 75%                      0.625000                          0.625000
# max                      1.000000                          1.000000
#
#        Excess Return % 12-mo (Agg)  Excess Return % 24-mo (Treasury)  \
# count                   269.000000                        257.000000
# mean                      0.499497                          0.507319
# std                       0.201386                          0.215835
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.503557                          0.541286
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 24-mo (Agg)  Excess Return % 36-mo (Treasury)  \
# count                   257.000000                        245.000000
# mean                      0.498248                          0.493073
# std                       0.219765                          0.208462
# min                       0.000000                          0.000000
# 25%                       0.375000                          0.375000
# 50%                       0.537844                          0.517038
# 75%                       0.625000                          0.625000
# max                       1.000000                          1.000000
#
#        Excess Return % 36-mo (Agg)
# count                   245.000000
# mean                      0.484863
# std                       0.217124
# min                       0.000000
# 25%                       0.375000
# 50%                       0.523230
# 75%                       0.625000
# max                       1.000000

# %% [markdown]
# # we need to join the two data sets on the OA
