# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_excel (r'preprocess_securites.xlsx', sheet_name='HY')

# %%
df["OAS"].head()
# Out:
# 0    304
# 1    273
# 2    284
# 3    294
# 4    268
# Name: OAS, dtype: int64

# %%
df.describe()
# Out:
#                OAS  Excess Return % 1-mo (Treasury)  \
# count   280.000000                       280.000000
# mean    555.267857                         0.177493
# std     262.262139                         2.955461
# min     246.000000                       -16.532000
# 25%     376.250000                        -0.732500
# 50%     489.000000                         0.355000
# 75%     658.250000                         1.432500
# max    1978.000000                        12.580000
#
#        Excess Return % 1-mo (Agg)  Excess Return % 3-mo (Treasury)  \
# count                  280.000000                       278.000000
# mean                     0.112788                         0.550633
# std                      2.583599                         5.912487
# min                    -13.937600                       -38.039000
# 25%                     -0.757125                        -1.125500
# 50%                      0.289600                         1.252000
# ...

# %%
# OAS Outlier Adjustment
q1 = df["OAS"].quantile(0.25)
q3 = df["OAS"].quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

print(lower_bound)

for x in df["OAS"]:
    if x > upper_bound:
         x = upper_bound
    df.replace(to_replace = x, 
                 value =x)
    print(x)
# Out:
# -46.75
# 304
# 273
# 284
# 294
# 268
# 267
# 271
# 259
# 259
# 299
# 290
# 296
# 300
# 287
# 283
# 298
# 318
# 337
# 338
# 520
# 595
# 652
# 544
# 566
# 560
# 521
# 519
# 476
# 475
# 487
# 466
# 490
# 507
# 513
# 491
# 476
# 487
# 508
# 575
# 588
# 616
# 617
# 626
# 643
# 677
# 779
# 906
# 916
# 787
# 770
# 818
# 806
# 768
# 816
# 827
# 805
# 1018
# 961
# 839
# 824
# 789
# 819
# 708
# 688
# 728
# 874
# 971
# 962
# 1036
# 1059
# 883
# 890
# 829
# 838
# 772
# 644
# 679
# 613
# 566
# 546
# 549
# 471
# 448
# 418
# 405
# 434
# 441
# 391
# 428
# 410
# 401
# 406
# 382
# 357
# 306
# 309
# 330
# 283
# 352
# 418
# 413
# 385
# 330
# 366
# 354
# 361
# 367
# 371
# 342
# 337
# 313
# 304
# 312
# 335
# 345
# 349
# 344
# 329
# 320
# 289
# 272
# 282
# 285
# 274
# 246
# 298
# 419
# 454
# 419
# 436
# 574
# 591
# 693
# 765
# 816
# 682
# 648
# 730
# 795
# 830
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1081.25
# 1033
# 903
# 886
# 770
# 739
# 741
# 622
# 641
# 657
# ...

# %%
# OAS Outlier Adjustment
q1 = df["Excess Return % 1-mo (Treasury)"].quantile(0.25)
q3 = df["Excess Return % 1-mo (Treasury)"].quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

print(lower_bound)

for x in df["Excess Return % 1-mo (Treasury)"]:
    if x > upper_bound:
         x = upper_bound
    df.replace(to_replace = x, 
                 value =x)
    if x < lower_bound:
         x = lower_bound
    df.replace(to_replace = x, 
                 value =x)
        
    print(x)
# Out:
# -3.98
# 0.682
# 1.608
# -0.344
# -0.044
# 1.431
# 0.617
# 0.13
# 0.843
# 0.465
# -0.907
# 0.707
# 0.069
# 0.175
# 0.729
# 0.802
# 0.118
# -0.052
# -0.151
# 0.361
# -3.98
# -2.652
# -1.863
# 4.68
# -0.355
# 0.95
# 1.848
# 0.677
# 1.61
# 0.356
# -0.163
# 0.457
# -0.98
# -1.076
# -0.432
# 1.674
# 1.201
# 0.042
# -0.58
# -3.248
# 0.472
# -1.511
# 0.285
# -0.01
# -0.194
# -1.379
# -3.81
# -3.98
# 0.587
# 4.68
# 0.43
# -2.694
# -0.569
# 1.409
# -3.034
# -0.557
# -0.173
# -3.98
# 1.308
# 4.68
# -0.006
# 0.009
# -2.351
# 4.507
# -0.431
# -1.658
# -3.98
# -3.98
# 0.836
# -3.98
# -0.283
# 4.68
# -0.812
# 3.342
# -0.151
# 2.797
# 4.68
# -1.253
# 3.186
# 1.978
# 0.965
# -0.081
# 3.418
# 1.3
# 1.553
# 0.915
# -1.208
# -0.231
# 2.229
# -1.206
# 1.092
# 0.453
# -0.093
# 1.223
# 1.237
# 2.283
# 0.687
# -0.501
# 2.208
# -2.412
# -2.671
# 0.744
# 1.419
# 2.811
# -1.083
# 0.126
# -0.038
# -0.011
# 0.063
# 1.777
# 0.601
# 1.345
# 0.855
# -0.103
# -0.628
# -0.155
# 0.203
# 0.456
# 0.964
# 0.627
# 1.787
# ...

# %%
''''
def mod_outlier(df):
    df1 = df.copy()
    df = df._get_numeric_data()


    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)

    iqr = q3 - q1

    lower_bound = q1 -(1.5 * iqr) 
    upper_bound = q3 +(1.5 * iqr)

    for col in df.columns:
        for i in range(0,len(df[col])):
            if df[col][i] < lower_bound[col]:            
                df[col][i] = lower_bound[col]

            if df[col][i] > upper_bound[col]:            
                df[col][i] = upper_bound[col]    

            for col in df.columns:
                df1[col] = df[col]    
            return(df1)

#def mod_outlier(df):
df1 = df.copy()
df = df._get_numeric_data()


q1 = df.quantile(0.25)
q3 = df.quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

for col in df.columns:
        for i in range(0,len(df[col])):
            if df[col][i] < lower_bound[col]:            
                df[col][i] = lower_bound[col]

            if df[col][i] > upper_bound[col]:            
                df[col][i] = upper_bound[col]    

            for col in df.columns:
                df1[col] = df[col]    
            return(df1)
            
''''
# Out:
#   File "<ipython-input-6-7827cf9319b5>", line 52
#     ''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
df = mod_outlier(df)

# %%
df.head()

# %%
df["OAS"].describe()
